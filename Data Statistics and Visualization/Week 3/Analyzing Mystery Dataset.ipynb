# %%
import pandas as pd

# %%
data = pd.read_csv('mystery.tsv',sep='\t')

# %%
data.headad()
# Out:
#           x1         y1         x2         y2         x3         y3       x4  \
# 0  32.331110  61.411101  51.203891  83.339777  55.993030  79.277264  55.3846
# 1  53.421463  26.186880  58.974470  85.499818  50.032254  79.013071  51.5385
# 2  63.920202  30.832194  51.872073  85.829738  51.288459  82.435940  46.1538
# 3  70.289506  82.533649  48.179931  85.045117  51.170537  79.165294  42.8205
# 4  34.118830  45.734551  41.683200  84.017941  44.377915  78.164628  40.7692
#
#         y4         x5         y5         x6         y6
# 0  97.1795  58.213608  91.881892  38.337757  92.472719
# 1  96.0256  58.196054  92.214989  35.751871  94.116768
# 2  94.4872  58.718231  90.310532  32.767218  88.518295
# 3  91.4103  57.278373  89.907607  33.729607  88.622266
# 4  88.3333  58.082020  92.008145  37.238249  83.724928

# %%
data.isnull().any()

# %%
print('DSO\t545')
# Out:
# DSO	545

# %%
print('DSO\n545')
# Out:
# DSO
# 545

# %%
data.shape
# Out:
# (142, 12)

# %%
data.describe()
# Out:
#                x1          y1          x2          y2          x3          y3  \
# count  142.000000  142.000000  142.000000  142.000000  142.000000  142.000000
# mean    54.266100   47.834721   54.268730   47.830823   54.267320   47.837717
# std     16.769825   26.939743   16.769239   26.935727   16.760013   26.930036
# min     15.560750    0.015119   19.288205    9.691547   21.863581   16.326546
# 25%     39.724115   24.625892   41.627968   26.244735   43.379116   18.349610
# 50%     53.340296   47.535269   53.842088   47.382937   54.023213   51.025022
# 75%     69.146597   71.803148   64.798900   72.532852   64.972672   77.782382
# max     91.639961   97.475771   91.735539   85.876229   85.664761   85.578134
#
#                x4          y4          x5          y5          x6          y6
# count  142.000000  142.000000  142.000000  142.000000  142.000000  142.000000
# mean    54.263273   47.832253   54.267341   47.839545   54.260150   47.839717
# ...

# %%
### Find the mean and the standard deviation for all xs'

data.iloc[:,0::2].mean()
# Out:
# x1    54.266100
# x2    54.268730
# x3    54.267320
# x4    54.263273
# x5    54.267341
# x6    54.260150
# dtype: float64

# %%
m=data.columns

# %%
s=[i for i in data.columns if('x' in i)]

# %%
data.loc[:,s]
# Out:
#             x1         x2         x3       x4         x5         x6
# 0    32.331110  51.203891  55.993030  55.3846  58.213608  38.337757
# 1    53.421463  58.974470  50.032254  51.5385  58.196054  35.751871
# 2    63.920202  51.872073  51.288459  46.1538  58.718231  32.767218
# 3    70.289506  48.179931  51.170537  42.8205  57.278373  33.729607
# 4    34.118830  41.683200  44.377915  40.7692  58.082020  37.238249
# 5    67.670716  37.890416  45.010270  38.7179  57.489448  36.027198
# 6    53.259129  39.548974  48.559817  35.6410  28.088741  39.239281
# 7    63.514981  39.649574  42.142268  33.0769  28.085468  39.784525
# 8    67.980539  34.750597  41.026972  28.9744  28.087273  35.166029
# 9    67.372466  27.560835  34.575309  26.1538  27.578025  40.622116
# 10   15.560750  24.635540  31.168601  23.0769  27.779919  39.181907
# 11   71.790768  20.959465  32.644254  22.3077  28.589000  42.430889
# 12   70.242546  20.689149  26.666646  22.3077  28.739141  43.081256
# ...

# %%
type(data.describe())
# Out:
# pandas.core.frame.DataFrame

# %%
data.describe().iloc[1,::2]
# Out:
# x1    54.266100
# x2    54.268730
# x3    54.267320
# x4    54.263273
# x5    54.267341
# x6    54.260150
# Name: mean, dtype: float64

# %%
data.iloc[:,1::2].std()
# Out:
# y1    26.939743
# y2    26.935727
# y3    26.930036
# y4    26.935403
# y5    26.930275
# y6    26.930002
# dtype: float64

# %%
data.x1.corr(data.y1)
# Out:
# -0.0641283521673984

# %%
data.corr()
# Out:
#           x1        y1        x2        y2        x3        y3        x4  \
# x1  1.000000 -0.064128 -0.326398  0.033820 -0.310384 -0.012673 -0.333159
# y1 -0.064128  1.000000  0.029011  0.069117  0.002156  0.007853  0.016166
# x2 -0.326398  0.029011  1.000000 -0.068586  0.870825 -0.043937  0.933687
# y2  0.033820  0.069117 -0.068586  1.000000 -0.087114  0.933516 -0.060522
# x3 -0.310384  0.002156  0.870825 -0.087114  1.000000 -0.068343  0.888407
# y3 -0.012673  0.007853 -0.043937  0.933516 -0.068343  1.000000 -0.030538
# x4 -0.333159  0.016166  0.933687 -0.060522  0.888407 -0.030538  1.000000
# y4  0.000679  0.055565 -0.083429  0.963927 -0.088545  0.912446 -0.064472
# x5 -0.267500  0.025357  0.807216 -0.049861  0.809402 -0.056936  0.852319
# y5 -0.000542  0.019737 -0.091835  0.952281 -0.121842  0.931707 -0.064583
# x6 -0.231686 -0.004364  0.692209 -0.066971  0.631872 -0.016590  0.780970
# y6 -0.002251  0.047189 -0.128082  0.931417 -0.112877  0.908781 -0.108217
#
# ...

# %%
xy=zip(data.columns[0::2],data.columns[1::2])
[data.loc[:,m].corr(data.loc[:,n]) for m,n in xy]
# Out:
# [-0.0641283521673984,
#  -0.06858639424107654,
#  -0.06834335648025566,
#  -0.06447185270095167,
#  -0.06296110022065418,
#  -0.06558333729297583]

# %%
## while loop 
j=0
while j<data.shape[1]:
    print(data.iloc[:,j].corr(data.iloc[:,j+1]))
    j +=2
# Out:
# -0.0641283521673984
# -0.06858639424107654
# -0.06834335648025566
# -0.06447185270095167
# -0.06296110022065418
# -0.06558333729297583

# %% [markdown]
# # Visual EDA

# %%
import matplotlib.pyplot as plt

# %%
plt.figure()
plt.plot(data.x1,data.y1)

# %%
plt.plot(data.x1,data.y1,"p")

# %%
plt.plot(data.x2,data.y2,'o')

# %%
plt.plot(data.x3,data.y3,'o')

# %%
plt.plot(data.x4,data.y4,'o')

# %%
plt.plot(data.x5,data.y5,'o')

# %%
plt.plot(data.x6,data.y6,'o')

# %%
#4. 

C=[0,1,2,3]
D=[0.5,2,1,4]
