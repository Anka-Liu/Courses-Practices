# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import re
from category_encoders.ordinal import OrdinalEncoder
from sklearn.impute import SimpleImputer
from yellowbrick.features import Rank1D
from sklearn.linear_model import LinearRegression
from yellowbrick.model_selection import FeatureImportances
from sklearn.ensemble import RandomForestRegressor
from yellowbrick.target import FeatureCorrelation
import matplotlib.pyplot as plt
from sklearn.feature_selection import SelectFromModel
from lightgbm import LGBMRegressor
from category_encoders.target_encoder import TargetEncoder
import warnings
warnings.filterwarnings('ignore')

# %%
# %%time 
df = pd.read_csv('Datasets/Property Data Compiled.csv')
# Out:
# Wall time: 2.45 s

# %%
df.head()
# Out:
#    Row PropID      Property Address                    Property Name  \
# 0    1     P1  6215 Johns Creek Cmn  The Reserve at Johns Creek Walk
# 1    2     P2         927 3rd St NW                            8West
# 2    3     P3         555 NW 8th St         Eighth Street Apartments
# 3    4     P4        250 10th St NE                Post Parkside ATL
# 4    5     P5        100 10th St NW                      100 Midtown
#
#    Star Rating Energy Star LEED Certified     Building Status Secondary Type  \
# 0            4         NaN            NaN            Existing     Apartments
# 1            4         NaN            NaN  Under Construction     Apartments
# 2            4         NaN            NaN            Existing      Dormitory
# 3            4         NaN            NaN            Existing     Apartments
# 4            3         NaN            NaN            Existing     Apartments
#
#   Market Name             Submarket Name         City State        Zip  \
# 0     Atlanta  Outlying Fulton County MF  Johns Creek    GA  300971535
# 1     Atlanta         Upper West Side MF      Atlanta    GA      30318
# 2     Atlanta         Upper West Side MF      Atlanta    GA      30318
# 3     Atlanta           Piedmont Park MF      Atlanta    GA  303093735
# 4     Atlanta         Central Midtown MF      Atlanta    GA      30309
#
#   County Name For Sale Price For Sale Status  Land Area (AC)  \
# 0      Fulton            NaN               N          8.9600
# 1      Fulton            NaN               N          4.0000
# 2      Fulton            NaN               N          0.0764
# 3      Fulton            NaN               N          1.5700
# 4      Fulton            NaN               N             NaN
#
#    Number Of Stories     Style  Number Of Units $Price/Unit  Cap Rate  \
# 0                3.0    Garden              210         NaN       NaN
# 1                NaN       NaN              264         NaN       NaN
# 2                4.0  Mid-Rise              200         NaN       NaN
# 3                4.0  Mid-Rise              188         NaN       NaN
# 4                9.0  Mid-Rise              118         NaN       NaN
#
#    Vacancy %  Avg Unit SF Avg Asking/Unit  Avg Asking/SF Avg Effective/Unit  \
# 0       4.29       1157.0           1,708           1.48              1,684
# 1        NaN       1036.0             NaN            NaN                NaN
# 2       5.50          NaN             NaN            NaN                NaN
# 3       4.79        942.0           1,975           2.12              1,963
# 4      11.02       1068.0           2,278           2.13              2,256
#
#    Avg Effective/SF  Avg Concessions %  % Studios  % 1-Bed  % 2-Bed  % 3-Bed  \
# 0              1.46                1.4        NaN    35.71    46.67    17.62
# 1               NaN                0.0       1.89    37.12    49.62    11.36
# 2               NaN                0.0        NaN      NaN    25.00    25.00
# 3              2.11                0.6      32.45    45.21    22.34      NaN
# 4              2.11                1.0        NaN      NaN    61.02      NaN
#
#   % 4-Bed Rent Type Affordable Type Market Segment  Parking Spaces/Unit  \
# 0     NaN    Market             NaN            All                1.095
# 1     NaN    Market             NaN            All                  NaN
# 2  50.00%    Market             NaN        Student                  NaN
# 3     NaN    Market             NaN            All                1.223
# 4  38.98%    Market             NaN        Student                0.847
#
#    Number Of Parking Spaces  Days On Market  \
# 0                     230.0             NaN
# 1                       NaN             NaN
# 2                       NaN             NaN
# 3                     230.0             NaN
# 4                     100.0             NaN
#
#                                            Amenities  Number Of 1 Bedrooms  \
# 0  Business Center, Controlled Access, Clubhouse,...                  75.0
# 1                                                NaN                  98.0
# 2                                                NaN                   NaN
# 3  Business Center, Controlled Access, Courtyard,...                  85.0
# 4  24 Hour Access, Business Center, Laundry Facil...                   NaN
#
#    Number Of 2 Bedrooms  Number Of 3 Bedrooms  Number Of 4 Bedrooms  \
# 0                  98.0                  37.0                   NaN
# 1                 131.0                  30.0                   NaN
# 2                  50.0                  50.0                 100.0
# 3                  42.0                   NaN                   NaN
# 4                  72.0                   NaN                  46.0
#
#   Architect Name Building Class Building Park  \
# 0            NaN              A           NaN
# 1    MSTSD, Inc.              A         8West
# 2            NaN              B           NaN
# 3            NaN              B           NaN
# 4            NaN              B           NaN
#
#                        Closest Transit Stop  Closest Transit Stop Dist (mi)  \
# 0                                       NaN                             NaN
# 1  Hartsfield-Jackson Atlanta International                           12.87
# 2  Hartsfield-Jackson Atlanta International                           14.83
# 3                                   Midtown                            0.45
# 4                                   Midtown                            0.30
#
#    Closest Transit Stop Walk Time (min) Construction Material  \
# 0                                   NaN               Masonry
# 1                                   NaN                   NaN
# 2                                   NaN                   NaN
# 3                                  10.0               Masonry
# 4                                   6.0   Reinforced Concrete
#
#                 Developer Name  \
# 0                          NaN
# 1  Atlantic Capital Properties
# 2                          NaN
# 3                          NaN
# 4                          NaN
#
#                                             Features  \
# 0  Business Center, Controlled Access, Clubhouse,...
# 1                                                NaN
# 2                                                NaN
# 3  Business Center, Controlled Access, Courtyard,...
# 4  24 Hour Access, Business Center, Laundry Facil...
#
#    Four Bedroom Asking Rent/SF Four Bedroom Asking Rent/Unit  \
# 0                          NaN                           NaN
# 1                          NaN                           NaN
# 2                          NaN                           NaN
# 3                          NaN                           NaN
# 4                         2.48                         3,299
#
#    Four Bedroom Avg SF  Four Bedroom Concessions %  \
# 0                  NaN                         NaN
# 1                  NaN                         NaN
# 2                  NaN                         NaN
# 3                  NaN                         NaN
# 4               1330.0                         1.0
#
#    Four Bedroom Effective Rent/SF Four Bedroom Effective Rent/Unit  \
# 0                             NaN                              NaN
# 1                             NaN                              NaN
# 2                             NaN                              NaN
# 3                             NaN                              NaN
# 4                            2.46                            3,266
#
#    Four Bedroom Vacancy %  Four Bedroom Vacant Units  Number Of Studios  \
# 0                     NaN                        NaN                NaN
# 1                     NaN                        NaN                5.0
# 2                     5.0                        5.0                NaN
# 3                     NaN                        NaN               61.0
# 4                    10.9                        5.0                NaN
#
#    One Bedroom Asking Rent/SF One Bedroom Asking Rent/Unit  \
# 0                        1.44                        1,314
# 1                         NaN                          NaN
# 2                         NaN                          NaN
# 3                        2.06                        1,795
# 4                         NaN                          NaN
#
#    One Bedroom Avg SF  One Bedroom Concessions %  \
# 0               914.0                        0.5
# 1               795.0                        NaN
# 2                 NaN                        NaN
# 3               870.0                        0.6
# 4                 NaN                        NaN
#
#    One Bedroom Effective Rent/SF One Bedroom Effective Rent/Unit  \
# 0                           1.43                           1,307
# 1                            NaN                             NaN
# 2                            NaN                             NaN
# 3                           2.05                           1,784
# 4                            NaN                             NaN
#
#    One Bedroom Vacancy %  One Bedroom Vacant Units       Owner Contact  \
# 0                    4.0                       3.0  C. Allan Swaringen
# 1                    NaN                       NaN                 NaN
# 2                    NaN                       NaN                 NaN
# 3                    4.7                       4.0      H. Eric Bolton
# 4                    NaN                       NaN                 NaN
#
#                                         Owner Name  Percent Leased  \
# 0   Jones Lang LaSalle Income Property Trust, Inc.             NaN
# 1                            8 West Apartments Llc             NaN
# 2  Board Of Regents of the University System of GA             NaN
# 3          Mid-America Apartment Communities, Inc.             NaN
# 4                         The Pierce Company, Inc.             NaN
#
#               Property Manager Address Property Manager City State Zip  \
# 0                 6215 Johns Creek Cmn       Johns Creek, GA 300971535
# 1  750 Town & Country Blvd Suite # 520               Houston, TX 77024
# 2                                  NaN                             NaN
# 3                          250 10th St           Atlanta, GA 30309
# 4                       100 10th St NW               Atlanta, GA 30309
#
#   Property Manager Contact                           Property Manager Name  \
# 0                      NaN      Carter Haston- Reserve at Johns Creek Walk
# 1                      NaN                       Trammell Crow Residential
# 2                      NaN                                             NaN
# 3                      NaN                             MAA - Post Parkside
# 4             Tammy Primus  Pierce Education Prop - 100 Midtown Apartments
#
#    Property Manager Phone  PropertyID  PropertyType  Serial  \
# 0            6.784754e+09     6400737  Multi-Family     NaN
# 1            7.137816e+09    10858893  Multi-Family     NaN
# 2                     NaN    11027518  Multi-Family     NaN
# 3            4.048178e+09     6897678  Multi-Family     NaN
# 4            4.049617e+09     6865125  Multi-Family     NaN
#
#    Studio Asking Rent/SF Studio Asking Rent/Unit  Studio Avg SF  \
# 0                    NaN                     NaN            NaN
# 1                    NaN                     NaN          589.0
# 2                    NaN                     NaN            NaN
# 3                   2.28                   1,748          765.0
# 4                    NaN                     NaN            NaN
#
#    Studio Concessions %  Studio Effective Rent/SF Studio Effective Rent/Unit  \
# 0                   NaN                       NaN                        NaN
# 1                   NaN                       NaN                        NaN
# 2                   NaN                       NaN                        NaN
# 3                   0.6                      2.27                      1,737
# 4                   NaN                       NaN                        NaN
#
#    Studio Vacancy %  Studio Vacant Units        Submarket Cluster  \
# 0               NaN                  NaN          North Fulton MF
# 1               NaN                  NaN  West Midtown Atlanta MF
# 2               NaN                  NaN  West Midtown Atlanta MF
# 3               4.9                  3.0       Midtown Atlanta MF
# 4               NaN                  NaN       Midtown Atlanta MF
#
#    Three Bedroom Asking Rent/SF Three Bedroom Asking Rent/Unit  \
# 0                          1.26                          2,021
# 1                           NaN                            NaN
# 2                           NaN                            NaN
# 3                           NaN                            NaN
# 4                           NaN                            NaN
#
#    Three Bedroom Avg SF  Three Bedroom Concessions %  \
# 0                1602.0                          0.7
# 1                1434.0                          NaN
# 2                   NaN                          NaN
# 3                   NaN                          NaN
# 4                   NaN                          NaN
#
#    Three Bedroom Effective Rent/SF Three Bedroom Effective Rent/Unit  \
# 0                             1.25                             2,008
# 1                              NaN                               NaN
# 2                              NaN                               NaN
# 3                              NaN                               NaN
# 4                              NaN                               NaN
#
#    Three Bedroom Vacancy %  Three Bedroom Vacant Units  Total Buildings  \
# 0                      5.4                         2.0              7.0
# 1                      NaN                         NaN              1.0
# 2                      6.0                         3.0              3.0
# 3                      NaN                         NaN              3.0
# 4                      NaN                         NaN              1.0
#
#    Two Bedroom Asking Rent/SF Two Bedroom Asking Rent/Unit  \
# 0                        1.61                        1,891
# 1                         NaN                          NaN
# 2                         NaN                          NaN
# 3                        2.08                        2,685
# 4                        1.81                        1,626
#
#    Two Bedroom Avg SF  Two Bedroom Concessions %  \
# 0              1175.0                        2.2
# 1              1143.0                        NaN
# 2                 NaN                        NaN
# 3              1291.0                        0.6
# 4               900.0                        1.0
#
#    Two Bedroom Effective Rent/SF Two Bedroom Effective Rent/Unit  \
# 0                           1.57                           1,850
# 1                            NaN                             NaN
# 2                            NaN                             NaN
# 3                           2.07                           2,668
# 4                           1.79                           1,610
#
#    Two Bedroom Vacancy %  Two Bedroom Vacant Units  Year Built  \
# 0                    4.1                       4.0      2006.0
# 1                    NaN                       NaN      2021.0
# 2                    6.0                       3.0      1995.0
# 3                    4.8                       2.0      1999.0
# 4                   11.1                       8.0      1968.0
#
#    Year Renovated Zoning                      Owner Address  \
# 0             NaN     C1       333 W Wacker Dr Suite # 2300
# 1             NaN    NaN                      654 8th St NW
# 2             NaN     R5               270 Washington St SW
# 3             NaN    RG4        6815 Poplar Ave Suite # 500
# 4             NaN     C4  8880 Rio San Diego Dr Suite # 750
#
#        Owner City State Zip     RBA Parcel Number 1(Min) Parcel Number 2(Max)  \
# 0     Chicago, IL 606061220  260872     11-1000-0359-034   11-1000-0359-034-1
# 1     Atlanta, GA 303185761  270000   14-0112-0003-061-5   14-0112-0003-061-5
# 2     Atlanta, GA 303039056  250000   17-0149-0008-098-2   17-0149-0008-098-2
# 3  Germantown, TN 381383606  243660   17-0106-0009-120-4   17-0106-0009-120-4
# 4   San Diego, CA 921081634  375662   17-0107-0006-060-4   17-0107-0006-060-4
#
#   Last Sale Date Last Sale Price   Latitude  Longitude  Acq Notes (my data)  \
# 0       08/01/17      47,000,000  34.050153 -84.178580                  NaN
# 1       02/27/19             NaN  33.779445 -84.409043                  NaN
# 2            NaN             NaN  33.779827 -84.405236                  NaN
# 3       10/02/08      25,347,300  33.782037 -84.378623                  NaN
# 4       12/10/14      22,330,000  33.780993 -84.390389                  NaN
#
#    2010 Avg Age(1m)  2010 Med Age(1m)  2010 Pop Age 0-4(1m)  \
# 0              32.4              36.4                 891.0
# 1              27.8              24.1                 395.0
# 2              26.4              23.4                 355.0
# 3              35.1              32.4                 842.0
# 4              31.2              27.6                 503.0
#
#    2010 Pop Age 10-14(1m)  2010 Pop Age 15-19(1m)  2010 Pop Age 20-24(1m)  \
# 0                  1555.0                  1266.0                   469.0
# 1                   225.0                  3122.0                  6299.0
# 2                   197.0                  3806.0                  7032.0
# 3                   366.0                  1668.0                  4039.0
# 4                   247.0                  3326.0                  8641.0
#
#    2010 Pop Age 45-49(1m)  2010 Pop Age 50-54(1m)  2010 Pop Age 55-59(1m)  \
# 0                  1573.0                  1177.0                   684.0
# 1                   719.0                   567.0                   432.0
# 2                   539.0                   467.0                   339.0
# 3                  1805.0                  1437.0                  1237.0
# 4                  1479.0                  1194.0                   894.0
#
#    2010 Pop Age 5-9(1m)  2010 Pop Age 60-64(1m)  2010 Pop Age 65+(1m)  \
# 0                1335.0                   428.0                 549.0
# 1                 241.0                   260.0                 357.0
# 2                 216.0                   208.0                 258.0
# 3                 485.0                  1043.0                1556.0
# 4                 274.0                   721.0                1005.0
#
#    2010 Pop Age 85+(1m)  2019 Avg Age(1m)  2019 Avg Age&#044; Female(1m)  \
# 0                  47.0              35.5                           36.3
# 1                  45.0              30.6                           29.9
# 2                  30.0              29.9                           29.2
# 3                 154.0              36.4                           35.4
# 4                  82.0              33.4                           32.5
#
#    2019 Avg Age&#044; Male(1m)  2019 HH Age 15-24(1m)  2019 HH Age 25-34(1m)  \
# 0                         34.5                  380.0                  844.0
# 1                         31.1                  513.0                 2776.0
# 2                         30.3                  640.0                 3836.0
# 3                         37.2                  493.0                 4963.0
# 4                         34.1                  714.0                 6137.0
#
#    2019 HH Age 35-44(1m)  2019 HH Age 45-54(1m)  2019 HH Age 55-64(1m)  \
# 0                  988.0                 1712.0                 1300.0
# 1                 1445.0                  803.0                  560.0
# 2                 2442.0                 1408.0                  826.0
# 3                 5478.0                 4078.0                 2638.0
# 4                 5630.0                 3774.0                 2258.0
#
#    2019 HH Age 65-74(1m)  2019 HH Age 75-84(1m)  2019 HH Age 85+(1m)  \
# 0                  548.0                  172.0                 50.0
# 1                  312.0                  114.0                 43.0
# 2                  371.0                  119.0                 35.0
# 3                 1557.0                  603.0                188.0
# 4                 1213.0                  442.0                127.0
#
#    2019 Med Age(1m)  2019 Med Age&#044; Female(1m)  \
# 0              35.5                           38.1
# 1              29.4                           28.9
# 2              29.2                           28.9
# 3              36.1                           34.6
# 4              32.7                           31.9
#
#    2019 Med Age&#044; Male(1m)  2019 Median HH Age(1m)  2019 Pop Age <19(1m)  \
# 0                         32.2                    49.6                5179.0
# 1                         29.7                    33.0                3967.0
# 2                         29.5                    36.5                4870.0
# 3                         37.3                    43.3                5858.0
# 4                         33.2                    40.9                6930.0
#
#    2019 Pop Age 0-4(1m)  2019 Pop Age 10-14(1m)  2019 Pop Age 15-19(1m)  \
# 0                 876.0                  1442.0                  1808.0
# 1                1420.0                   554.0                  1028.0
# 2                1831.0                   633.0                  1204.0
# 3                2266.0                   989.0                   927.0
# 4                2844.0                   960.0                  1224.0
#
#    2019 Pop Age 20-24(1m)  2019 Pop Age 20-64(1m)  2019 Pop Age 25-29(1m)  \
# 0                  1640.0                 11539.0                  1297.0
# 1                  2857.0                 16909.0                  4512.0
# 2                  3405.0                 20199.0                  5407.0
# 3                  1976.0                 26356.0                  4123.0
# 4                  3647.0                 32682.0                  6849.0
#
#    2019 Pop Age 30-34(1m)  2019 Pop Age 35-39(1m)  2019 Pop Age 40-44(1m)  \
# 0                   812.0                   847.0                  1175.0
# 1                  3370.0                  2077.0                  1248.0
# 2                  4092.0                  2589.0                  1574.0
# 3                  4546.0                  4103.0                  3284.0
# 4                  6295.0                  4840.0                  3441.0
#
#    2019 Pop Age 45-49(1m)  2019 Pop Age 50-54(1m)  2019 Pop Age 55-59(1m)  \
# 0                  1666.0                  1679.0                  1440.0
# 1                   978.0                   761.0                   637.0
# 2                  1172.0                   841.0                   661.0
# 3                  2906.0                  2231.0                  1807.0
# 4                  2804.0                  2050.0                  1599.0
#
#    2019 Pop Age 5-9(1m)  2019 Pop Age 60-64(1m)  2019 Pop Age 65+(1m)  \
# 0                1053.0                   983.0                1319.0
# 1                 965.0                   469.0                 749.0
# 2                1202.0                   458.0                 660.0
# 3                1676.0                  1380.0                2630.0
# 4                1902.0                  1157.0                1997.0
#
#    2019 Pop Age 65-69(1m)  2019 Pop Age 70-74(1m)  2019 Pop Age 75-79(1m)  \
# 0                   616.0                   343.0                   183.0
# 1                   328.0                   196.0                   106.0
# 2                   305.0                   174.0                    91.0
# 3                  1065.0                   718.0                   420.0
# 4                   846.0                   547.0                   308.0
#
#    2019 Pop Age 80-84(1m)  2019 Pop Age 85+(1m)  2024 Avg Age(1m)  \
# 0                    95.0                  82.0              37.1
# 1                    58.0                  61.0              32.6
# 2                    47.0                  43.0              31.8
# 3                   222.0                 205.0              38.0
# 4                   158.0                 138.0              35.2
#
#    2024 Avg Female Age(1m)  2024 Avg Male Age(1m)  2024 HH Age 15-24(1m)  \
# 0                     38.1                   36.0                  366.0
# 1                     31.2                   33.4                  280.0
# 2                     30.6                   32.7                  354.0
# 3                     36.7                   39.0                  381.0
# 4                     33.9                   36.2                  443.0
#
#    2024 HH Age 25-34(1m)  2024 HH Age 35-44(1m)  2024 HH Age 45-54(1m)  \
# 0                 1103.0                  928.0                 1384.0
# 1                 2172.0                 2165.0                 1106.0
# 2                 2945.0                 3387.0                 2012.0
# 3                 3382.0                 5958.0                 5079.0
# 4                 4297.0                 6615.0                 4986.0
#
#    2024 HH Age 55-64(1m)  2024 HH Age 65-74(1m)  2024 HH Age 75-84(1m)  \
# 0                 1488.0                  855.0                  305.0
# 1                  671.0                  415.0                  184.0
# 2                 1154.0                  586.0                  216.0
# 3                 3447.0                 2088.0                  964.0
# 4                 3112.0                 1734.0                  746.0
#
#    2024 HH Age 85+(1m)  2024 Med Age(1m)  2024 Median HH Age(1m)  \
# 0                 78.0              35.9                    51.2
# 1                 56.0              33.1                    40.0
# 2                 55.0              32.9                    41.1
# 3                292.0              39.2                    47.1
# 4                210.0              36.2                    44.6
#
#    2024 Pop Age <19(1m)  2024 Pop Age 0-4(1m)  2024 Pop Age 10-14(1m)  \
# 0                5007.0                1214.0                  1202.0
# 1                5040.0                1792.0                   979.0
# 2                6419.0                2325.0                  1235.0
# 3                7752.0                2584.0                  1684.0
# 4                9531.0                3400.0                  1931.0
#
#    2024 Pop Age 15-19(1m)  2024 Pop Age 20-24(1m)  2024 Pop Age 20-64(1m)  \
# 0                  1509.0                  1695.0                 12305.0
# 1                   838.0                  1499.0                 16878.0
# 2                  1007.0                  1780.0                 20554.0
# 3                  1210.0                  1337.0                 26245.0
# 4                  1367.0                  1983.0                 32676.0
#
#    2024 Pop Age 25-29(1m)  2024 Pop Age 30-34(1m)  2024 Pop Age 35-39(1m)  \
# 0                  1609.0                  1281.0                  1004.0
# 1                  2832.0                  3515.0                  3065.0
# 2                  3394.0                  4264.0                  3783.0
# 3                  2439.0                  3712.0                  4264.0
# 4                  4014.0                  5680.0                  5799.0
#
#    2024 Pop Age 40-44(1m)  2024 Pop Age 45-49(1m)  2024 Pop Age 50-54(1m)  \
# 0                  1003.0                  1277.0                  1538.0
# 1                  2147.0                  1426.0                  1011.0
# 2                  2710.0                  1815.0                  1249.0
# 3                  4025.0                  3480.0                  2880.0
# 4                  4840.0                  3747.0                  2852.0
#
#    2024 Pop Age 55-59(1m)  2024 Pop Age 5-9(1m)  2024 Pop Age 60-64(1m)  \
# 0                  1567.0                1082.0                  1331.0
# 1                   778.0                1431.0                   605.0
# 2                   903.0                1852.0                   656.0
# 3                  2307.0                2274.0                  1801.0
# 4                  2157.0                2833.0                  1604.0
#
#    2024 Pop Age 65+(1m)  2024 Pop Age 65-69(1m)  2024 Pop Age 70-74(1m)  \
# 0                2226.0                   963.0                   609.0
# 1                1125.0                   451.0                   303.0
# 2                1077.0                   459.0                   292.0
# 3                3703.0                  1372.0                   994.0
# 4                2979.0                  1165.0                   805.0
#
#    2024 Pop Age 75-79(1m)  2024 Pop Age 80-84(1m)  2024 Pop Age 85+(1m)  \
# 0                   344.0                   176.0                 134.0
# 1                   184.0                   102.0                  85.0
# 2                   169.0                    89.0                  68.0
# 3                   654.0                   370.0                 313.0
# 4                   508.0                   279.0                 222.0
#
#    Situs_Num Situs_Num_Remainder SITUS_DIR          SITUS_NAM  \
# 0     6215.0     Johns Creek Cmn       NaN  Johns Creek Cmn
# 1      927.0           3rd St NW       NaN            3rd St
# 2      555.0           NW 8th St        NW            8th St
# 3      250.0          10th St NE       NaN           10th St
# 4      100.0          10th St NW       NaN           10th St
#
#                                          SCP                 SCSitus_NumNam  \
# 0  GA Fulton The Reserve at Johns Creek Walk  GA Fulton6215 Johns Creek Cmn
# 1                            GA Fulton 8West            GA Fulton927 3rd St
# 2         GA Fulton Eighth Street Apartments            GA Fulton555 8th St
# 3                GA Fulton Post Parkside ATL           GA Fulton250 10th St
# 4                      GA Fulton 100 Midtown           GA Fulton100 10th St
#
#                           SCAPN
# 0    GA Fulton 11-1000-0359-034
# 1  GA Fulton 14-0112-0003-061-5
# 2  GA Fulton 17-0149-0008-098-2
# 3  GA Fulton 17-0106-0009-120-4
# 4  GA Fulton 17-0107-0006-060-4

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ### Replace NAs in number of bedrooms with zeros

# %%
for key in df.keys():
    if 'bed' in key.lower():
        df[key].fillna(0, inplace = True)
    elif 'studio' in key.lower():
        df[key].fillna(0, inplace = True)

# %% [markdown]
# ### Clean state names

# %%
df['State'] = df['State'].apply(lambda x: re.sub('[^a-z]', '', x.lower()).upper())

# %% [markdown]
# ### Consider only Existing properties and ones Under Renovation

# %%
search_mask = df['Building Status'].apply(lambda x: True if x in ['Existing','Under Renovation'] else False)
df = df[search_mask]

# %% [markdown]
# ### Clean Year Renovated

# %%
df['Year Renovated'].fillna(-1, inplace = True)

# %% [markdown]
# ### Clean Building Material

# %% [markdown]
# #### Remove NaNs in Building Materials by replacing with the most frequently Material used in the County

# %%
county_mat = df.groupby('County Name')['Construction Material'].describe()['top']
county = df['County Name'].tolist()
materials = df['Construction Material'].tolist()

for i in range(len(materials)):
    if type(materials[i]) == float:
        materials[i] = county_mat[county[i]]
        
df['Construction Material'] = materials

# %% [markdown]
# #### Remove remaining NaNs with most frequently used Material across the Dataset

# %%
mat = df['Construction Material'].value_counts().idxmax()
df['Construction Material'].fillna(mat, inplace = True)

# %% [markdown]
# ### Remove NaNs from Average Effective Rent

# %%
df = df[~df['Avg Effective/SF'].isna()]

# %% [markdown]
# ### Make all Zip code 5 digits

# %%
zip_res = df['Zip'].apply(lambda x: len(str(x))).min()
df['Zip'] = df['Zip'].apply(lambda x: int(str(x)[:zip_res]))

# %% [markdown]
# ### Clean Features

# %% [markdown]
# #### Split Features in individual columns

# %%
# %%time
df['Features'].fillna('None', inplace = True)
feature_list = df['Features'].apply(lambda x: np.array(list(map(lambda y: y[1:] if y[0] == ' ' else y, x.split(','))))).values
features = []
for row in feature_list:
    for feature in row:
        features.append(feature)

features = list(set(features))

for item in features:
    df[item] = df['Features'].apply(lambda x: 1 if item in x else 0)
# Out:
# Wall time: 3.5 s

# %% [markdown]
# #### Remove features present in less than 5% of the rows

# %%
# %%time

feature_freq = pd.DataFrame({
    'Feature': features,
    'Percentage': list(map(lambda x: sum(df[x])/df.shape[0], features))
})
feature_freq.sort_values('Percentage', ascending = False, inplace = True)

for feature in features:
    if feature not in feature_freq[feature_freq['Percentage'] > 0.05]['Feature'].values:
        df.drop(columns=[feature], inplace = True)
# Out:
# Wall time: 6.62 s

# %% [markdown]
# ### Zero Imputation

# %%
#Number Of Parking Spaces, Parking Spaces/Unit

# %%
for key in ['Number Of Parking Spaces', 'Parking Spaces/Unit']:
    df[key].fillna(0, inplace = True)

# %%
#Number Of Parking Spaces, Parking Spaces/Unit

# %% [markdown]
# ### Mode Imputation

# %%
mode = df['Total Buildings'].mode()[0]
df['Total Buildings'].fillna(mode, inplace = True)

# %%
#Total Buildings,

# %% [markdown]
# ### Impute by mode in Zip Code

# %%
# %%time 
zip_code = df['Zip'].tolist()
for item in ['Market Segment', 'Number Of Stories', 'Vacancy %', 'Closest Transit Stop Dist (mi)', 'Submarket Cluster', 'Submarket Name', 'Closest Transit Stop']:
    item_list = df[item].tolist()
    if df[item].dtype == 'object':
        mode_zip = df.groupby('Zip')[item].describe()['top']
    else:
        mode_zip = df.groupby('Zip')[item].median()
    for i in range(len(item_list)):
        if type(item_list[i]) == float:
            if np.isnan(item_list[i]):
                item_list[i] = mode_zip[zip_code[i]]
    df[item] = item_list
# Out:
# Wall time: 41.3 s

# %% [markdown]
# ### Create a data frame with percentage of NAs for every column

# %%
def na_freq(df):
    df_na = (df.isna().sum()/df.shape[0]).reset_index().sort_values(0, ascending = False)
    df_na.rename(columns = {'index':'key', 0:'values'}, inplace = True)
    return df_na

# %%
df_na = na_freq(df)
df_na
# Out:
#                                       key    values
# 81                                 Serial  1.000000
# 120                   Acq Notes (my data)  1.000000
# 73                         Percent Leased  1.000000
# 21                               Cap Rate  0.999759
# 20                            $Price/Unit  0.999097
# 14                         For Sale Price  0.999097
# 5                             Energy Star  0.997230
# 39                         Days On Market  0.994882
# 47                          Building Park  0.976697
# 45                         Architect Name  0.954236
# 50   Closest Transit Stop Walk Time (min)  0.929789
# 52                         Developer Name  0.822364
# 35                        Affordable Type  0.814355
# 206                             SITUS_DIR  0.783886
# 76               Property Manager Contact  0.755163
# 71                          Owner Contact  0.694466
# 117                       Last Sale Price  0.567472
# 116                        Last Sale Date  0.359186
# 110                                Zoning  0.344373
# 15                        For Sale Status  0.083037
# 90                      Submarket Cluster  0.059011
# 9                          Submarket Name  0.059011
# 49         Closest Transit Stop Dist (mi)  0.056964
# 48                   Closest Transit Stop  0.056964
# 16                         Land Area (AC)  0.054555
# 40                              Amenities  0.047631
# 204                             Situs_Num  0.023063
# 112                  Owner City State Zip  0.012344
# 111                         Owner Address  0.010959
# 78                 Property Manager Phone  0.010297
# 108                            Year Built  0.009273
# 115                  Parcel Number 2(Max)  0.007828
# 114                  Parcel Number 1(Min)  0.007828
# 72                             Owner Name  0.004998
# 74               Property Manager Address  0.004817
# 75        Property Manager City State Zip  0.004817
# 77                  Property Manager Name  0.004697
# 18                                  Style  0.004215
# 22                              Vacancy %  0.002288
# 34                              Rent Type  0.000482
# 17                      Number Of Stories  0.000422
# 23                            Avg Unit SF  0.000422
# 3                           Property Name  0.000361
# 113                                   RBA  0.000181
# 7                          Secondary Type  0.000060
# 185                2024 Pop Age 10-14(1m)  0.000000
# 181                      2024 Med Age(1m)  0.000000
# 150                  2019 Pop Age 0-4(1m)  0.000000
# 177                 2024 HH Age 55-64(1m)  0.000000
# 178                 2024 HH Age 65-74(1m)  0.000000
# 179                 2024 HH Age 75-84(1m)  0.000000
# 180                   2024 HH Age 85+(1m)  0.000000
# 189                2024 Pop Age 25-29(1m)  0.000000
# 188                2024 Pop Age 20-64(1m)  0.000000
# 184                  2024 Pop Age 0-4(1m)  0.000000
# 149                  2019 Pop Age <19(1m)  0.000000
# 151                2019 Pop Age 10-14(1m)  0.000000
# 187                2024 Pop Age 20-24(1m)  0.000000
# 148                2019 Median HH Age(1m)  0.000000
# 186                2024 Pop Age 15-19(1m)  0.000000
# 182                2024 Median HH Age(1m)  0.000000
# 183                  2024 Pop Age <19(1m)  0.000000
# 147           2019 Med Age&#044; Male(1m)  0.000000
# 176                 2024 HH Age 45-54(1m)  0.000000
# 173                 2024 HH Age 15-24(1m)  0.000000
# 175                 2024 HH Age 35-44(1m)  0.000000
# 174                 2024 HH Age 25-34(1m)  0.000000
# 166                2019 Pop Age 70-74(1m)  0.000000
# 167                2019 Pop Age 75-79(1m)  0.000000
# 168                2019 Pop Age 80-84(1m)  0.000000
# 164                  2019 Pop Age 65+(1m)  0.000000
# 163                2019 Pop Age 60-64(1m)  0.000000
# 169                  2019 Pop Age 85+(1m)  0.000000
# 162                  2019 Pop Age 5-9(1m)  0.000000
# 170                      2024 Avg Age(1m)  0.000000
# 190                2024 Pop Age 30-34(1m)  0.000000
# 161                2019 Pop Age 55-59(1m)  0.000000
# 160                2019 Pop Age 50-54(1m)  0.000000
# 159                2019 Pop Age 45-49(1m)  0.000000
# 158                2019 Pop Age 40-44(1m)  0.000000
# 157                2019 Pop Age 35-39(1m)  0.000000
# 156                2019 Pop Age 30-34(1m)  0.000000
# 155                2019 Pop Age 25-29(1m)  0.000000
# 154                2019 Pop Age 20-64(1m)  0.000000
# 153                2019 Pop Age 20-24(1m)  0.000000
# 172                 2024 Avg Male Age(1m)  0.000000
# 152                2019 Pop Age 15-19(1m)  0.000000
# 165                2019 Pop Age 65-69(1m)  0.000000
# 171               2024 Avg Female Age(1m)  0.000000
# 0                                     Row  0.000000
# 191                2024 Pop Age 35-39(1m)  0.000000
# 233                      Volleyball Court  0.000000
# 222                          Tennis Court  0.000000
# 223                     Controlled Access  0.000000
# 224                                Lounge  0.000000
# 225                    Laundry Facilities  0.000000
# 226                       Business Center  0.000000
# 227                              Gameroom  0.000000
# 228                                 Gated  0.000000
# 229                           Picnic Area  0.000000
# 230                         Car Wash Area  0.000000
# 231                              Elevator  0.000000
# 232                            Playground  0.000000
# 234                                  Pool  0.000000
# 220                         Storage Space  0.000000
# 235                                   Spa  0.000000
# 236                        24 Hour Access  0.000000
# 237                        Fitness Center  0.000000
# 238                       Package Service  0.000000
# 239                             Courtyard  0.000000
# 240                                 Wi-Fi  0.000000
# 241                             Recycling  0.000000
# 242            Breakfast/Coffee Concierge  0.000000
# 243                       Laundry Service  0.000000
# 244             Planned Social Activities  0.000000
# 245                         Pet Play Area  0.000000
# 221                 Walking/Biking Trails  0.000000
# 219                   Maintenance on site  0.000000
# 192                2024 Pop Age 40-44(1m)  0.000000
# 203                  2024 Pop Age 85+(1m)  0.000000
# 193                2024 Pop Age 45-49(1m)  0.000000
# 194                2024 Pop Age 50-54(1m)  0.000000
# 195                2024 Pop Age 55-59(1m)  0.000000
# 196                  2024 Pop Age 5-9(1m)  0.000000
# 197                2024 Pop Age 60-64(1m)  0.000000
# 198                  2024 Pop Age 65+(1m)  0.000000
# 199                2024 Pop Age 65-69(1m)  0.000000
# 145                      2019 Med Age(1m)  0.000000
# 200                2024 Pop Age 70-74(1m)  0.000000
# 201                2024 Pop Age 75-79(1m)  0.000000
# 202                2024 Pop Age 80-84(1m)  0.000000
# 205                   Situs_Num_Remainder  0.000000
# 218                      Basketball Court  0.000000
# 207                             SITUS_NAM  0.000000
# 208                                   SCP  0.000000
# 209                        SCSitus_NumNam  0.000000
# 210                                 SCAPN  0.000000
# 211                                 Grill  0.000000
# 212                             Concierge  0.000000
# 213                               Sundeck  0.000000
# 214             Furnished Units Available  0.000000
# 215            Media Center/Movie Theatre  0.000000
# 216                                Cabana  0.000000
# 217              Property Manager on Site  0.000000
# 146         2019 Med Age&#044; Female(1m)  0.000000
# 123                  2010 Pop Age 0-4(1m)  0.000000
# 144                   2019 HH Age 85+(1m)  0.000000
# 60                 Four Bedroom Vacancy %  0.000000
# 44                   Number Of 4 Bedrooms  0.000000
# 46                         Building Class  0.000000
# 51                  Construction Material  0.000000
# 53                               Features  0.000000
# 54            Four Bedroom Asking Rent/SF  0.000000
# 55          Four Bedroom Asking Rent/Unit  0.000000
# 56                    Four Bedroom Avg SF  0.000000
# 57             Four Bedroom Concessions %  0.000000
# 58         Four Bedroom Effective Rent/SF  0.000000
# 59       Four Bedroom Effective Rent/Unit  0.000000
# 61              Four Bedroom Vacant Units  0.000000
# 82                  Studio Asking Rent/SF  0.000000
# 62                      Number Of Studios  0.000000
# 63             One Bedroom Asking Rent/SF  0.000000
# 64           One Bedroom Asking Rent/Unit  0.000000
# 65                     One Bedroom Avg SF  0.000000
# 66              One Bedroom Concessions %  0.000000
# 67          One Bedroom Effective Rent/SF  0.000000
# 68        One Bedroom Effective Rent/Unit  0.000000
# 69                  One Bedroom Vacancy %  0.000000
# 70               One Bedroom Vacant Units  0.000000
# 79                             PropertyID  0.000000
# 43                   Number Of 3 Bedrooms  0.000000
# 42                   Number Of 2 Bedrooms  0.000000
# 41                   Number Of 1 Bedrooms  0.000000
# 38               Number Of Parking Spaces  0.000000
# 2                        Property Address  0.000000
# 4                             Star Rating  0.000000
# 6                         Building Status  0.000000
# 8                             Market Name  0.000000
# 10                                   City  0.000000
# 11                                  State  0.000000
# 12                                    Zip  0.000000
# 13                            County Name  0.000000
# 19                        Number Of Units  0.000000
# 24                        Avg Asking/Unit  0.000000
# 25                          Avg Asking/SF  0.000000
# 26                     Avg Effective/Unit  0.000000
# 27                       Avg Effective/SF  0.000000
# 28                      Avg Concessions %  0.000000
# 29                              % Studios  0.000000
# 30                                % 1-Bed  0.000000
# 31                                % 2-Bed  0.000000
# 32                                % 3-Bed  0.000000
# 33                                % 4-Bed  0.000000
# 36                         Market Segment  0.000000
# 37                    Parking Spaces/Unit  0.000000
# 80                           PropertyType  0.000000
# 83                Studio Asking Rent/Unit  0.000000
# 143                 2019 HH Age 75-84(1m)  0.000000
# 131                2010 Pop Age 60-64(1m)  0.000000
# 121                      2010 Avg Age(1m)  0.000000
# 122                      2010 Med Age(1m)  0.000000
# 1                                  PropID  0.000000
# 124                2010 Pop Age 10-14(1m)  0.000000
# 125                2010 Pop Age 15-19(1m)  0.000000
# 126                2010 Pop Age 20-24(1m)  0.000000
# 127                2010 Pop Age 45-49(1m)  0.000000
# 128                2010 Pop Age 50-54(1m)  0.000000
# 129                2010 Pop Age 55-59(1m)  0.000000
# 130                  2010 Pop Age 5-9(1m)  0.000000
# 132                  2010 Pop Age 65+(1m)  0.000000
# 84                          Studio Avg SF  0.000000
# 133                  2010 Pop Age 85+(1m)  0.000000
# 134                      2019 Avg Age(1m)  0.000000
# 135         2019 Avg Age&#044; Female(1m)  0.000000
# 136           2019 Avg Age&#044; Male(1m)  0.000000
# 137                 2019 HH Age 15-24(1m)  0.000000
# 138                 2019 HH Age 25-34(1m)  0.000000
# 139                 2019 HH Age 35-44(1m)  0.000000
# 140                 2019 HH Age 45-54(1m)  0.000000
# 141                 2019 HH Age 55-64(1m)  0.000000
# 142                 2019 HH Age 65-74(1m)  0.000000
# 119                             Longitude  0.000000
# 118                              Latitude  0.000000
# 109                        Year Renovated  0.000000
# 107              Two Bedroom Vacant Units  0.000000
# 85                   Studio Concessions %  0.000000
# 86               Studio Effective Rent/SF  0.000000
# 87             Studio Effective Rent/Unit  0.000000
# 88                       Studio Vacancy %  0.000000
# 89                    Studio Vacant Units  0.000000
# 91           Three Bedroom Asking Rent/SF  0.000000
# 92         Three Bedroom Asking Rent/Unit  0.000000
# 93                   Three Bedroom Avg SF  0.000000
# 94            Three Bedroom Concessions %  0.000000
# 95        Three Bedroom Effective Rent/SF  0.000000
# 96      Three Bedroom Effective Rent/Unit  0.000000
# 97                Three Bedroom Vacancy %  0.000000
# 98             Three Bedroom Vacant Units  0.000000
# 99                        Total Buildings  0.000000
# 100            Two Bedroom Asking Rent/SF  0.000000
# 101          Two Bedroom Asking Rent/Unit  0.000000
# 102                    Two Bedroom Avg SF  0.000000
# 103             Two Bedroom Concessions %  0.000000
# 104         Two Bedroom Effective Rent/SF  0.000000
# 105       Two Bedroom Effective Rent/Unit  0.000000
# 106                 Two Bedroom Vacancy %  0.000000
# 246                             Clubhouse  0.000000

# %%
for key in df_na[df_na['values']>0.1]['key'].tolist():
    df.drop(columns=[key], inplace = True)

# %%
df_na = na_freq(df)
df_na
# Out:
#                                    key    values
# 13                     For Sale Status  0.083037
# 76                   Submarket Cluster  0.059011
# 8                       Submarket Name  0.059011
# 41      Closest Transit Stop Dist (mi)  0.056964
# 40                Closest Transit Stop  0.056964
# 14                      Land Area (AC)  0.054555
# 34                           Amenities  0.047631
# 186                          Situs_Num  0.023063
# 97                Owner City State Zip  0.012344
# 96                       Owner Address  0.010959
# 65              Property Manager Phone  0.010297
# 94                          Year Built  0.009273
# 99                Parcel Number 1(Min)  0.007828
# 100               Parcel Number 2(Max)  0.007828
# 61                          Owner Name  0.004998
# 62            Property Manager Address  0.004817
# 63     Property Manager City State Zip  0.004817
# 64               Property Manager Name  0.004697
# 16                               Style  0.004215
# 18                           Vacancy %  0.002288
# 30                           Rent Type  0.000482
# 19                         Avg Unit SF  0.000422
# 15                   Number Of Stories  0.000422
# 3                        Property Name  0.000361
# 98                                 RBA  0.000181
# 6                       Secondary Type  0.000060
# 159              2024 HH Age 55-64(1m)  0.000000
# 155              2024 HH Age 15-24(1m)  0.000000
# 156              2024 HH Age 25-34(1m)  0.000000
# 157              2024 HH Age 35-44(1m)  0.000000
# 158              2024 HH Age 45-54(1m)  0.000000
# 166               2024 Pop Age 0-4(1m)  0.000000
# 160              2024 HH Age 65-74(1m)  0.000000
# 161              2024 HH Age 75-84(1m)  0.000000
# 162                2024 HH Age 85+(1m)  0.000000
# 163                   2024 Med Age(1m)  0.000000
# 164             2024 Median HH Age(1m)  0.000000
# 165               2024 Pop Age <19(1m)  0.000000
# 167             2024 Pop Age 10-14(1m)  0.000000
# 168             2024 Pop Age 15-19(1m)  0.000000
# 169             2024 Pop Age 20-24(1m)  0.000000
# 170             2024 Pop Age 20-64(1m)  0.000000
# 171             2024 Pop Age 25-29(1m)  0.000000
# 172             2024 Pop Age 30-34(1m)  0.000000
# 154              2024 Avg Male Age(1m)  0.000000
# 152                   2024 Avg Age(1m)  0.000000
# 153            2024 Avg Female Age(1m)  0.000000
# 174             2024 Pop Age 40-44(1m)  0.000000
# 129        2019 Med Age&#044; Male(1m)  0.000000
# 130             2019 Median HH Age(1m)  0.000000
# 131               2019 Pop Age <19(1m)  0.000000
# 132               2019 Pop Age 0-4(1m)  0.000000
# 133             2019 Pop Age 10-14(1m)  0.000000
# 134             2019 Pop Age 15-19(1m)  0.000000
# 135             2019 Pop Age 20-24(1m)  0.000000
# 136             2019 Pop Age 20-64(1m)  0.000000
# 137             2019 Pop Age 25-29(1m)  0.000000
# 138             2019 Pop Age 30-34(1m)  0.000000
# 139             2019 Pop Age 35-39(1m)  0.000000
# 140             2019 Pop Age 40-44(1m)  0.000000
# 141             2019 Pop Age 45-49(1m)  0.000000
# 142             2019 Pop Age 50-54(1m)  0.000000
# 143             2019 Pop Age 55-59(1m)  0.000000
# 144               2019 Pop Age 5-9(1m)  0.000000
# 145             2019 Pop Age 60-64(1m)  0.000000
# 146               2019 Pop Age 65+(1m)  0.000000
# 147             2019 Pop Age 65-69(1m)  0.000000
# 148             2019 Pop Age 70-74(1m)  0.000000
# 149             2019 Pop Age 75-79(1m)  0.000000
# 150             2019 Pop Age 80-84(1m)  0.000000
# 151               2019 Pop Age 85+(1m)  0.000000
# 173             2024 Pop Age 35-39(1m)  0.000000
# 0                                  Row  0.000000
# 175             2024 Pop Age 45-49(1m)  0.000000
# 202              Walking/Biking Trails  0.000000
# 204                  Controlled Access  0.000000
# 205                             Lounge  0.000000
# 206                 Laundry Facilities  0.000000
# 207                    Business Center  0.000000
# 208                           Gameroom  0.000000
# 209                              Gated  0.000000
# 210                        Picnic Area  0.000000
# 211                      Car Wash Area  0.000000
# 212                           Elevator  0.000000
# 213                         Playground  0.000000
# 214                   Volleyball Court  0.000000
# 215                               Pool  0.000000
# 216                                Spa  0.000000
# 217                     24 Hour Access  0.000000
# 218                     Fitness Center  0.000000
# 219                    Package Service  0.000000
# 220                          Courtyard  0.000000
# 221                              Wi-Fi  0.000000
# 222                          Recycling  0.000000
# 223         Breakfast/Coffee Concierge  0.000000
# 224                    Laundry Service  0.000000
# 225          Planned Social Activities  0.000000
# 226                      Pet Play Area  0.000000
# 203                       Tennis Court  0.000000
# 201                      Storage Space  0.000000
# 176             2024 Pop Age 50-54(1m)  0.000000
# 200                Maintenance on site  0.000000
# 177             2024 Pop Age 55-59(1m)  0.000000
# 178               2024 Pop Age 5-9(1m)  0.000000
# 179             2024 Pop Age 60-64(1m)  0.000000
# 180               2024 Pop Age 65+(1m)  0.000000
# 127                   2019 Med Age(1m)  0.000000
# 181             2024 Pop Age 65-69(1m)  0.000000
# 182             2024 Pop Age 70-74(1m)  0.000000
# 183             2024 Pop Age 75-79(1m)  0.000000
# 184             2024 Pop Age 80-84(1m)  0.000000
# 185               2024 Pop Age 85+(1m)  0.000000
# 187                Situs_Num_Remainder  0.000000
# 188                          SITUS_NAM  0.000000
# 189                                SCP  0.000000
# 190                     SCSitus_NumNam  0.000000
# 191                              SCAPN  0.000000
# 192                              Grill  0.000000
# 193                          Concierge  0.000000
# 194                            Sundeck  0.000000
# 195          Furnished Units Available  0.000000
# 196         Media Center/Movie Theatre  0.000000
# 197                             Cabana  0.000000
# 198           Property Manager on Site  0.000000
# 199                   Basketball Court  0.000000
# 128      2019 Med Age&#044; Female(1m)  0.000000
# 114               2010 Pop Age 65+(1m)  0.000000
# 126                2019 HH Age 85+(1m)  0.000000
# 50              Four Bedroom Vacancy %  0.000000
# 38                Number Of 4 Bedrooms  0.000000
# 39                      Building Class  0.000000
# 42               Construction Material  0.000000
# 43                            Features  0.000000
# 44         Four Bedroom Asking Rent/SF  0.000000
# 45       Four Bedroom Asking Rent/Unit  0.000000
# 46                 Four Bedroom Avg SF  0.000000
# 47          Four Bedroom Concessions %  0.000000
# 48      Four Bedroom Effective Rent/SF  0.000000
# 49    Four Bedroom Effective Rent/Unit  0.000000
# 51           Four Bedroom Vacant Units  0.000000
# 68               Studio Asking Rent/SF  0.000000
# 52                   Number Of Studios  0.000000
# 53          One Bedroom Asking Rent/SF  0.000000
# 54        One Bedroom Asking Rent/Unit  0.000000
# 55                  One Bedroom Avg SF  0.000000
# 56           One Bedroom Concessions %  0.000000
# 57       One Bedroom Effective Rent/SF  0.000000
# 58     One Bedroom Effective Rent/Unit  0.000000
# 59               One Bedroom Vacancy %  0.000000
# 60            One Bedroom Vacant Units  0.000000
# 66                          PropertyID  0.000000
# 37                Number Of 3 Bedrooms  0.000000
# 36                Number Of 2 Bedrooms  0.000000
# 35                Number Of 1 Bedrooms  0.000000
# 33            Number Of Parking Spaces  0.000000
# 2                     Property Address  0.000000
# 4                          Star Rating  0.000000
# 5                      Building Status  0.000000
# 7                          Market Name  0.000000
# 9                                 City  0.000000
# 10                               State  0.000000
# 11                                 Zip  0.000000
# 12                         County Name  0.000000
# 17                     Number Of Units  0.000000
# 20                     Avg Asking/Unit  0.000000
# 21                       Avg Asking/SF  0.000000
# 22                  Avg Effective/Unit  0.000000
# 23                    Avg Effective/SF  0.000000
# 24                   Avg Concessions %  0.000000
# 25                           % Studios  0.000000
# 26                             % 1-Bed  0.000000
# 27                             % 2-Bed  0.000000
# 28                             % 3-Bed  0.000000
# 29                             % 4-Bed  0.000000
# 31                      Market Segment  0.000000
# 32                 Parking Spaces/Unit  0.000000
# 67                        PropertyType  0.000000
# 69             Studio Asking Rent/Unit  0.000000
# 125              2019 HH Age 75-84(1m)  0.000000
# 113             2010 Pop Age 60-64(1m)  0.000000
# 103                   2010 Avg Age(1m)  0.000000
# 104                   2010 Med Age(1m)  0.000000
# 105               2010 Pop Age 0-4(1m)  0.000000
# 106             2010 Pop Age 10-14(1m)  0.000000
# 107             2010 Pop Age 15-19(1m)  0.000000
# 108             2010 Pop Age 20-24(1m)  0.000000
# 109             2010 Pop Age 45-49(1m)  0.000000
# 110             2010 Pop Age 50-54(1m)  0.000000
# 111             2010 Pop Age 55-59(1m)  0.000000
# 112               2010 Pop Age 5-9(1m)  0.000000
# 1                               PropID  0.000000
# 70                       Studio Avg SF  0.000000
# 115               2010 Pop Age 85+(1m)  0.000000
# 116                   2019 Avg Age(1m)  0.000000
# 117      2019 Avg Age&#044; Female(1m)  0.000000
# 118        2019 Avg Age&#044; Male(1m)  0.000000
# 119              2019 HH Age 15-24(1m)  0.000000
# 120              2019 HH Age 25-34(1m)  0.000000
# 121              2019 HH Age 35-44(1m)  0.000000
# 122              2019 HH Age 45-54(1m)  0.000000
# 123              2019 HH Age 55-64(1m)  0.000000
# 124              2019 HH Age 65-74(1m)  0.000000
# 102                          Longitude  0.000000
# 101                           Latitude  0.000000
# 95                      Year Renovated  0.000000
# 93            Two Bedroom Vacant Units  0.000000
# 71                Studio Concessions %  0.000000
# 72            Studio Effective Rent/SF  0.000000
# 73          Studio Effective Rent/Unit  0.000000
# 74                    Studio Vacancy %  0.000000
# 75                 Studio Vacant Units  0.000000
# 77        Three Bedroom Asking Rent/SF  0.000000
# 78      Three Bedroom Asking Rent/Unit  0.000000
# 79                Three Bedroom Avg SF  0.000000
# 80         Three Bedroom Concessions %  0.000000
# 81     Three Bedroom Effective Rent/SF  0.000000
# 82   Three Bedroom Effective Rent/Unit  0.000000
# 83             Three Bedroom Vacancy %  0.000000
# 84          Three Bedroom Vacant Units  0.000000
# 85                     Total Buildings  0.000000
# 86          Two Bedroom Asking Rent/SF  0.000000
# 87        Two Bedroom Asking Rent/Unit  0.000000
# 88                  Two Bedroom Avg SF  0.000000
# 89           Two Bedroom Concessions %  0.000000
# 90       Two Bedroom Effective Rent/SF  0.000000
# 91     Two Bedroom Effective Rent/Unit  0.000000
# 92               Two Bedroom Vacancy %  0.000000
# 227                          Clubhouse  0.000000

# %% [markdown]
# Year Built, Construction Material, Features, Star Rating, Owner Name, Owner Address, Number Of Stories, Land Area (AC),

# %%
df.head()
# Out:
#    Row PropID      Property Address                    Property Name  \
# 0    1     P1  6215 Johns Creek Cmn  The Reserve at Johns Creek Walk
# 3    4     P4        250 10th St NE                Post Parkside ATL
# 4    5     P5        100 10th St NW                      100 Midtown
# 5    6     P6        150 NE 10th St          Juniper & 10th Highrise
# 6    7     P7      48-80 12th St NE   Twelfth Street West Apartments
#
#    Star Rating Building Status Secondary Type Market Name  \
# 0            4        Existing     Apartments     Atlanta
# 3            4        Existing     Apartments     Atlanta
# 4            3        Existing     Apartments     Atlanta
# 5            2        Existing     Apartments     Atlanta
# 6            2        Existing     Apartments     Atlanta
#
#               Submarket Name         City State    Zip County Name  \
# 0  Outlying Fulton County MF  Johns Creek    GA  30097      Fulton
# 3           Piedmont Park MF      Atlanta    GA  30309      Fulton
# 4         Central Midtown MF      Atlanta    GA  30309      Fulton
# 5         Central Midtown MF      Atlanta    GA  30309      Fulton
# 6         Central Midtown MF      Atlanta    GA  30309      Fulton
#
#   For Sale Status  Land Area (AC)  Number Of Stories     Style  \
# 0               N          8.9600                3.0    Garden
# 3               N          1.5700                4.0  Mid-Rise
# 4               N             NaN                9.0  Mid-Rise
# 5               N          0.6576               14.0  Mid-Rise
# 6               N          1.4653                2.0  Low-Rise
#
#    Number Of Units  Vacancy %  Avg Unit SF Avg Asking/Unit  Avg Asking/SF  \
# 0              210       4.29       1157.0           1,708           1.48
# 3              188       4.79        942.0           1,975           2.12
# 4              118      11.02       1068.0           2,278           2.13
# 5              149       6.71        619.0             643           1.04
# 6              129       8.63        483.0             788           1.63
#
#   Avg Effective/Unit  Avg Effective/SF  Avg Concessions %  % Studios  % 1-Bed  \
# 0              1,684              1.46                1.4       0.00    35.71
# 3              1,963              2.11                0.6      32.45    45.21
# 4              2,256              2.11                1.0       0.00     0.00
# 5                638              1.03                0.8      58.39    41.61
# 6                786              1.63                0.2      61.24    38.76
#
#    % 2-Bed  % 3-Bed % 4-Bed   Rent Type Market Segment  Parking Spaces/Unit  \
# 0    46.67    17.62       0      Market            All                1.095
# 3    22.34     0.00       0      Market            All                1.223
# 4    61.02     0.00  38.98%      Market        Student                0.847
# 5     0.00     0.00       0  Affordable         Senior                0.336
# 6     0.00     0.00       0      Market            All                0.093
#
#    Number Of Parking Spaces  \
# 0                     230.0
# 3                     230.0
# 4                     100.0
# 5                      50.0
# 6                      12.0
#
#                                            Amenities  Number Of 1 Bedrooms  \
# 0  Business Center, Controlled Access, Clubhouse,...                  75.0
# 3  Business Center, Controlled Access, Courtyard,...                  85.0
# 4  24 Hour Access, Business Center, Laundry Facil...                   0.0
# 5  Clubhouse, Fitness Center, Laundry Facilities,...                  62.0
# 6  Controlled Access, Laundry Facilities, Propert...                  50.0
#
#    Number Of 2 Bedrooms  Number Of 3 Bedrooms  Number Of 4 Bedrooms  \
# 0                  98.0                  37.0                   0.0
# 3                  42.0                   0.0                   0.0
# 4                  72.0                   0.0                  46.0
# 5                   0.0                   0.0                   0.0
# 6                   0.0                   0.0                   0.0
#
#   Building Class                      Closest Transit Stop  \
# 0              A  Hartsfield-Jackson Atlanta International
# 3              B                                   Midtown
# 4              B                                   Midtown
# 5              C                                   Midtown
# 6              C                                   Midtown
#
#    Closest Transit Stop Dist (mi) Construction Material  \
# 0                          39.485               Masonry
# 3                           0.450               Masonry
# 4                           0.300   Reinforced Concrete
# 5                           0.270                 Steel
# 6                           0.440               Masonry
#
#                                             Features  \
# 0  Business Center, Controlled Access, Clubhouse,...
# 3  Business Center, Controlled Access, Courtyard,...
# 4  24 Hour Access, Business Center, Laundry Facil...
# 5  Clubhouse, Fitness Center, Laundry Facilities,...
# 6  Controlled Access, Laundry Facilities, Propert...
#
#    Four Bedroom Asking Rent/SF Four Bedroom Asking Rent/Unit  \
# 0                         0.00                             0
# 3                         0.00                             0
# 4                         2.48                         3,299
# 5                         0.00                             0
# 6                         0.00                             0
#
#    Four Bedroom Avg SF  Four Bedroom Concessions %  \
# 0                  0.0                         0.0
# 3                  0.0                         0.0
# 4               1330.0                         1.0
# 5                  0.0                         0.0
# 6                  0.0                         0.0
#
#    Four Bedroom Effective Rent/SF Four Bedroom Effective Rent/Unit  \
# 0                            0.00                                0
# 3                            0.00                                0
# 4                            2.46                            3,266
# 5                            0.00                                0
# 6                            0.00                                0
#
#    Four Bedroom Vacancy %  Four Bedroom Vacant Units  Number Of Studios  \
# 0                     0.0                        0.0                0.0
# 3                     0.0                        0.0               61.0
# 4                    10.9                        5.0                0.0
# 5                     0.0                        0.0               87.0
# 6                     0.0                        0.0               79.0
#
#    One Bedroom Asking Rent/SF One Bedroom Asking Rent/Unit  \
# 0                        1.44                        1,314
# 3                        2.06                        1,795
# 4                        0.00                            0
# 5                        0.95                          643
# 6                        1.54                          846
#
#    One Bedroom Avg SF  One Bedroom Concessions %  \
# 0               914.0                        0.5
# 3               870.0                        0.6
# 4                 0.0                        0.0
# 5               676.0                        0.8
# 6               550.0                        0.3
#
#    One Bedroom Effective Rent/SF One Bedroom Effective Rent/Unit  \
# 0                           1.43                           1,307
# 3                           2.05                           1,784
# 4                           0.00                               0
# 5                           0.94                             638
# 6                           1.53                             844
#
#    One Bedroom Vacancy %  One Bedroom Vacant Units  \
# 0                    4.0                       3.0
# 3                    4.7                       4.0
# 4                    0.0                       0.0
# 5                    6.5                       4.0
# 6                    0.0                       0.0
#
#                                        Owner Name Property Manager Address  \
# 0  Jones Lang LaSalle Income Property Trust, Inc.     6215 Johns Creek Cmn
# 3         Mid-America Apartment Communities, Inc.              250 10th St
# 4                        The Pierce Company, Inc.           100 10th St NW
# 5    The Housing Authority of the City of Atlanta           150 NE 10th St
# 6                                Selig Realty Inc               60 12TH St
#
#   Property Manager City State Zip  \
# 0       Johns Creek, GA 300971535
# 3           Atlanta, GA 30309
# 4               Atlanta, GA 30309
# 5           Atlanta, GA 303094021
# 6               ATLANTA, GA 30309
#
#                             Property Manager Name  Property Manager Phone  \
# 0      Carter Haston- Reserve at Johns Creek Walk            6.784754e+09
# 3                             MAA - Post Parkside            4.048178e+09
# 4  Pierce Education Prop - 100 Midtown Apartments            4.049617e+09
# 5              Columbia - Juniper & 10th Highrise            4.042491e+09
# 6          Habersham - Twelfth St West Apartments            4.048748e+09
#
#    PropertyID  PropertyType  Studio Asking Rent/SF Studio Asking Rent/Unit  \
# 0     6400737  Multi-Family                   0.00                       0
# 3     6897678  Multi-Family                   2.28                   1,748
# 4     6865125  Multi-Family                   0.00                       0
# 5     6900122  Multi-Family                   1.11                     643
# 6     6900121  Multi-Family                   1.71                     751
#
#    Studio Avg SF  Studio Concessions %  Studio Effective Rent/SF  \
# 0            0.0                   0.0                      0.00
# 3          765.0                   0.6                      2.27
# 4            0.0                   0.0                      0.00
# 5          578.0                   0.8                      1.10
# 6          440.0                   0.2                      1.70
#
#   Studio Effective Rent/Unit  Studio Vacancy %  Studio Vacant Units  \
# 0                          0               0.0                  0.0
# 3                      1,737               4.9                  3.0
# 4                          0               0.0                  0.0
# 5                        638               6.9                  6.0
# 6                        749               0.0                  0.0
#
#     Submarket Cluster  Three Bedroom Asking Rent/SF  \
# 0     North Fulton MF                          1.26
# 3  Midtown Atlanta MF                          0.00
# 4  Midtown Atlanta MF                          0.00
# 5  Midtown Atlanta MF                          0.00
# 6  Midtown Atlanta MF                          0.00
#
#   Three Bedroom Asking Rent/Unit  Three Bedroom Avg SF  \
# 0                          2,021                1602.0
# 3                              0                   0.0
# 4                              0                   0.0
# 5                              0                   0.0
# 6                              0                   0.0
#
#    Three Bedroom Concessions %  Three Bedroom Effective Rent/SF  \
# 0                          0.7                             1.25
# 3                          0.0                             0.00
# 4                          0.0                             0.00
# 5                          0.0                             0.00
# 6                          0.0                             0.00
#
#   Three Bedroom Effective Rent/Unit  Three Bedroom Vacancy %  \
# 0                             2,008                      5.4
# 3                                 0                      0.0
# 4                                 0                      0.0
# 5                                 0                      0.0
# 6                                 0                      0.0
#
#    Three Bedroom Vacant Units  Total Buildings  Two Bedroom Asking Rent/SF  \
# 0                         2.0              7.0                        1.61
# 3                         0.0              3.0                        2.08
# 4                         0.0              1.0                        1.81
# 5                         0.0              1.0                        0.00
# 6                         0.0              2.0                        0.00
#
#   Two Bedroom Asking Rent/Unit  Two Bedroom Avg SF  Two Bedroom Concessions %  \
# 0                        1,891              1175.0                        2.2
# 3                        2,685              1291.0                        0.6
# 4                        1,626               900.0                        1.0
# 5                            0                 0.0                        0.0
# 6                            0                 0.0                        0.0
#
#    Two Bedroom Effective Rent/SF Two Bedroom Effective Rent/Unit  \
# 0                           1.57                           1,850
# 3                           2.07                           2,668
# 4                           1.79                           1,610
# 5                           0.00                               0
# 6                           0.00                               0
#
#    Two Bedroom Vacancy %  Two Bedroom Vacant Units  Year Built  \
# 0                    4.1                       4.0      2006.0
# 3                    4.8                       2.0      1999.0
# 4                   11.1                       8.0      1968.0
# 5                    0.0                       0.0      1974.0
# 6                    0.0                       0.0      1959.0
#
#    Year Renovated                      Owner Address  \
# 0            -1.0       333 W Wacker Dr Suite # 2300
# 3            -1.0        6815 Poplar Ave Suite # 500
# 4            -1.0  8880 Rio San Diego Dr Suite # 750
# 5            -1.0       230 John Wesley Dobbs Ave NE
# 6            -1.0      1100 Spring St NW Suite # 550
#
#        Owner City State Zip     RBA Parcel Number 1(Min) Parcel Number 2(Max)  \
# 0     Chicago, IL 606061220  260872     11-1000-0359-034   11-1000-0359-034-1
# 3  Germantown, TN 381383606  243660   17-0106-0009-120-4   17-0106-0009-120-4
# 4   San Diego, CA 921081634  375662   17-0107-0006-060-4   17-0107-0006-060-4
# 5     Atlanta, GA 30303      107338   17-0106-0009-118-8   17-0106-0009-118-8
# 6     Atlanta, GA 303092846   60520   17-0106-0004-032-6   17-0106-0004-091-2
#
#     Latitude  Longitude  2010 Avg Age(1m)  2010 Med Age(1m)  \
# 0  34.050153 -84.178580              32.4              36.4
# 3  33.782037 -84.378623              35.1              32.4
# 4  33.780993 -84.390389              31.2              27.6
# 5  33.782011 -84.382180              34.6              31.6
# 6  33.784842 -84.385122              33.6              30.3
#
#    2010 Pop Age 0-4(1m)  2010 Pop Age 10-14(1m)  2010 Pop Age 15-19(1m)  \
# 0                 891.0                  1555.0                  1266.0
# 3                 842.0                   366.0                  1668.0
# 4                 503.0                   247.0                  3326.0
# 5                 614.0                   274.0                  1785.0
# 6                 488.0                   259.0                  2003.0
#
#    2010 Pop Age 20-24(1m)  2010 Pop Age 45-49(1m)  2010 Pop Age 50-54(1m)  \
# 0                   469.0                  1573.0                  1177.0
# 3                  4039.0                  1805.0                  1437.0
# 4                  8641.0                  1479.0                  1194.0
# 5                  4576.0                  1664.0                  1324.0
# 6                  5106.0                  1503.0                  1204.0
#
#    2010 Pop Age 55-59(1m)  2010 Pop Age 5-9(1m)  2010 Pop Age 60-64(1m)  \
# 0                   684.0                1335.0                   428.0
# 3                  1237.0                 485.0                  1043.0
# 4                   894.0                 274.0                   721.0
# 5                  1151.0                 335.0                   966.0
# 6                   937.0                 318.0                   801.0
#
#    2010 Pop Age 65+(1m)  2010 Pop Age 85+(1m)  2019 Avg Age(1m)  \
# 0                 549.0                  47.0              35.5
# 3                1556.0                 154.0              36.4
# 4                1005.0                  82.0              33.4
# 5                1408.0                 122.0              36.0
# 6                1152.0                 101.0              35.2
#
#    2019 Avg Age&#044; Female(1m)  2019 Avg Age&#044; Male(1m)  \
# 0                           36.3                         34.5
# 3                           35.4                         37.2
# 4                           32.5                         34.1
# 5                           34.9                         36.7
# 6                           34.1                         35.9
#
#    2019 HH Age 15-24(1m)  2019 HH Age 25-34(1m)  2019 HH Age 35-44(1m)  \
# 0                  380.0                  844.0                  988.0
# 3                  493.0                 4963.0                 5478.0
# 4                  714.0                 6137.0                 5630.0
# 5                  497.0                 5021.0                 5395.0
# 6                  544.0                 5211.0                 5332.0
#
#    2019 HH Age 45-54(1m)  2019 HH Age 55-64(1m)  2019 HH Age 65-74(1m)  \
# 0                 1712.0                 1300.0                  548.0
# 3                 4078.0                 2638.0                 1557.0
# 4                 3774.0                 2258.0                 1213.0
# 5                 3904.0                 2492.0                 1471.0
# 6                 3743.0                 2280.0                 1270.0
#
#    2019 HH Age 75-84(1m)  2019 HH Age 85+(1m)  2019 Med Age(1m)  \
# 0                  172.0                 50.0              35.5
# 3                  603.0                188.0              36.1
# 4                  442.0                127.0              32.7
# 5                  569.0                168.0              35.5
# 6                  476.0                139.0              34.6
#
#    2019 Med Age&#044; Female(1m)  2019 Med Age&#044; Male(1m)  \
# 0                           38.1                         32.2
# 3                           34.6                         37.3
# 4                           31.9                         33.2
# 5                           34.2                         36.6
# 6                           33.5                         35.6
#
#    2019 Median HH Age(1m)  2019 Pop Age <19(1m)  2019 Pop Age 0-4(1m)  \
# 0                    49.6                5179.0                 876.0
# 3                    43.3                5858.0                2266.0
# 4                    40.9                6930.0                2844.0
# 5                    42.9                5684.0                2295.0
# 6                    42.0                5714.0                2330.0
#
#    2019 Pop Age 10-14(1m)  2019 Pop Age 15-19(1m)  2019 Pop Age 20-24(1m)  \
# 0                  1442.0                  1808.0                  1640.0
# 3                   989.0                   927.0                  1976.0
# 4                   960.0                  1224.0                  3647.0
# 5                   889.0                   872.0                  2126.0
# 6                   862.0                   905.0                  2356.0
#
#    2019 Pop Age 20-64(1m)  2019 Pop Age 25-29(1m)  2019 Pop Age 30-34(1m)  \
# 0                 11539.0                  1297.0                   812.0
# 3                 26356.0                  4123.0                  4546.0
# 4                 32682.0                  6849.0                  6295.0
# 5                 26979.0                  4485.0                  4852.0
# 6                 27268.0                  4830.0                  5020.0
#
#    2019 Pop Age 35-39(1m)  2019 Pop Age 40-44(1m)  2019 Pop Age 45-49(1m)  \
# 0                   847.0                  1175.0                  1666.0
# 3                  4103.0                  3284.0                  2906.0
# 4                  4840.0                  3441.0                  2804.0
# 5                  4259.0                  3300.0                  2829.0
# 6                  4276.0                  3247.0                  2740.0
#
#    2019 Pop Age 50-54(1m)  2019 Pop Age 55-59(1m)  2019 Pop Age 5-9(1m)  \
# 0                  1679.0                  1440.0                1053.0
# 3                  2231.0                  1807.0                1676.0
# 4                  2050.0                  1599.0                1902.0
# 5                  2125.0                  1706.0                1628.0
# 6                  2031.0                  1596.0                1617.0
#
#    2019 Pop Age 60-64(1m)  2019 Pop Age 65+(1m)  2019 Pop Age 65-69(1m)  \
# 0                   983.0                1319.0                   616.0
# 3                  1380.0                2630.0                  1065.0
# 4                  1157.0                1997.0                   846.0
# 5                  1297.0                2463.0                  1002.0
# 6                  1172.0                2135.0                   881.0
#
#    2019 Pop Age 70-74(1m)  2019 Pop Age 75-79(1m)  2019 Pop Age 80-84(1m)  \
# 0                   343.0                   183.0                    95.0
# 3                   718.0                   420.0                   222.0
# 4                   547.0                   308.0                   158.0
# 5                   677.0                   396.0                   206.0
# 6                   588.0                   338.0                   174.0
#
#    2019 Pop Age 85+(1m)  2024 Avg Age(1m)  2024 Avg Female Age(1m)  \
# 0                  82.0              37.1                     38.1
# 3                 205.0              38.0                     36.7
# 4                 138.0              35.2                     33.9
# 5                 182.0              37.6                     36.3
# 6                 154.0              36.9                     35.4
#
#    2024 Avg Male Age(1m)  2024 HH Age 15-24(1m)  2024 HH Age 25-34(1m)  \
# 0                   36.0                  366.0                 1103.0
# 3                   39.0                  381.0                 3382.0
# 4                   36.2                  443.0                 4297.0
# 5                   38.6                  362.0                 3417.0
# 6                   37.9                  374.0                 3591.0
#
#    2024 HH Age 35-44(1m)  2024 HH Age 45-54(1m)  2024 HH Age 55-64(1m)  \
# 0                  928.0                 1384.0                 1488.0
# 3                 5958.0                 5079.0                 3447.0
# 4                 6615.0                 4986.0                 3112.0
# 5                 5951.0                 4949.0                 3292.0
# 6                 6013.0                 4841.0                 3109.0
#
#    2024 HH Age 65-74(1m)  2024 HH Age 75-84(1m)  2024 HH Age 85+(1m)  \
# 0                  855.0                  305.0                 78.0
# 3                 2088.0                  964.0                292.0
# 4                 1734.0                  746.0                210.0
# 5                 1981.0                  916.0                273.0
# 6                 1772.0                  788.0                227.0
#
#    2024 Med Age(1m)  2024 Median HH Age(1m)  2024 Pop Age <19(1m)  \
# 0              35.9                    51.2                5007.0
# 3              39.2                    47.1                7752.0
# 4              36.2                    44.6                9531.0
# 5              38.8                    46.7                7727.0
# 6              38.0                    45.8                7849.0
#
#    2024 Pop Age 0-4(1m)  2024 Pop Age 10-14(1m)  2024 Pop Age 15-19(1m)  \
# 0                1214.0                  1202.0                  1509.0
# 3                2584.0                  1684.0                  1210.0
# 4                3400.0                  1931.0                  1367.0
# 5                2644.0                  1644.0                  1145.0
# 6                2726.0                  1644.0                  1145.0
#
#    2024 Pop Age 20-24(1m)  2024 Pop Age 20-64(1m)  2024 Pop Age 25-29(1m)  \
# 0                  1695.0                 12305.0                  1609.0
# 3                  1337.0                 26245.0                  2439.0
# 4                  1983.0                 32676.0                  4014.0
# 5                  1341.0                 26869.0                  2602.0
# 6                  1421.0                 27293.0                  2810.0
#
#    2024 Pop Age 30-34(1m)  2024 Pop Age 35-39(1m)  2024 Pop Age 40-44(1m)  \
# 0                  1281.0                  1004.0                  1003.0
# 3                  3712.0                  4264.0                  4025.0
# 4                  5680.0                  5799.0                  4840.0
# 5                  3984.0                  4515.0                  4168.0
# 6                  4227.0                  4671.0                  4211.0
#
#    2024 Pop Age 45-49(1m)  2024 Pop Age 50-54(1m)  2024 Pop Age 55-59(1m)  \
# 0                  1277.0                  1538.0                  1567.0
# 3                  3480.0                  2880.0                  2307.0
# 4                  3747.0                  2852.0                  2157.0
# 5                  3507.0                  2826.0                  2218.0
# 6                  3475.0                  2753.0                  2125.0
#
#    2024 Pop Age 5-9(1m)  2024 Pop Age 60-64(1m)  2024 Pop Age 65+(1m)  \
# 0                1082.0                  1331.0                2226.0
# 3                2274.0                  1801.0                3703.0
# 4                2833.0                  1604.0                2979.0
# 5                2294.0                  1708.0                3488.0
# 6                2334.0                  1600.0                3100.0
#
#    2024 Pop Age 65-69(1m)  2024 Pop Age 70-74(1m)  2024 Pop Age 75-79(1m)  \
# 0                   963.0                   609.0                   344.0
# 3                  1372.0                   994.0                   654.0
# 4                  1165.0                   805.0                   508.0
# 5                  1295.0                   937.0                   617.0
# 6                  1180.0                   834.0                   539.0
#
#    2024 Pop Age 80-84(1m)  2024 Pop Age 85+(1m)  Situs_Num  \
# 0                   176.0                 134.0     6215.0
# 3                   370.0                 313.0      250.0
# 4                   279.0                 222.0      100.0
# 5                   349.0                 290.0      150.0
# 6                   302.0                 245.0        NaN
#
#   Situs_Num_Remainder          SITUS_NAM  \
# 0     Johns Creek Cmn  Johns Creek Cmn
# 3          10th St NE           10th St
# 4          10th St NW           10th St
# 5          NE 10th St           10th St
# 6    48-80 12th St NE     48-80 12th St
#
#                                          SCP                 SCSitus_NumNam  \
# 0  GA Fulton The Reserve at Johns Creek Walk  GA Fulton6215 Johns Creek Cmn
# 3                GA Fulton Post Parkside ATL           GA Fulton250 10th St
# 4                      GA Fulton 100 Midtown           GA Fulton100 10th St
# 5          GA Fulton Juniper & 10th Highrise           GA Fulton150 10th St
# 6   GA Fulton Twelfth Street West Apartments        GA Fulton 48-80 12th St
#
#                           SCAPN  Grill  Concierge  Sundeck  \
# 0    GA Fulton 11-1000-0359-034      1          0        1
# 3  GA Fulton 17-0106-0009-120-4      1          0        0
# 4  GA Fulton 17-0107-0006-060-4      0          0        0
# 5  GA Fulton 17-0106-0009-118-8      0          0        0
# 6  GA Fulton 17-0106-0004-032-6      0          0        0
#
#    Furnished Units Available  Media Center/Movie Theatre  Cabana  \
# 0                          0                           0       1
# 3                          0                           0       0
# 4                          0                           1       0
# 5                          0                           1       0
# 6                          0                           0       0
#
#    Property Manager on Site  Basketball Court  Maintenance on site  \
# 0                         1                 0                    1
# 3                         0                 0                    0
# 4                         0                 1                    0
# 5                         1                 0                    0
# 6                         1                 0                    0
#
#    Storage Space  Walking/Biking Trails  Tennis Court  Controlled Access  \
# 0              0                      0             0                  1
# 3              0                      0             0                  1
# 4              1                      0             0                  0
# 5              0                      0             0                  0
# 6              0                      0             0                  1
#
#    Lounge  Laundry Facilities  Business Center  Gameroom  Gated  Picnic Area  \
# 0       1                   1                1         0      0            0
# 3       0                   1                1         0      1            1
# 4       1                   1                1         0      0            0
# 5       0                   1                0         0      0            0
# 6       0                   1                0         0      0            0
#
#    Car Wash Area  Elevator  Playground  Volleyball Court  Pool  Spa  \
# 0              0         0           1                 0     0    0
# 3              0         0           0                 0     0    0
# 4              0         0           0                 0     0    1
# 5              0         0           0                 0     0    0
# 6              0         0           0                 0     0    0
#
#    24 Hour Access  Fitness Center  Package Service  Courtyard  Wi-Fi  \
# 0               0               1                1          0      0
# 3               0               1                0          1      0
# 4               1               0                0          0      0
# 5               0               1                0          0      0
# 6               0               0                0          0      0
#
#    Recycling  Breakfast/Coffee Concierge  Laundry Service  \
# 0          1                           0                0
# 3          0                           0                0
# 4          0                           0                0
# 5          0                           0                0
# 6          0                           0                1
#
#    Planned Social Activities  Pet Play Area  Clubhouse
# 0                          0              0          1
# 3                          0              0          0
# 4                          0              0          0
# 5                          0              0          1
# 6                          0              0          0

# %%
df.to_csv('Cleaned Property Data Compiled.csv', index = False)

# %% [markdown]
# profile = df.profile_report(title='Pandas Profiling Report')
# profile.to_file(output_file="Properties.html")

# %%
df.drop(columns=['Row', 'PropID', 'Property Address', 'Property Name', 'Avg Asking/SF', 'Avg Asking/Unit', 'Avg Effective/Unit',
                    'Four Bedroom Asking Rent/SF', 'Four Bedroom Asking Rent/Unit', 'Four Bedroom Effective Rent/SF',
                    'Four Bedroom Effective Rent/Unit', 'One Bedroom Asking Rent/SF', 'One Bedroom Asking Rent/Unit', 'One Bedroom Effective Rent/SF',
                    'One Bedroom Effective Rent/Unit', 'PropertyID', 'Studio Asking Rent/SF', 'Studio Asking Rent/Unit', 'Studio Effective Rent/SF',
                    'Studio Effective Rent/Unit', 'Three Bedroom Asking Rent/SF', 'Three Bedroom Asking Rent/Unit', 'Three Bedroom Effective Rent/SF',
                    'Three Bedroom Effective Rent/Unit', 'Two Bedroom Asking Rent/SF', 'Two Bedroom Asking Rent/Unit', 'Two Bedroom Effective Rent/SF',
                    'Two Bedroom Asking Rent/Unit', 'Two Bedroom Effective Rent/SF', 'Two Bedroom Effective Rent/Unit', 'SCP',
                    'SCSitus_NumNam', 'SCAPN', '2010 Pop Age 20-24(1m)', '2010 Pop Age 45-49(1m)', '2010 Pop Age 50-54(1m)', '2010 Pop Age 55-59(1m)',
                     '2010 Pop Age 60-64(1m)', '2010 Pop Age 65+(1m)', '2010 Pop Age 85+(1m)', '2019 Avg Age&#044; Male(1m)', '2019 HH Age 25-34(1m)', '2019 HH Age 35-44(1m)', 
                     '2019 HH Age 45-54(1m)', '2019 HH Age 55-64(1m)', '2019 HH Age 65-74(1m)', '2019 HH Age 75-84(1m)', '2019 HH Age 85+(1m)',
                    '2019 Med Age&#044; Male(1m)', '2019 Pop Age 0-4(1m)', '2019 Pop Age 20-24(1m)', '2019 Pop Age 20-64(1m)', '2019 Pop Age 25-29(1m)',
                     '2019 Pop Age 30-34(1m)', '2019 Pop Age 35-39(1m)', '2019 Pop Age 40-44(1m)','2019 Pop Age 45-49(1m)', '2019 Pop Age 50-54(1m)',
                     '2019 Pop Age 55-59(1m)', '2019 Pop Age 60-64(1m)', '2019 Pop Age 65+(1m)', '2019 Pop Age 65-69(1m)', '2019 Pop Age 70-74(1m)',
                     '2019 Pop Age 75-79(1m)', '2019 Pop Age 80-84(1m)', '2019 Pop Age 85+(1m)', '2024 Avg Male Age(1m)', '2024 HH Age 25-34(1m)',
                     '2024 HH Age 35-44(1m)', '2024 HH Age 45-54(1m)', '2024 HH Age 55-64(1m)', '2024 HH Age 65-74(1m)', '2024 HH Age 75-84(1m)','2024 HH Age 85+(1m)',
                    '2024 Pop Age <19(1m)', '2024 Pop Age 0-4(1m)', '2024 Pop Age 20-64(1m)', '2024 Pop Age 25-29(1m)', '2024 Pop Age 30-34(1m)',
                     '2024 Pop Age 35-39(1m)', '2024 Pop Age 40-44(1m)', '2024 Pop Age 45-49(1m)', '2024 Pop Age 50-54(1m)', '2024 Pop Age 55-59(1m)',
                     '2024 Pop Age 5-9(1m)', '2024 Pop Age 60-64(1m)', '2024 Pop Age 65+(1m)', '2024 Pop Age 65-69(1m)', '2024 Pop Age 70-74(1m)',
                     '2024 Pop Age 75-79(1m)', '2024 Pop Age 80-84(1m)', '2024 Pop Age 85+(1m)', '2010 Pop Age 10-14(1m)', '2010 Pop Age 15-19(1m)',
                     '2010 Pop Age 5-9(1m)', '2019 HH Age 15-24(1m)', '2024 Pop Age 10-14(1m)', '2010 Avg Age(1m)' ,'2010 Med Age(1m)', '2010 Pop Age 0-4(1m)',
                     '2019 Avg Age(1m)', '2019 Avg Age&#044; Female(1m)', '2019 Med Age&#044; Female(1m)', '2019 Median HH Age(1m)', '2019 Pop Age <19(1m)',
                     '2019 Pop Age 10-14(1m)', '2019 Pop Age 15-19(1m)', '2019 Pop Age 5-9(1m)', '2024 Avg Age(1m)', '2024 Avg Female Age(1m)', '2024 HH Age 15-24(1m)',
                    '2024 Median HH Age(1m)', '2024 Pop Age 15-19(1m)', '2024 Pop Age 20-24(1m)'], inplace = True)

# %%
predictors = list(df.columns)
predictors.remove('Avg Effective/SF')
response = 'Avg Effective/SF'

# %%
X = df[predictors]
y = df[response]

# %%
def cat(predictors):
    X = df[predictors]
    cat_features = []
    bool_mask = X.dtypes == 'object'
    for i in range(len(bool_mask)):
        if bool_mask[i]:
            cat_features.append(i)
    return cat_features

# %% [markdown]
# ### Encode Categorical Variables

# %%
encoder = OrdinalEncoder()
X = encoder.fit_transform(X, y)

# %%
key_list = predictors

# %%
si = SimpleImputer(strategy='most_frequent')
X = si.fit_transform(X)

# %% [markdown]
# ### Select top 50 features from a Gradient Boosting Model

# %%
fsel = SelectFromModel(LGBMRegressor(categorical_feature = cat(predictors), n_jobs=-1), max_features=50)
fsel.fit(X, y)
# Out:
# SelectFromModel(estimator=LGBMRegressor(boosting_type='gbdt',
#                                         categorical_feature=[1, 2, 3, 4, 5, 6,
#                                                              8, 9, 12, 21, 22,
#                                                              23, 26, 31, 32, 34,
#                                                              35, 45, 46, 47, 48,
#                                                              50, 55, 67, 68, 69,
#                                                              70, 71, 77, 78],
#                                         class_weight=None, colsample_bytree=1.0,
#                                         importance_type='split',
#                                         learning_rate=0.1, max_depth=-1,
#                                         min_child_samples=20,
#                                         min_child_weight=0.001,
#                                         min_split_gain=0.0, n_estimators=100,
#                                         n_jobs=-1, num_leaves=31,
#                                         objective=None, random_state=None,
#                                         reg_alpha=0.0, reg_lambda=0.0,
#                                         silent=True, subsample=1.0,
#                                         subsample_for_bin=200000,
#                                         subsample_freq=0),
#                 max_features=50, norm_order=1, prefit=False, threshold=None)

# %%
fsel.get_support(indices=True)
# Out:
# array([ 2,  4,  5,  8, 10, 11, 12, 13, 15, 16, 17, 22, 23, 27, 28, 30, 32,
#        41, 43, 45, 47, 55, 60, 61, 65, 68, 72, 73, 74, 75], dtype=int64)

# %%
sel = [key_list[i] for i in fsel.get_support(indices=True)]

# %% [markdown]
# ### Get the important variables

# %%
X = df[sel]
encoder = OrdinalEncoder()
X = encoder.fit_transform(X, y)
si = SimpleImputer(strategy='most_frequent')
X = si.fit_transform(X)

# %% [markdown]
# ### Plot feature importance for Random Forest Model

# %%
plt.figure(figsize=(12,12))
ax = plt.gca()
labels = list(map(lambda s: s.title(), sel))
model = RandomForestRegressor(n_estimators=100)
viz = FeatureImportances(model, labels=labels)
viz.fit(X, y)
viz.show(ax=ax)

# %% [markdown]
# ### Plot feature importance for Linear Regression

# %%
plt.figure(figsize=(12,12))
ax = plt.gca()
labels = list(map(lambda s: s.title(), sel))
viz = FeatureImportances(LinearRegression(n_jobs=-1), labels=labels)
viz.fit(X, y)
viz.show(ax=ax)

# %% [markdown]
# ### Plot Pearson correlation

# %%
plt.figure(figsize=(12,12))
ax = plt.gca()
visualizer = FeatureCorrelation(labels=labels)

visualizer.fit(X, y)        # Fit the data to the visualizer
visualizer.show(ax =ax)           # Finalize and render the figure

# %% [markdown]
# ### Plot Shapiro Ranking of features

# %%
plt.figure(figsize=(12,12))
ax = plt.gca()
# Instantiate the 1D visualizer with the Sharpiro ranking algorithm
visualizer = Rank1D(algorithm='shapiro', features = labels)

visualizer.fit(X, y)           # Fit the data to the visualizer
visualizer.transform(X)        # Transform the data
visualizer.show(ax = ax)              # Finalize and render the figure
