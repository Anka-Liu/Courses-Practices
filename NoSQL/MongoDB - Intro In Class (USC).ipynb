# %% [markdown]
# # MongoDB Intro - In Class

# %%
from pymongo import MongoClient
import pymongo
db_url="mongodb://handson:handson@cluster0-shard-00-00-pfhcv.mongodb.net:27017,cluster0-shard-00-01-pfhcv.mongodb.net:27017,cluster0-shard-00-02-pfhcv.mongodb.net:27017/test?ssl=true&replicaSet=Cluster0-shard-0&authSource=admin&retryWrites=true&w=majority"
client = MongoClient(db_url)

# See all databases: list(client.list_databases())
airbnb=client['sample_airbnb']['listingsAndReviews']
geospatial=client['sample_geospatial']['shipwrecks']
movies=client['sample_mflix']
supplies=client['sample_supplies']['sales']
training=client['sample_training']
weather=client['sample_weatherdata']['data']
grades = training['grades']

# %%
from pymongo import MongoClient
import pymongo
db_url="mongodb://localhost"
client = MongoClient(db_url)

# %%
list(client['NoSQL']['Homework'].find({"name":'Author1',"info.education.degree.disseration.advisor.currentAdvisedStuddents.studentNames":{'$in':['student2']}},
                {'_id':0,'name':1,'info':1}))
# Out:
# [{'name': 'Author1',
#   'info': {'bio': 'Author1 is great and was born in..',
#    'favorite_writing_utensil': 'quil',
#    'education': {'university': 'Education University',
#     'degree': {'name': 'Philosophy',
#      'department': 'Philosophy',
#      'school': 'Arts & Sciences',
#      'disseration': {'name': 'Dissertation 1',
#       'advisor': {'name': 'AdvisorName',
#        'position': 'Dept Head',
#        'currentAdvisedStuddents': {'count': 4,
#         'studentNames': ['student1',
#          'student2',
#          'student3',
#          'student4']}}}}}}}]

# %% [markdown]
# ### All Query Operators discussed below can be found here:
# https://docs.mongodb.com/manual/reference/operator/query/

# %% [markdown]
# ## Question 1
#
# Find the number of listings in the Airbnb collection with "accomodates" value of 5 i.e. that accomodates 5 people.

# %%
airbnb.count_documents({'accommodates':5})
# Out:
# 264

# %% [markdown]
# ## Question 2
#
# Find the number of documents in the Airbnb collection that have a "TV" as a value in the "amenities" array.

# %%
airbnb.count_documents({'amenities':'TV'})
# Out:
# 4280

# %% [markdown]
# ## Question 3
#
# Find all the listings with 10 bedrooms, sorted by name descending and ONLY return the name, bedrooms, amenities, and address field. Limit to 1 result.
# ~~~
# SELECT name, bedrooms, address
# FROM airbnb
# WHERE bedrooms = 10
# ORDER BY name desc
# LIMIT 1
# ~~~

# %%
list(airbnb.find({'bedrooms':10},{'_id':0,"name":1,"address":1,"amenities":1}).sort("name",-1))
# Out:
# [{'name': 'Great Complex of the Cellars',
#   'amenities': ['TV',
#    'Cable TV',
#    'Wifi',
#    'Kitchen',
#    'Free street parking',
#    'Heating',
#    'Family/kid friendly',
#    'Washer',
#    'Dryer',
#    'First aid kit',
#    'Fire extinguisher',
#    'Essentials',
#    'Shampoo',
#    'Lock on bedroom door',
#    'Hangers',
#    'Hair dryer',
#    'Iron',
#    'Laptop friendly workspace',
#    'Private entrance',
#    'Baby monitor',
#    'Bathtub',
#    'Baby bath',
#    'High chair',
#    'Crib',
#    'Pack ’n Play/travel crib',
#    'Hot water',
#    'Bed linens',
#    'Extra pillows and blankets',
#    'Microwave',
#    'Coffee maker',
#    'Refrigerator',
#    'Dishes and silverware',
#    'Cooking basics',
#    'Oven',
#    'Stove',
#    'BBQ grill',
#    'Patio or balcony',
#    'Luggage dropoff allowed',
#    'Long term stays allowed',
#    'Host greets you',
#    'Waterfront'],
#   'address': {'street': 'Vila Nova de Gaia, Porto, Portugal',
#    'suburb': '',
#    'government_area': 'Santa Marinha e São Pedro da Afurada',
#    'market': 'Porto',
#    'country': 'Portugal',
#    'country_code': 'PT',
#    'location': {'type': 'Point',
#     'coordinates': [-8.62181, 41.13354],
#     'is_location_exact': False}}},
#  {'name': 'Excellent Location and price !',
#   'amenities': ['TV',
#    'Internet',
#    'Wifi',
#    'Air conditioning',
#    'Smoking allowed',
#    'Breakfast',
#    'Elevator',
#    'Heating',
#    'Family/kid friendly',
#    'Suitable for events',
#    'Dryer',
#    'Smoke detector',
#    'Fire extinguisher',
#    'Essentials',
#    'Shampoo',
#    '24-hour check-in',
#    'Hangers',
#    'Hair dryer',
#    'Iron',
#    'Laptop friendly workspace'],
#   'address': {'street': 'Istanbul, Istanbul Province, Turkey',
#    'suburb': 'Fatih',
#    'government_area': 'Fatih',
#    'market': 'Istanbul',
#    'country': 'Turkey',
#    'country_code': 'TR',
#    'location': {'type': 'Point',
#     'coordinates': [28.97592, 41.00884],
#     'is_location_exact': False}}}]

# %% [markdown]
# ## Question 4
#
# SELECT name, number_of_reviews  <br>
# FROM airbnb <br>
# ORDER BY number_of_reviews desc <br>
# LIMIT 1

# %%
list(airbnb.find({'bedrooms':10},{'_id':0,"name":1,"address":1,"amenities":1}).sort("name",-1))

# %% [markdown]
# # Comparison Operators
#
# ~~~
# $eq: Matches values that are equal to a specified value.
# $gt: Matches values that are greater than a specified value.
# $gte: Matches values that are greater than or equal to a specified value.
# $in: Matches any of the values specified in an array.
# $lt: Matches values that are less than a specified value.
# $lte: Matches values that are less than or equal to a specified value.
# $ne: Matches all values that are not equal to a specified value.
# $nin: Matches none of the values specified in an array.
# ~~~
#
# See https://docs.mongodb.com/manual/reference/operator/query-comparison/ for more info.

# %% [markdown]
# ## Question 5
#
# Return the document where "accommodates" is greater than 6, and ordered by "number_of_reviews" descending, limit to 1 result. Only return "name", "accommodates", "number_of_reviews", and the "address".
#
# ~~~
# Syntax: {field: {$gt: value} }
# ~~~

# %%
list(airbnb.find({"accommodates":{"$gt":6}},{'_id':0,"name":1,"accommodates":1}).sort("number_of_reviews",-1))
# Out:
# [{'name': 'Spectacular Modern Uptown Duplex', 'accommodates': 11},
#  {'name': 'Lulapartment', 'accommodates': 8},
#  {'name': 'Lulapartment II', 'accommodates': 7},
#  {'name': '3BR 2WR Apt (KS) 5 min wan chai MTR', 'accommodates': 8},
#  {'name': 'SANTA CATARINA HOUSE', 'accommodates': 8},
#  {'name': 'Beautiful Home Away From Home!', 'accommodates': 10},
#  {'name': 'ENTIRE BUILDING in the City Center/Beach', 'accommodates': 10},
#  {'name': '2BRs big size 2minsMTR close to MK', 'accommodates': 9},
#  {'name': 'Huge 3 bedroom apt on Nathan Rd -KD', 'accommodates': 8},
#  {'name': 'Sand Sun Surf w Parking. City 9km', 'accommodates': 15},
#  {'name': 'Porto Leça Beach Flat in Matosinhos', 'accommodates': 8},
#  {'name': 'LUXURY! 3BR ,Bathtub, 1min MTR 4-9ppl', 'accommodates': 9},
#  {'name': 'At The Heart Of The Old Sultanahmet', 'accommodates': 7},
#  {'name': 'Stately Darlinghurst Terrace', 'accommodates': 8},
#  {'name': 'Bondi Beach Dreaming 3-Bed House', 'accommodates': 8},
#  {'name': 'Sagrada Familia area for 12 people', 'accommodates': 12},
#  {'name': 'Pin Porto City Center', 'accommodates': 10},
#  {'name': 'Tatami with 6 ppl 1Minute to  MTR', 'accommodates': 7},
#  {'name': 'Spacious and quiet duplex apartment in Poble Sec',
#   'accommodates': 7},
#  {'name': 'OPORTO FLAT', 'accommodates': 8},
#  {'name': "Tutu's Hale with a View (Grandma's House)", 'accommodates': 8},
#  {'name': 'Featured on TV - A Current Affair Come for a swim!',
#   'accommodates': 7},
#  {'name': 'Makai Hideaway', 'accommodates': 14},
#  {'name': 'Large Duplex in Midtown East with backyard!', 'accommodates': 7},
#  {'name': 'Family Matters | Historic Centre', 'accommodates': 7},
#  {'name': 'Cottage in Haiku', 'accommodates': 9},
#  {'name': 'Ohana Haven', 'accommodates': 10},
#  {'name': '3 bedroom + 2 bathroom apt near MTR', 'accommodates': 11},
#  {'name': 'Big, glamorous, 4BR, 3-story house', 'accommodates': 8},
#  {'name': '2 Bdrm/2 Bath  Family Suite Ocean View', 'accommodates': 8},
#  {'name': '@CausewayBayMTR/TimeSq.★Near HKCEC', 'accommodates': 7},
#  {'name': 'Executive cataluña 6 , 5 bedrooms', 'accommodates': 13},
#  {'name': 'Elegant 2BD in Time Sq with W/D!', 'accommodates': 7},
#  {'name': 'THE BEST Home ** PARKINGS **5beds,12guests,3bdroom',
#   'accommodates': 12},
#  {'name': '#Old City#Authentic Duplex #Terrace', 'accommodates': 7},
#  {'name': '6 bd country living near beach', 'accommodates': 16},
#  {'name': 'Lovely Big Room in Center of Porto', 'accommodates': 7},
#  {'name': 'Artist Garden Duplex Ft. Greene - 2.5 Bedroom', 'accommodates': 8},
#  {'name': 'Large Garden Duplex on Park block', 'accommodates': 7},
#  {'name': 'Spacious and Comfy 2BR apartment Heart Of downtown',
#   'accommodates': 8},
#  {'name': '★ Amazing with terrace & wifi ★', 'accommodates': 8},
#  {'name': 'Aconchego entre a Praia e a Lagoa', 'accommodates': 7},
#  {'name': 'Sydney Olympic Park Apartment', 'accommodates': 7},
#  {'name': 'Cheerful new renovated central apt', 'accommodates': 8},
#  {'name': 'Grand apartment Sagrada Familia', 'accommodates': 8},
#  {'name': 'Apartamento Copa3 quartos 11pessoas', 'accommodates': 11},
#  {'name': 'SydneyCBD/CentralAircon/TwoStory/FamilyHome', 'accommodates': 10},
#  {'name': '5 ★★★★★ Gorgeous suite only 1 block from subway!',
#   'accommodates': 7},
#  {'name': 'VERY LARGE 5 Bedroom Home, free onsite parking',
#   'accommodates': 10},
#  {'name': 'Wan Chai 3 Bedrooms Spacious Convenient Spot', 'accommodates': 8},
#  {'name': 'BEACH ESCAPE', 'accommodates': 14},
#  {'name': 'BBC OPORTO 4X2', 'accommodates': 8},
#  {'name': 'Ocean View Across Street from Beach Clean & Quiet',
#   'accommodates': 7},
#  {'name': 'Luxury Vacation Walk to Beach Ocean Condo Maui HI',
#   'accommodates': 7},
#  {'name': 'City Views Close to SI Ferry', 'accommodates': 8},
#  {'name': 'NEW!_Warm Apt._1min Subway_8ppl_3room2bath', 'accommodates': 8},
#  {'name': '☆ Mile-End 3BR Only 10-minutes from Downtown', 'accommodates': 8},
#  {'name': 'Duplex apartment with garden', 'accommodates': 7},
#  {'name': 'Fabulous 3 Bedrm Poipu Beach CONDO', 'accommodates': 7},
#  {'name': 'Amazing Ocean View Condo in Wailea!', 'accommodates': 8},
#  {'name': 'Walk to beach - Cottage close to Waikiki', 'accommodates': 8},
#  {'name': 'GREAT VIEW -Santa Teresa- GUESTHOUSE "Casa 48"  #2',
#   'accommodates': 16},
#  {'name': "Rob's Beach Terrace", 'accommodates': 8},
#  {'name': '⭐❤2BR BIG HOME-MAX 7GUESTS-MONG KOK MTR 旺角地鐵兩房一廳❤⭐',
#   'accommodates': 7},
#  {'name': 'Cosmopolitan Brownstone Sanctuary', 'accommodates': 8},
#  {'name': 'Stone House 2, com terraço e Wi-Fi', 'accommodates': 8},
#  {'name': 'Feel Porto Downtown City Roofs', 'accommodates': 8},
#  {'name': 'Holiday Villa - Casa do Sobreiro', 'accommodates': 9},
#  {'name': 'Grande I Apartment on Valencia St.', 'accommodates': 7},
#  {'name': '5º | Palácio do Comércio', 'accommodates': 8},
#  {'name': 'Sandstone Cottage, Great Mackerel Beach', 'accommodates': 8},
#  {'name': 'Historical big flat@city center', 'accommodates': 10},
#  {'name': 'Experience Kona Farm', 'accommodates': 8},
#  {'name': 'Casa S. Miguel 6 - The Yellow House', 'accommodates': 8},
#  {'name': 'Bohemian 4BR in Plateau by Sonder', 'accommodates': 7},
#  {'name': 'Spacious apartment in the heart of Downtown MTL',
#   'accommodates': 13},
#  {'name': 'Luxury Living! Sleeps 8, 2 Car Spots, Close to CBD',
#   'accommodates': 8},
#  {'name': "The Porto Concierge - Boavista's Dance", 'accommodates': 8},
#  {'name': 'Gran Via De Luxe 5* DaysinBarcelona', 'accommodates': 10},
#  {'name': 'Casa Montreal (Perfect for Family/Group)!', 'accommodates': 12},
#  {'name': 'House close to station & direct to opera house....',
#   'accommodates': 16},
#  {'name': 'Un chez vous confortable et spacieux .', 'accommodates': 8},
#  {'name': 'Wow Historical Brooklyn New York!@!', 'accommodates': 8},
#  {'name': 'Ribeira Charming Duplex', 'accommodates': 8},
#  {'name': 'Sunset Beach Lodge Retreat', 'accommodates': 8},
#  {'name': 'Dor.me', 'accommodates': 8},
#  {'name': 'Cozy and convenient home near Time Square HK', 'accommodates': 8},
#  {'name': 'South West Luxury 2 Bedrooms Close to Downtown', 'accommodates': 7},
#  {'name': 'Stunning Oceanfront. Amazing Views. 2 Bed 2 Baths',
#   'accommodates': 7},
#  {'name': 'Sydney CBD 3 Bedroom 1 Bathroom Apartment', 'accommodates': 8},
#  {'name': 'COPACABANA BEACH- REVEILLON -WI FI FREE -Cable TV',
#   'accommodates': 8},
#  {'name': 'Chelsea Dream: Stunning Duplex 1,800sf Loft~6BEDS',
#   'accommodates': 10},
#  {'name': 'Northshore Home: Stunning ocean-views, 1 acre land',
#   'accommodates': 8},
#  {'name': 'Jubilee By The Sea (Ocean Views)', 'accommodates': 11},
#  {'name': 'OCEANFRONT - Vacation in Sand - Harmony', 'accommodates': 8},
#  {'name': 'Waterfront, Enchanted Lake Home 2/1', 'accommodates': 8},
#  {'name': 'Huge duplex apt. up to 8 in Taksim', 'accommodates': 8},
#  {'name': 'INSTAGRAM HOME *MTR*ELEMENT MALL*NEW TRAIN KOWLOON',
#   'accommodates': 9},
#  {'name': 'Spacious 3 BDR APT Brooklyn Sleeps 12!', 'accommodates': 12},
#  {'name': 'White House', 'accommodates': 10},
#  {'name': 'Gorgeous Ocean Front Home w/ Salt Water Pool', 'accommodates': 10},
#  {'name': 'POIPU TURTLE SUITE STEPS TO THE BEACH W/ AC!', 'accommodates': 7},
#  {'name': 'The Kona Coffee Condo', 'accommodates': 8},
#  {'name': 'Bundeena Base Art House, Sea View with Heated Pool',
#   'accommodates': 8},
#  {'name': 'CALABRIA, central, large, 4 bedrooms', 'accommodates': 8},
#  {'name': 'Work n Rest Free wifi Quiet, Family Fun Shops Cafe',
#   'accommodates': 12},
#  {'name': 'Beach Block 6bed Penthouse, Ipanema Best Location!',
#   'accommodates': 13},
#  {'name': 'Lucky House 2 Bed Rooms, 5 mins to MTR', 'accommodates': 7},
#  {'name': 'Casa do Rio - Porto', 'accommodates': 7},
#  {'name': 'Popular Rainforest Hideaway', 'accommodates': 8},
#  {'name': 'Kaena O Kekai', 'accommodates': 16},
#  {'name': 'MILE-END ☀️Near MONTROYAL park☀️ FREE PARKING', 'accommodates': 12},
#  {'name': 'BEST REVIEWS*BEST MALLS*SAFE STAY*DIMSUM*CWB*MTR',
#   'accommodates': 8},
#  {'name': 'Awesome 2-storey home Bronte Beach next to Bondi!',
#   'accommodates': 11},
#  {'name': 'A1 Tradewinds Ranch House (2 story)', 'accommodates': 10},
#  {'name': 'Kuulai Hale Private Cottage', 'accommodates': 7},
#  {'name': 'The Porto Concierge - Camellia House', 'accommodates': 11},
#  {'name': 'Stylish Mile End Condo with City Views from the Roof Deck',
#   'accommodates': 8},
#  {'name': 'Gorgeous Hawaiiana Home near beach', 'accommodates': 8},
#  {'name': '★ Mar/Apr Discount ★ Beachfront/Remodeled 2017/18.',
#   'accommodates': 8},
#  {'name': 'Private OceanFront - Bathtub Beach. Spacious House',
#   'accommodates': 14},
#  {'name': 'AVAILABLE, Poipu Beach, NEW OeanView Deck House',
#   'accommodates': 8},
#  {'name': 'Kaanapali Hillside 3 bedroom condo', 'accommodates': 8},
#  {'name': 'Big 4 Bedroom~', 'accommodates': 7},
#  {'name': '3 Bedroom / Ocean views / Free Parking - Waikiki',
#   'accommodates': 8},
#  {'name': 'Luxurious 4 to 5 Room The Rocks Large House Sydney',
#   'accommodates': 8},
#  {'name': "MEHMET'S PLACE IN ISTANBUL", 'accommodates': 8},
#  {'name': 'Beautiful apartment in the city centre of BCN!!!',
#   'accommodates': 7},
#  {'name': '3bd/2ba Valley House Near Kaimuki, Upstairs', 'accommodates': 8},
#  {'name': 'Standing 3 rooms flat in Copacabana', 'accommodates': 7},
#  {'name': 'Big Private 4 bedrooms 1 bathroom Near Subway!',
#   'accommodates': 13},
#  {'name': '1921 15kms from Sydney CBD with Pool Spa parking.',
#   'accommodates': 9},
#  {'name': '3 bedrooms, luxury condominium', 'accommodates': 10},
#  {'name': "L'etoile de Mer TST 海の星宿 尖沙咀 Single Mixed Capsule",
#   'accommodates': 12},
#  {'name': 'Guindais Well House - Porto downtown', 'accommodates': 9},
#  {'name': 'Quite Family Retreat', 'accommodates': 8},
#  {'name': 'Big House Near Porto and beachs', 'accommodates': 8},
#  {'name': 'Last Minute Specials~Heated Pool~Steps to Beach!',
#   'accommodates': 9},
#  {'name': 'Tamarama Penthouse apartment', 'accommodates': 7},
#  {'name': '地鉄上的3房2廳2卫浴住9人可月租2萬9千起', 'accommodates': 9},
#  {'name': 'Tapioles Triplex Apartment', 'accommodates': 10},
#  {'name': 'Coastal Apartment with Cafes, Bars & Beach at Your Doorstep',
#   'accommodates': 7},
#  {'name': 'Large railroad style 3 bedroom apt in Manhattan!',
#   'accommodates': 9},
#  {'name': 'Beautiful 3BR flat in the Center', 'accommodates': 7},
#  {'name': 'Artsy 4BR in Plateau by Sonder', 'accommodates': 8},
#  {'name': 'Hale Ohia: Peaceful Escape Close to National Park',
#   'accommodates': 7},
#  {'name': 'Mixed Dorm Bed#8 in Wan Chai (灣仔)(混合床位)(一張床位)', 'accommodates': 8},
#  {'name': 'Private Rooms in Very Peaceful Environment', 'accommodates': 8},
#  {'name': 'The Porto Concierge - Baron Omega', 'accommodates': 10},
#  {'name': 'Perfect Peaceful Hale', 'accommodates': 8},
#  {'name': 'Comfortable and Accesible For Groups (H1+H2)', 'accommodates': 10},
#  {'name': 'Family / Groups, 3 BRs Near Soho & Macau Ferry', 'accommodates': 8},
#  {'name': 'Ainani Jade Ohana 3 Bedroom/2 Bath', 'accommodates': 8},
#  {'name': 'Self Check In @ Panoramic Vic Harbour Homestay!',
#   'accommodates': 7},
#  {'name': 'Caliu, Friendly Rentals', 'accommodates': 10},
#  {'name': 'WORLD CLASS MALLS*LUXURY 3BED2BATH*CLEAN*MTR*SAFE',
#   'accommodates': 8},
#  {'name': 'Renovated Federalist House with a Private Garden and Hot Tub',
#   'accommodates': 10},
#  {'name': '市中心特色唐樓 Downtown Guesthouse', 'accommodates': 10},
#  {'name': 'StayIN Oporto Música - Apartment', 'accommodates': 16},
#  {'name': 'Hawaiian Escape', 'accommodates': 8},
#  {'name': 'Sublime loft with private roof top @ Old Montreal',
#   'accommodates': 7},
#  {'name': 'Sublime 2 bedrooms @ Old Montreal close to subway',
#   'accommodates': 7},
#  {'name': 'Big Group! Spacious! Wanchai!', 'accommodates': 12},
#  {'name': 'Hop Inn - 8 Bed Mixed Dorm (Mody)', 'accommodates': 8},
#  {'name': 'BEST HOME in the BlueMosq area!', 'accommodates': 12},
#  {'name': 'Spacious and Clean Get Away', 'accommodates': 10},
#  {'name': 'Brooklyn home.  Comfort and clean. Liguria room.',
#   'accommodates': 8},
#  {'name': 'Le Bed & Cocktail: Discover Montreal like a local',
#   'accommodates': 12},
#  {'name': '*Ke Iki Paradise Sands', 'accommodates': 8},
#  {'name': 'Penthouse Sands of Kahana Sandy Swimmable Beach',
#   'accommodates': 9},
#  {'name': 'Quiet area, Wan Chai Centre, Near Tram station', 'accommodates': 7},
#  {'name': 'Charming MtlHomestay Accommodation!', 'accommodates': 7},
#  {'name': 'Experience Dolphins Frolicing on the Kona Coast',
#   'accommodates': 8},
#  {'name': 'Oporto Charming Townhouse - ﾒﾄﾛ100m', 'accommodates': 8},
#  {'name': '4 BR in Spacious & Elegant Vintage 1910 Apartment',
#   'accommodates': 8},
#  {'name': '佐敦地鐵站2分鐘 溫馨全新裝修兩房 全新傢電床品住9人  光猛通爽 jordan mtr 2min',
#   'accommodates': 9},
#  {'name': '4BR-5BR Hawaiian Dreams Beach House', 'accommodates': 10},
#  {'name': 'Charming House with private garden and barbecue',
#   'accommodates': 8},
#  {'name': 'Peaceful hometown with perfect sea and forest view',
#   'accommodates': 8},
#  {'name': '2458 - AB Park Güell Apartment 4-3 - Wonderful 3-Bedroom Apartment near Park Güell with a Balcony',
#   'accommodates': 8},
#  {'name': 'DOWNTOWN VIP MONTREAL ,HIGH END DECOR,GOOD VALUE..',
#   'accommodates': 16},
#  {'name': 'Perto do Porto, Gaia e mar.', 'accommodates': 8},
#  {'name': 'Panoramic Seaview “Pi(π) House Bosphorus” Cihangir',
#   'accommodates': 10},
#  {'name': 'Apartment in Ipanema with Balcony', 'accommodates': 7},
#  {'name': 'MAR 402 Tres habitaciones junto a la Playa', 'accommodates': 8},
#  {'name': '2447 - AB Park Güell Apartment 1-1 - Elegant 4-Bedroom Apartment near Park Güell with a Balcony',
#   'accommodates': 10},
#  {'name': 'Beautiful Bondi family beach house', 'accommodates': 8},
#  {'name': 'Ocean front Beach House in Makaha', 'accommodates': 10},
#  {'name': 'Duo· Sleeps 9! 4Bedroom/2Bath/2Kitchen/2Parking',
#   'accommodates': 9},
#  {'name': 'Gorgeous Garden Retreat in trendy, quaint Kaimuki',
#   'accommodates': 8},
#  {'name': '7 guests at ville St-Laurent, with parking spot',
#   'accommodates': 7},
#  {'name': 'Liiiving in Porto | Santa Catarina Luxury Apt. I',
#   'accommodates': 8},
#  {'name': 'WONDERFUL APARTMENT NEAR PASEO DE GRACIA', 'accommodates': 7},
#  {'name': 'Casa de Vilela', 'accommodates': 16},
#  {'name': 'The Central Place VI', 'accommodates': 7},
#  {'name': 'Fabulous Beach Front Penthouse', 'accommodates': 8},
#  {'name': 'Villa CL', 'accommodates': 7},
#  {'name': 'Luxury & Cozy Apartment in Heart of Sydney CBD', 'accommodates': 8},
#  {'name': 'Waikoloa Beach Villas C1.  Hilton Pool Pass Included in 2019',
#   'accommodates': 8},
#  {'name': 'VayCay with Southern Comfort and the Aloha Spirit',
#   'accommodates': 8},
#  {'name': 'Our COZY LOFT in Williamsburg, Brooklyn', 'accommodates': 8},
#  {'name': '900+sq ft Modern Comfy Apartment, TST Centre', 'accommodates': 12},
#  {'name': '(Mong Kok)  New !!! Warm, comfortable, 2 min MTR',
#   'accommodates': 9},
#  {'name': '⭐️Ocean/City Views⭐️Van Included⭐️Hot Tub⭐️3 Bath',
#   'accommodates': 12},
#  {'name': "Shangri'La by the Sea, Kapoho Beach", 'accommodates': 8},
#  {'name': 'Beachside Blue - AC, close to beach and PCC', 'accommodates': 8},
#  {'name': 'The Porto Concierge -  Lodeiro Country House', 'accommodates': 12},
#  {'name': 'Villa 200m2, 10 mn de Porto  , 150m de la plage',
#   'accommodates': 10},
#  {'name': 'Autèntic Monumental 32', 'accommodates': 14},
#  {'name': 'Westin Kaanapali KORVN 2BR', 'accommodates': 8},
#  {'name': 'Sophisticated, waterfront living w/ resort pool, hot tub, & beach access',
#   'accommodates': 8},
#  {'name': 'Spacious 3 BR 12ppl Beside MTR :)', 'accommodates': 12},
#  {'name': 'Absolute harborfront 2-bed luxury heaven MAR SALE!',
#   'accommodates': 7},
#  {'name': '-MAISON ALEXANDRA- 3 STOREY WATERFRONT PH FLOOR',
#   'accommodates': 16},
#  {'name': 'Quinta Adágio', 'accommodates': 8},
#  {'name': 'BEAUTIFUL 2-BEDROOM TOWNHOUSE NYC', 'accommodates': 9},
#  {'name': 'Sagrada Familia Butterfly', 'accommodates': 7},
#  {'name': 'The deck house @ Clareville Beach', 'accommodates': 9},
#  {'name': 'Family friendly vacation home near sandy beaches',
#   'accommodates': 10},
#  {'name': 'Plumeria House, Poipu Home with a View', 'accommodates': 14},
#  {'name': 'Casa completa no Condomínio Mansões!', 'accommodates': 12},
#  {'name': 'Family Hawaiian Paradise on Marina Top Level', 'accommodates': 10},
#  {'name': 'The Porto Concierge - Jazz Apartment', 'accommodates': 8},
#  {'name': 'North Shore Country Villa', 'accommodates': 12},
#  {'name': 'Haena to re-open in 2019! Ocean Views! Newly added A/C in all rooms! - Haena Kai',
#   'accommodates': 7},
#  {'name': 'Greenwich Village Townhome with Private Garden!',
#   'accommodates': 7},
#  {'name': 'IPANEMA, Rio de Janeiro, Brasil', 'accommodates': 8},
#  {'name': 'Penthouse da Música for 8', 'accommodates': 8},
#  {'name': 'Pili Mai 2L', 'accommodates': 8},
#  {'name': 'Modern and Amazing Apartments in Porto', 'accommodates': 10},
#  {'name': 'Beautiful 2 BR Up To 8 People In Old Montreal', 'accommodates': 8},
#  {'name': 'Apartment with Balcony , Sultan Ahmet', 'accommodates': 7},
#  {'name': 'Grace 1 - Habitat Apartments', 'accommodates': 8},
#  {'name': '6roomsHouse 5mins toTrainStation near SYD Airport',
#   'accommodates': 14},
#  {'name': 'Large 3 bedrooms apartment', 'accommodates': 8},
#  {'name': 'Blue Mosque Special Apartment!', 'accommodates': 10},
#  {'name': 'Nuevo espacioso apartamento en BCN', 'accommodates': 8},
#  {'name': 'RE.. BIG AND CLASSIC 2 BEDROOM IN ARPOADOR', 'accommodates': 8},
#  {'name': 'Private Family Retreat with Spa & Pool', 'accommodates': 8},
#  {'name': 'Kolea Resort at Waikoloa Beach', 'accommodates': 9},
#  {'name': 'Great Complex of the Cellars', 'accommodates': 16},
#  {'name': 'Douro view Apartment', 'accommodates': 7},
#  {'name': 'Excellent Duplex in Sarrià with Private Pool', 'accommodates': 10},
#  {'name': 'Warm# 3 bedroom + 2 bathroom  7pp#Apt. near MTR',
#   'accommodates': 7},
#  {'name': 'Water view getaway loft', 'accommodates': 8},
#  {'name': 'Whale Beach Pittwater Views- By Escape Vacations',
#   'accommodates': 8},
#  {'name': '旺角市中心地鐵出口,三房兩卫一大廳', 'accommodates': 9},
#  {'name': "Marriott's Ko Olina Beach Club", 'accommodates': 8},
#  {'name': '4 quartos na praia da Barra', 'accommodates': 12},
#  {'name': '5 Bedroom family home in Outremont W/3 Parkings',
#   'accommodates': 12},
#  {'name': 'Oporto Boavista Family & Friends', 'accommodates': 8},
#  {'name': 'Fern Forest Getaway - entire house', 'accommodates': 15},
#  {'name': 'Westin Kaanapali KORVS 2BR OCEAN VIEW', 'accommodates': 8},
#  {'name': 'Ribeiro de Moinho', 'accommodates': 8},
#  {'name': 'Quarto 9 Camas ( Suite) LE HOUSE HOSTEL 2', 'accommodates': 9},
#  {'name': 'Large 6 Bedroom Apartment in Plateau + sunroom',
#   'accommodates': 12},
#  {'name': 'Elegant quiet luxury home at Bondi', 'accommodates': 7},
#  {'name': 'The Porto Concierge - Baltar Rustic(Rota Romanico)',
#   'accommodates': 7},
#  {'name': 'Ultra Modern Pool House Maroubra', 'accommodates': 8},
#  {'name': 'z1 Bedroom@Whole Apartment w/Lift', 'accommodates': 8},
#  {'name': 'Terrace and pool apartment near the Barcelona', 'accommodates': 10},
#  {'name': 'CRONULLA BEACH HOUSE', 'accommodates': 9},
#  {'name': 'Maison Chez Maria |Large groups |Close to airport',
#   'accommodates': 12},
#  {'name': 'Dee Why Home with a View', 'accommodates': 7},
#  {'name': '旺角地铁站附近三房一厅', 'accommodates': 8},
#  {'name': 'Spacious, bright, central. AC. Rambla Catalunya',
#   'accommodates': 8},
#  {'name': 'High Floor-Ocean View! 2 Bed/2 Ba/1 Pkg WBT#1804',
#   'accommodates': 7},
#  {'name': 'Apartamento Design VIP Praia da Barra - 3 quartos',
#   'accommodates': 8},
#  {'name': 'Gallery Seaside House at Porto', 'accommodates': 8},
#  {'name': 'Spacious 4 BR Apartment on Plateau + Terrace', 'accommodates': 8},
#  {'name': '4 bdrm, 2 bath, 2 living room, kitchen', 'accommodates': 12},
#  {'name': '2714 - AB Girona Apartment 41 - Stylish Apartment for up to 7 guests in Eixample with a Balcony',
#   'accommodates': 7},
#  {'name': 'Secluded semi moments to everywhere', 'accommodates': 10},
#  {'name': 'Rio Parque Condominio Clube', 'accommodates': 8},
#  {'name': 'Luxury ocean view Beach Villa 622', 'accommodates': 8},
#  {'name': 'Bilgi Üniversitesi yanında güzel ev', 'accommodates': 7},
#  {'name': 'B103 Waipouli Beach Resort, Sleeps 8!', 'accommodates': 8},
#  {'name': 'Deluxe Large Apt for 9 px 2bathroom', 'accommodates': 10},
#  {'name': 'Aquilla House - Ocean Views Newport', 'accommodates': 8},
#  {'name': 'Modern luxury Beach House', 'accommodates': 10},
#  {'name': 'Westin Kaanapali KORVS 2BR', 'accommodates': 8},
#  {'name': 'Grande maison avec jardin sur le Plateau', 'accommodates': 7},
#  {'name': 'Avarandado Souza Lima', 'accommodates': 8},
#  {'name': 'AMAZING split level Penthouse', 'accommodates': 8},
#  {'name': 'Beautiful 4 level terrace in the heart of Sydney!',
#   'accommodates': 7},
#  {'name': '5 Room Villa in Oporto Center', 'accommodates': 10},
#  {'name': 'Venue Hotel Old City', 'accommodates': 15},
#  {'name': 'Paradise in Willoughby', 'accommodates': 8},
#  {'name': 'Adjacent house in Outremont', 'accommodates': 13},
#  {'name': 'Spacious downtown 3 bedroom for New Years Eve', 'accommodates': 8},
#  {'name': 'Casa do Pombal', 'accommodates': 10},
#  {'name': 'Amazing sea View - Comfortable & Triplex Apartment',
#   'accommodates': 10},
#  {'name': 'Roof House +Free Breakfast+Wi-Fi+15 min to Airport',
#   'accommodates': 8},
#  {'name': '春遊大优惠 旺角CBD核心区 商旅首选 简约舒适大三居', 'accommodates': 8},
#  {'name': 'Ayasofya delux apartmens', 'accommodates': 7},
#  {'name': 'Tranquil Beach & Bush Cottage + Backyard Studio',
#   'accommodates': 7},
#  {'name': '4BR family home nr beaches and park', 'accommodates': 7},
#  {'name': 'Renovated 2 Bedroom/2 Bathroom Apartment P0305', 'accommodates': 7},
#  {'name': 'Temporada LAPA - CENTRO - RIO DE JANEIRO - RJ', 'accommodates': 9},
#  {'name': 'Upper part of a house,1500sf,3bd2bth, split level',
#   'accommodates': 9},
#  {'name': 'A jewel in Bondi', 'accommodates': 8},
#  {'name': 'Bondi Beach Pad', 'accommodates': 7},
#  {'name': 'Flat Duplex Ipanema All Service Luxo Com Serviços',
#   'accommodates': 8},
#  {'name': 'Lanikai Plantation - 4 bedrooms/3 baths', 'accommodates': 8},
#  {'name': 'Hale Nui Ohana', 'accommodates': 14},
#  {'name': 'taksim istanbul apart 3+1', 'accommodates': 10},
#  {'name': 'Private 4 Bedroom Beach House in Bondi', 'accommodates': 9},
#  {'name': 'Curl Curl Getaway | Pool & Spacious 4 BR House', 'accommodates': 8},
#  {'name': 'Tranquil beach home with pool & ocean glimpses', 'accommodates': 8},
#  {'name': 'Serene & Artsy, 1/2 acre, Oceanfront Home, Bikes!',
#   'accommodates': 8},
#  {'name': 'LEGNOCASA', 'accommodates': 16},
#  {'name': 'BIG HEAVEN IN HONOLULU', 'accommodates': 8},
#  {'name': 'Beautiful forest hill view! 2 bed/2bath', 'accommodates': 9},
#  {'name': 'Dorm 3baths SohoEast......', 'accommodates': 12},
#  {'name': '三大房大床,客廳寬闊｡旺角中心,到地鐵口不到1分鐘', 'accommodates': 8},
#  {'name': 'Modern & Cosy 3BD in Ramblas *Balcony', 'accommodates': 8},
#  {'name': 'Ocean & golf course views!! 3 BR/2BA Sleeps 7', 'accommodates': 7},
#  {'name': 'Big&bucolic apt in the heart of Rio', 'accommodates': 7},
#  {'name': "Catete's Colonial Big Hause Room B", 'accommodates': 8},
#  {'name': 'Barra da Tijuca: cobertura ESPETACULAR', 'accommodates': 8},
#  {'name': 'Cosy penthouse close to Barra beach', 'accommodates': 10},
#  {'name': 'Modern House + Granny Flat sleeps 10+', 'accommodates': 8},
#  {'name': 'Mauna Kea High Bluffs Private Home.  Cleaning Fee Waived!',
#   'accommodates': 8},
#  {'name': 'Villa Hodgkinson 18A - Convenient Sydney Location',
#   'accommodates': 10},
#  {'name': 'Modernist apartment principal', 'accommodates': 10},
#  {'name': 'Reveillon, Eventos, Férias, Passeio, Feriado 1',
#   'accommodates': 10},
#  {'name': '2 Apês no mesmo apart-hotel (3 quartos e 1 quarto)',
#   'accommodates': 12},
#  {'name': 'Wonderful Seafront 4 Bedroom Apart in Copacabana',
#   'accommodates': 8},
#  {'name': '❤️ 6-BR APARTMENT w Kitchen + 2 Rooms!', 'accommodates': 16},
#  {'name': 'Large Luxury Hong Kong Island apartment', 'accommodates': 8},
#  {'name': 'Terrace, sea view at Diagonal Mar!', 'accommodates': 8},
#  {'name': 'Calm & Cozy 4BR with Parking', 'accommodates': 10},
#  {'name': 'AMAZING VIEW 3 QUARTOS FRENTE MAR', 'accommodates': 10},
#  {'name': '2Units2Bedrooms2Bathrooms2ParkingOffPremises', 'accommodates': 9},
#  {'name': '9 People*Kitchen+dining inoutside room(9人房+房外有廚廳',
#   'accommodates': 9},
#  {'name': 'Best Rio Location For Holidays', 'accommodates': 8},
#  {'name': 'Lujoso apartamento ideal familias (8 pax)', 'accommodates': 8},
#  {'name': 'In front of the sea, terrace close Congress center',
#   'accommodates': 8},
#  {'name': '3store apartment for vacations', 'accommodates': 8},
#  {'name': 'Coogee Luxury Home with Salt Water Pool & Parking',
#   'accommodates': 8},
#  {'name': 'Olympic Port apartments', 'accommodates': 12},
#  {'name': 'Splendid uptown suites at Times Square!銅鑼灣舒適大房', 'accommodates': 7},
#  {'name': 'Excellent Location and price !', 'accommodates': 16},
#  {'name': 'Casa da Nininha', 'accommodates': 16},
#  {'name': "Big apartment by Barcelona's main train station",
#   'accommodates': 7},
#  {'name': '3 Floor Luxury Townhouse, Downtown, W/Free Parking',
#   'accommodates': 10},
#  {'name': '3BR Private Williamsburg Apartment', 'accommodates': 7},
#  {'name': 'Duplex com vista para o J. Botanico', 'accommodates': 8},
#  {'name': 'CASA PARA AS OLIMPIADAS 2016', 'accommodates': 10},
#  {'name': 'Aluguel Temporada Casa São Conrado', 'accommodates': 11},
#  {'name': 'Colonial Mansion in Santa Teresa', 'accommodates': 8},
#  {'name': 'Apartamento de Luxo para Olimpíadas', 'accommodates': 8},
#  {'name': '* Lani Beach House', 'accommodates': 8},
#  {'name': 'Spacious Four Bedroom Terrace', 'accommodates': 8},
#  {'name': 'Cobertura de Luxo -Olimpíadas', 'accommodates': 8},
#  {'name': 'Apto Olimpíadas praia Barra Tijuca', 'accommodates': 8},
#  {'name': 'Apartamento Maracanã Olímpiadas', 'accommodates': 8},
#  {'name': 'Stunning Apartmet for Rio 2016', 'accommodates': 8},
#  {'name': 'Barra da Tijuca beach house', 'accommodates': 16},
#  {'name': 'Casanova Eixample 4 bedrooms apartment', 'accommodates': 7},
#  {'name': 'Beautiful 4 Bedroom House with pool', 'accommodates': 8},
#  {'name': 'Casa MARAVILHOSA, 5 suites OLIMPIADAS RIO 2016',
#   'accommodates': 10},
#  {'name': 'Ventanas Nature Resort  ambiente familiar', 'accommodates': 8},
#  {'name': 'Casa completa p olimpíadas com serviços incluído',
#   'accommodates': 10},
#  {'name': 'Apartamento de luxo em Copacabana - 4 quartos', 'accommodates': 8},
#  {'name': 'Cozy apartment great Area &location( 9 pax)', 'accommodates': 9},
#  {'name': 'LUXICO - Principino', 'accommodates': 8},
#  {'name': "Kahala Ali'i", 'accommodates': 14},
#  {'name': 'Large 3bd 2 bath duplex in prime Greenpoint!', 'accommodates': 7},
#  {'name': 'Whale Beach Sensation', 'accommodates': 12},
#  {'name': 'TÜYAP 8 pers 2+1', 'accommodates': 8},
#  {'name': 'Marriott Waiohai Beach Club 2Bd Villa 2020', 'accommodates': 8},
#  {'name': 'Most Beautiful Villa on Bosphorus Istanbul...', 'accommodates': 14},
#  {'name': '12 people or we can negotiate.', 'accommodates': 12},
#  {'name': 'Guest House 4U - Povoa : beach and  Family 8 PAX',
#   'accommodates': 8},
#  {'name': 'Bungan Beach House', 'accommodates': 8},
#  {'name': 'APARTAMENTO INTEIRO PARA O RÉVEILLON!', 'accommodates': 8},
#  {'name': 'PROS - Family Heaven in the Heart of Manly', 'accommodates': 7},
#  {'name': '1405 - LUXURY BEACH TERRACE APARTME', 'accommodates': 8},
#  {'name': 'LUXICO - Vaucluse Manor', 'accommodates': 10},
#  {'name': 'LUXURY HOUSE IN BARRA DA TIJUCA', 'accommodates': 16},
#  {'name': 'Volcano Dancing Ferns Estate - Minutes from Hawaii Volcanoes National Park! - Volcano Dancing Ferns Estate',
#   'accommodates': 8},
#  {'name': 'boğaz & doğa manzaralı', 'accommodates': 12},
#  {'name': 'Party/Event – Day/Night – Botafogo/Laranjeiras!',
#   'accommodates': 16},
#  {'name': 'Condo au charme parisien au cœur d’Ahuntsic', 'accommodates': 8},
#  {'name': 'Mall Of İstanbul', 'accommodates': 8},
#  {'name': 'Beautiful family house', 'accommodates': 10},
#  {'name': '4 luxury Mosman bedrooms own ensuites, new kitchen',
#   'accommodates': 8},
#  {'name': '4 Modern private ensuite Lofts in Ipanema Hills',
#   'accommodates': 14},
#  {'name': 'COPA BEACH :)', 'accommodates': 10},
#  {'name': 'Golf Villa C5', 'accommodates': 8},
#  {'name': 'Özel müstakil villa', 'accommodates': 10},
#  {'name': 'Cozy seasonal apartment in  Eixample, city center.',
#   'accommodates': 7},
#  {'name': 'Casa do Golfe Vale Pisao, Nature Resort', 'accommodates': 8},
#  {'name': 'Istanbul Single family home', 'accommodates': 9},
#  {'name': 'Two Apartments  The First Ottoman Suites', 'accommodates': 8},
#  {'name': '2 Luxurious Flats at Trindade | Ace Location', 'accommodates': 7},
#  {'name': 'Four Deluxe Apartments The First Ottoman Suits',
#   'accommodates': 16},
#  {'name': 'Maravilhoso apartamento pra passar férias', 'accommodates': 8},
#  {'name': 'Summer Holiday - North Balgowlah Family Home', 'accommodates': 8},
#  {'name': 'Appartement de 125m2 lumineux et calme', 'accommodates': 7},
#  {'name': '4 bedroom duplex apartment near metro station', 'accommodates': 9},
#  {'name': '3 BEDROONS IN COPACABANA BEACH 200 m2', 'accommodates': 8},
#  {'name': 'Alugo casa para temporada da copa', 'accommodates': 10},
#  {'name': 'RIO DE JANEIRO - FIFA WORLD CUP', 'accommodates': 8},
#  {'name': 'taksim meydanına yürüyerek sadece 3 dakika', 'accommodates': 7},
#  {'name': 'Spacious 5 bedroom house - PERFECT LOCATION', 'accommodates': 10},
#  {'name': 'Happy People Plaza España - 4 bedroom (3)', 'accommodates': 8},
#  {'name': 'Beautiful apartment  3 rooms, close to the beach',
#   'accommodates': 7},
#  {'name': 'Beylerbeyineyürüme mesefesinde , metrobüse 100mt.',
#   'accommodates': 8},
#  {'name': 'NEW LISTING! Beautiful family home w/great room & lanai - walk to Anini Beach!',
#   'accommodates': 12},
#  {'name': 'Sands Of Kahana 356 - 3 Bedroom, 2 Bathroom | Sleeps 8',
#   'accommodates': 8},
#  {'name': 'Apartamento Superior com 3 quartos', 'accommodates': 10},
#  {'name': 'Dorm 3baths SohoEast..', 'accommodates': 12},
#  {'name': 'Apartamento prox praia leblon', 'accommodates': 8},
#  {'name': 'Private room with sunny terrace of 200m2. 6', 'accommodates': 10},
#  {'name': 'CASA DA CORUJA', 'accommodates': 7},
#  {'name': 'Amazing Downtown Views from a renovated Suite', 'accommodates': 8},
#  {'name': 'Apartamento em Copacabana', 'accommodates': 7},
#  {'name': '8br DUPLEX in Plateau Mont Royal!', 'accommodates': 16},
#  {'name': 'APART HOTEL', 'accommodates': 16},
#  {'name': 'Stone Wall Apartment', 'accommodates': 7},
#  {'name': 'Piso muy grande con 6 habitaciones en el centro',
#   'accommodates': 13},
#  {'name': 'Alugo casa para as Olimpiadas', 'accommodates': 10},
#  {'name': 'Sharing apartment', 'accommodates': 10},
#  {'name': 'Beautiful apartment froint to the beach with pool',
#   'accommodates': 7},
#  {'name': 'Copacabana 3 rooms 3 wcs garage', 'accommodates': 10},
#  {'name': 'Amazing Industrial 4 bedroom Loft', 'accommodates': 10},
#  {'name': 'Awesome house in the west side of Rio de Janeiro',
#   'accommodates': 8},
#  {'name': 'Rare 2 Bedroom + Loft Townhouse on the North Shore',
#   'accommodates': 8},
#  {'name': 'Kai uli Beachfront Estate Laumilo', 'accommodates': 16},
#  {'name': 'Pardal Apartment by JC', 'accommodates': 12},
#  {'name': 'Amazing Duplex with Big Terrace *4BD', 'accommodates': 10},
#  {'name': 'BCN Duplex Sagrada Familia', 'accommodates': 9},
#  {'name': 'Alii Estate- Luxury 4 Acres- Walk to Beach', 'accommodates': 10},
#  {'name': 'BCN Duplex Mirò Monthly', 'accommodates': 8},
#  {'name': 'KT4B2 觀塘派對場地 PARTY ROOM', 'accommodates': 16},
#  {'name': '★ RARE - gigantic Montreal nest ★ MTL life - @Prefontaine E',
#   'accommodates': 14},
#  {'name': 'DOWNTOWN ON St. CATHERINE!', 'accommodates': 16},
#  {'name': 'O:Neat & relaxing unit, 10pax max, fast speed WiFi',
#   'accommodates': 10},
#  {'name': 'Salim Bey Apartments', 'accommodates': 8},
#  {'name': 'DISPONÍVEL Carnaval! 4 Qtos P/ toda a família!!!',
#   'accommodates': 10},
#  {'name': 'Casa do Castelo Fermedo,Arouca,preço quarto duplo',
#   'accommodates': 12},
#  {'name': 'Bondi Abode w/swimming pool', 'accommodates': 8},
#  {'name': 'Duplex penthouse with pool in Meier', 'accommodates': 10},
#  {'name': 'D3 - Centro Ciudad / Pº de Gracia', 'accommodates': 10},
#  {'name': 'Wonderful apt overlooking the sea', 'accommodates': 8},
#  {'name': 'Big house at Copacabana beach, 8 bedrooms', 'accommodates': 16},
#  {'name': 'Spacious house w/pool in Sydney', 'accommodates': 8},
#  {'name': 'MALL OF İSTANBUL 3+1 RENTAL DAY', 'accommodates': 7},
#  {'name': 'Magnífica casa.Vista espetacular!', 'accommodates': 10},
#  {'name': 'Roof top apartment BEST LOCATION', 'accommodates': 8}]

# %% [markdown]
# ## Question 6
#
# Return the document where the "accomoodates" is greater than 3 and less than 6, and "amenities" value where that does not contain a "TV" nor "Internet" and "number_of_reviews" greater than or equal to 22. Only return the name, accomodates, amenities and number_of_reviews fields and sort by the number_of_reviews field descending. Limit to 1 result.
#
# ~~~
# Syntax: { field: { $nin: [ <value1>, <value2> ... <valueN> ]} }
# ~~~

# %%
list(
    airbnb.find({
        "accommodates":{"$gt":1,"$lt":6},
        "amenities":{"$nin":["TV","Internet"]},
        "number_of_reviews":{"$gt":22}
    },{'_id':0,"name":1,"accommodates":1,"amenities":1,"number_of_reviews":1})
)
# Out:
# [{'name': 'Cozy house at Beyoğlu',
#   'accommodates': 2,
#   'number_of_reviews': 27,
#   'amenities': ['Wifi',
#    'Kitchen',
#    'Smoking allowed',
#    'Breakfast',
#    'Pets live on this property',
#    'Cat(s)',
#    'Free street parking',
#    'Heating',
#    'Washer',
#    'Essentials',
#    'Shampoo',
#    'Lock on bedroom door',
#    'Hangers',
#    'Hair dryer',
#    'Iron',
#    'Laptop friendly workspace',
#    'Hot water',
#    'Bed linens',
#    'Extra pillows and blankets',
#    'Coffee maker',
#    'Refrigerator',
#    'Dishwasher',
#    'Cooking basics',
#    'Patio or balcony',
#    'Luggage dropoff allowed',
#    'Host greets you']},
#  {'name': 'A bedroom far away from home',
#   'accommodates': 2,
#   'number_of_reviews': 239,
#   'amenities': ['Wifi',
#    'Kitchen',
#    'Free street parking',
#    'Heating',
#    'Family/kid friendly',
#    'Smoke detector',
#    'Carbon monoxide detector',
#    'Essentials',
#    'Shampoo',
#    'Lock on bedroom door',
#    'Hangers',
#    'Hair dryer',
#    'Iron',
#    'Laptop friendly workspace',
#    'translation missing: en.hosting_amenity_50',
#    'Private entrance',
#    'Hot water',
#    'Host greets you']},
#  {'name': 'DOUBLE ROOM IN THE HEART OF BCN',
#   'accommodates': 2,
#   'number_of_reviews': 108,
#   'amenities': ['Wifi',
#    'Kitchen',
#    'Paid parking off premises',
#    'Smoking allowed',
#    'Heating',
#    'Washer',
#    'Essentials',
#    'Shampoo',
#    'Lock on bedroom door',
#    'Hangers',
#    'Hair dryer',
#    'Iron',
#    'translation missing: en.hosting_amenity_49',
#    'translation missing: en.hosting_amenity_50',
#    'Hot water',
#    'Bed linens',
#    'Host greets you']},
#  {'name': 'Triple room Barcelona Guell park',
#   'accommodates': 3,
#   'number_of_reviews': 191,
#   'amenities': ['Wifi',
#    'Paid parking off premises',
#    'Pets live on this property',
#    'Cat(s)',
#    'Elevator',
#    'Heating',
#    'Family/kid friendly',
#    'Fire extinguisher',
#    'Essentials',
#    'Hangers',
#    'Hair dryer',
#    'Hot water',
#    'Host greets you']},
#  {'name': 'habitación doble tranquila con luz',
#   'accommodates': 2,
#   'number_of_reviews': 23,
#   'amenities': ['Wifi',
#    'Free parking on premises',
#    'Smoking allowed',
#    'Elevator',
#    'Free street parking',
#    'Buzzer/wireless intercom',
#    'Heating',
#    'Family/kid friendly',
#    'Essentials',
#    'Hot water',
#    'Host greets you']},
#  {'name': 'Cozy Chinatown studio apartment',
#   'accommodates': 2,
#   'number_of_reviews': 26,
#   'amenities': ['Wifi',
#    'Air conditioning',
#    'Kitchen',
#    'Heating',
#    'Family/kid friendly',
#    'Smoke detector',
#    'Fire extinguisher',
#    'Essentials',
#    'Shampoo',
#    'Hangers',
#    'Hair dryer',
#    'Laptop friendly workspace',
#    'translation missing: en.hosting_amenity_50',
#    'Refrigerator',
#    'Cooking basics',
#    'Oven',
#    'Stove',
#    'Long term stays allowed']},
#  {'name': 'Fabulous occasion orange',
#   'accommodates': 2,
#   'number_of_reviews': 163,
#   'amenities': ['Wifi',
#    'Kitchen',
#    'Pets allowed',
#    'Elevator',
#    'Heating',
#    'Smoke detector',
#    'Fire extinguisher',
#    'Essentials',
#    'Shampoo',
#    'Hangers',
#    'Hair dryer',
#    'translation missing: en.hosting_amenity_50',
#    'Hot water',
#    'Bed linens',
#    'Microwave',
#    'Coffee maker',
#    'Refrigerator',
#    'Dishes and silverware',
#    'Long term stays allowed',
#    'Host greets you']},
#  {'name': 'Eco Hale Hawaii in the Rainforest Lots Of Aloha',
#   'accommodates': 2,
#   'number_of_reviews': 291,
#   'amenities': ['Wifi',
#    'Kitchen',
#    'Free parking on premises',
#    'Breakfast',
#    'Hot tub',
#    'Family/kid friendly',
#    'Smoke detector',
#    'Carbon monoxide detector',
#    'First aid kit',
#    'Safety card',
#    'Fire extinguisher',
#    'Essentials',
#    'Shampoo',
#    'Hangers',
#    'translation missing: en.hosting_amenity_50',
#    'Private entrance',
#    'Hot water',
#    'Bed linens',
#    'Extra pillows and blankets',
#    'Microwave',
#    'Coffee maker',
#    'Refrigerator',
#    'Dishes and silverware',
#    'Cooking basics',
#    'Stove',
#    'Patio or balcony',
#    'Garden or backyard',
#    'Beach essentials',
#    'Long term stays allowed',
#    'Well-lit path to entrance',
#    'Host greets you']},
#  {'name': 'Lovely twin room in central flat',
#   'accommodates': 2,
#   'number_of_reviews': 93,
#   'amenities': ['Wifi',
#    'Pets allowed',
#    'Elevator',
#    'Heating',
#    'Family/kid friendly',
#    'Essentials',
#    'Host greets you']},
#  {'name': 'Habitación indiv con cama extra',
#   'accommodates': 2,
#   'number_of_reviews': 79,
#   'amenities': ['Wifi',
#    'Kitchen',
#    'Elevator',
#    'Heating',
#    'Family/kid friendly',
#    'Essentials',
#    'Shampoo',
#    'Hangers',
#    'Hair dryer',
#    'Iron',
#    'Laptop friendly workspace',
#    'translation missing: en.hosting_amenity_50',
#    'Hot water',
#    'Bed linens',
#    'Extra pillows and blankets',
#    'Coffee maker',
#    'Refrigerator',
#    'Dishes and silverware',
#    'Luggage dropoff allowed',
#    'Wide hallway clearance',
#    'Paid parking on premises']},
#  {'name': '★Union Square, Brand New★#F, Free W/D',
#   'accommodates': 4,
#   'number_of_reviews': 62,
#   'amenities': ['Wifi',
#    'Air conditioning',
#    'Kitchen',
#    'Heating',
#    'Washer',
#    'Dryer',
#    'Smoke detector',
#    'Carbon monoxide detector',
#    'Fire extinguisher',
#    'Essentials',
#    'Lock on bedroom door',
#    'Hangers',
#    'Hair dryer',
#    'Iron',
#    'Laptop friendly workspace',
#    'translation missing: en.hosting_amenity_49',
#    'translation missing: en.hosting_amenity_50']},
#  {'name': 'Cozy, Convenient 1 Bed Apartment!!! UWS Manhattan',
#   'accommodates': 3,
#   'number_of_reviews': 29,
#   'amenities': ['Wifi',
#    'Air conditioning',
#    'Kitchen',
#    'Gym',
#    'Elevator',
#    'Heating',
#    'Family/kid friendly',
#    'Washer',
#    'Dryer',
#    'Smoke detector',
#    'Carbon monoxide detector',
#    'Essentials',
#    'Shampoo',
#    'Hangers',
#    'Hair dryer',
#    'Iron',
#    'Laptop friendly workspace',
#    'Hot water',
#    'Bed linens',
#    'Ethernet connection',
#    'Microwave',
#    'Refrigerator',
#    'Dishes and silverware',
#    'Cooking basics',
#    'Stove',
#    'Garden or backyard',
#    'Long term stays allowed',
#    'Other',
#    'Paid parking on premises']},
#  {'name': 'bonita y comoda habitacion en el piso céntrico',
#   'accommodates': 2,
#   'number_of_reviews': 66,
#   'amenities': ['Wifi',
#    'Kitchen',
#    'Heating',
#    'Essentials',
#    'Hangers',
#    'Hair dryer',
#    'translation missing: en.hosting_amenity_49',
#    'translation missing: en.hosting_amenity_50']},
#  {'name': 'Sunny appartment on the Plateau',
#   'accommodates': 2,
#   'number_of_reviews': 81,
#   'amenities': ['Wifi',
#    'Kitchen',
#    'Free parking on premises',
#    'Breakfast',
#    'Buzzer/wireless intercom',
#    'Heating',
#    'Family/kid friendly',
#    'Washer',
#    'Dryer',
#    'Smoke detector',
#    'Fire extinguisher',
#    'Essentials',
#    'Hair dryer',
#    'Iron',
#    'Laptop friendly workspace',
#    'Hot water',
#    'Other']},
#  {'name': 'Newly renovated studio in hip Bushwick near subway',
#   'accommodates': 4,
#   'number_of_reviews': 131,
#   'amenities': ['Wifi',
#    'Air conditioning',
#    'Kitchen',
#    'Heating',
#    'Family/kid friendly',
#    'Smoke detector',
#    'Carbon monoxide detector',
#    'Essentials',
#    'Shampoo',
#    'Hangers',
#    'Hair dryer',
#    'Laptop friendly workspace',
#    'translation missing: en.hosting_amenity_50',
#    'Self check-in',
#    'Smart lock']},
#  {'name': 'the shoebox, west chelsea',
#   'accommodates': 2,
#   'number_of_reviews': 99,
#   'amenities': ['Wifi',
#    'Air conditioning',
#    'Kitchen',
#    'Elevator',
#    'Buzzer/wireless intercom',
#    'Heating',
#    'Essentials',
#    'Hangers',
#    'Hair dryer',
#    'Iron',
#    'Laptop friendly workspace',
#    'translation missing: en.hosting_amenity_49',
#    'translation missing: en.hosting_amenity_50',
#    'Host greets you']},
#  {'name': 'Treehouse with Incredible Views',
#   'accommodates': 4,
#   'number_of_reviews': 31,
#   'amenities': ['Wifi',
#    'Air conditioning',
#    'Kitchen',
#    'Free parking on premises',
#    'Free street parking',
#    'Smoke detector',
#    'Fire extinguisher',
#    'Essentials',
#    'Shampoo',
#    'Hangers',
#    'Laptop friendly workspace',
#    'translation missing: en.hosting_amenity_49',
#    'translation missing: en.hosting_amenity_50',
#    'Private entrance',
#    'Hot water',
#    'Bed linens',
#    'Extra pillows and blankets',
#    'Microwave',
#    'Refrigerator',
#    'Dishes and silverware',
#    'Oven',
#    'Patio or balcony',
#    'Garden or backyard',
#    'Beach essentials',
#    'Luggage dropoff allowed',
#    'Long term stays allowed',
#    'Wide doorway',
#    'Well-lit path to entrance',
#    'Wide doorway',
#    'Wide doorway',
#    'Wide entryway']},
#  {'name': 'Private cabin',
#   'accommodates': 2,
#   'number_of_reviews': 24,
#   'amenities': ['Wifi',
#    'Air conditioning',
#    'Kitchen',
#    'Pets allowed',
#    'Breakfast',
#    'Heating',
#    'Washer',
#    'Dryer',
#    'Smoke detector',
#    'First aid kit',
#    'Fire extinguisher',
#    'Essentials',
#    'Shampoo',
#    'Lock on bedroom door',
#    'Hangers',
#    'Hair dryer',
#    'Iron',
#    'Laptop friendly workspace',
#    'translation missing: en.hosting_amenity_49',
#    'translation missing: en.hosting_amenity_50']},
#  {'name': 'Apartment located near Guell park',
#   'accommodates': 2,
#   'number_of_reviews': 63,
#   'amenities': ['Wifi',
#    'Pets live on this property',
#    'Essentials',
#    'Hair dryer',
#    'Host greets you']},
#  {'name': 'At Home in Authentic Porto',
#   'accommodates': 4,
#   'number_of_reviews': 124,
#   'amenities': ['Wifi',
#    'Kitchen',
#    'Pets allowed',
#    'Elevator',
#    'Heating',
#    'Family/kid friendly',
#    'Washer',
#    'Smoke detector',
#    'Carbon monoxide detector',
#    'First aid kit',
#    'Essentials',
#    'Shampoo',
#    'Hangers',
#    'Laptop friendly workspace',
#    'Hot water',
#    'Bed linens']},
#  {'name': 'Private Room in Renovated Library w/ Swimming Pool',
#   'accommodates': 2,
#   'number_of_reviews': 89,
#   'amenities': ['Wifi',
#    'Pool',
#    'Free parking on premises',
#    'Breakfast',
#    'Pets live on this property',
#    'Dog(s)',
#    'Heating',
#    'Family/kid friendly',
#    'Washer',
#    'Dryer',
#    'First aid kit',
#    'Essentials',
#    'Shampoo',
#    'Lock on bedroom door',
#    'Hangers',
#    'Hair dryer',
#    'Iron',
#    'Laptop friendly workspace',
#    'Self check-in',
#    'Building staff',
#    'Private entrance',
#    'Hot water',
#    'Bed linens',
#    'Extra pillows and blankets',
#    'Refrigerator',
#    'Single level home',
#    'Garden or backyard',
#    'Luggage dropoff allowed',
#    'Long term stays allowed',
#    'Step-free access',
#    'Wide doorway',
#    'Well-lit path to entrance',
#    'Step-free access',
#    'Accessible-height bed',
#    'Step-free access',
#    'Step-free access',
#    'Wide entryway']},
#  {'name': 'Share a flat in a lovely penthouse with terrace',
#   'accommodates': 2,
#   'number_of_reviews': 23,
#   'amenities': ['Wifi',
#    'Pool',
#    'Kitchen',
#    'Paid parking off premises',
#    'Smoking allowed',
#    'Pets allowed',
#    'Breakfast',
#    'Buzzer/wireless intercom',
#    'Family/kid friendly',
#    'Washer',
#    'Smoke detector',
#    'First aid kit',
#    'Essentials',
#    'Shampoo',
#    'Hair dryer',
#    'Laptop friendly workspace',
#    'Babysitter recommendations',
#    'Hot water',
#    'Microwave',
#    'Coffee maker',
#    'Refrigerator',
#    'Dishwasher',
#    'Dishes and silverware',
#    'Cooking basics',
#    'Oven',
#    'Stove',
#    'BBQ grill',
#    'Patio or balcony',
#    'Beach essentials',
#    'Luggage dropoff allowed',
#    'Cleaning before checkout',
#    'Well-lit path to entrance',
#    'Other']},
#  {'name': 'Bright and quiet room with private bathroom',
#   'accommodates': 2,
#   'number_of_reviews': 100,
#   'amenities': ['Wifi',
#    'Air conditioning',
#    'Kitchen',
#    'Elevator',
#    'Heating',
#    'Family/kid friendly',
#    'Washer',
#    'Dryer',
#    'Smoke detector',
#    'First aid kit',
#    'Fire extinguisher',
#    'Essentials',
#    'Shampoo',
#    'Hangers',
#    'Hair dryer',
#    'Iron',
#    'Laptop friendly workspace',
#    'translation missing: en.hosting_amenity_50',
#    'Hot water',
#    'Bed linens',
#    'Extra pillows and blankets',
#    'Microwave',
#    'Refrigerator',
#    'Dishwasher',
#    'Dishes and silverware',
#    'Cooking basics',
#    'Oven',
#    'Stove',
#    'Patio or balcony',
#    'Luggage dropoff allowed',
#    'Long term stays allowed',
#    'Other']},
#  {'name': 'Cozy In The Heart Of The Plateau',
#   'accommodates': 2,
#   'number_of_reviews': 112,
#   'amenities': ['Wifi',
#    'Kitchen',
#    'Paid parking off premises',
#    'Pets live on this property',
#    'Cat(s)',
#    'Free street parking',
#    'Heating',
#    'Family/kid friendly',
#    'Washer',
#    'Smoke detector',
#    'Essentials',
#    'Shampoo',
#    'Hangers',
#    'Hair dryer',
#    'Iron',
#    'Self check-in',
#    'Smart lock',
#    'Bathtub',
#    'Hot water',
#    'Bed linens',
#    'Coffee maker',
#    'Refrigerator',
#    'Dishes and silverware',
#    'Cooking basics',
#    'Oven',
#    'Stove',
#    'Patio or balcony',
#    'Luggage dropoff allowed',
#    'Long term stays allowed']},
#  {'name': 'Cozy Well-Furnished Home in the Heart of Harlem',
#   'accommodates': 2,
#   'number_of_reviews': 120,
#   'amenities': ['Wifi',
#    'Kitchen',
#    'Gym',
#    'Breakfast',
#    'Elevator',
#    'Heating',
#    'Family/kid friendly',
#    'Smoke detector',
#    'Carbon monoxide detector',
#    'First aid kit',
#    'Fire extinguisher',
#    'Essentials',
#    'Shampoo',
#    'Hangers',
#    'Hair dryer',
#    'Iron',
#    'Laptop friendly workspace',
#    'Hot water',
#    'Bed linens',
#    'Extra pillows and blankets',
#    'Microwave',
#    'Coffee maker',
#    'Refrigerator',
#    'Dishwasher',
#    'Dishes and silverware',
#    'Cooking basics',
#    'Oven',
#    'Stove',
#    'Luggage dropoff allowed',
#    'Long term stays allowed',
#    'Wide hallway clearance',
#    'Well-lit path to entrance',
#    'Step-free access',
#    'Step-free access',
#    'Host greets you']},
#  {'name': 'Lovely sydney CBD heart studio with a balcony',
#   'accommodates': 2,
#   'number_of_reviews': 27,
#   'amenities': ['Wifi',
#    'Air conditioning',
#    'Pool',
#    'Kitchen',
#    'Gym',
#    'Elevator',
#    'Heating',
#    'Washer',
#    'Dryer',
#    'Smoke detector',
#    'Essentials',
#    'Shampoo',
#    'Hangers',
#    'Hair dryer',
#    'Iron',
#    'Laptop friendly workspace',
#    'translation missing: en.hosting_amenity_49',
#    'translation missing: en.hosting_amenity_50',
#    'Hot water',
#    'Bed linens',
#    'Extra pillows and blankets',
#    'Microwave',
#    'Refrigerator',
#    'Dishwasher',
#    'Dishes and silverware',
#    'Cooking basics',
#    'Oven',
#    'Stove',
#    'Patio or balcony',
#    'Luggage dropoff allowed',
#    'Wide hallway clearance',
#    'Step-free access',
#    'Wide doorway',
#    'Flat path to front door',
#    'Well-lit path to entrance',
#    'Step-free access',
#    'Wide doorway',
#    'Wide clearance to bed',
#    'Step-free access',
#    'Wide doorway',
#    'Accessible-height toilet',
#    'Step-free access',
#    'Wide entryway',
#    'Handheld shower head']},
#  {'name': "Mike's House- Hina Room",
#   'accommodates': 2,
#   'number_of_reviews': 192,
#   'amenities': ['Cable TV',
#    'Wifi',
#    'Kitchen',
#    'Free parking on premises',
#    'Pets live on this property',
#    'Cat(s)',
#    'Family/kid friendly',
#    'Washer',
#    'Dryer',
#    'Smoke detector',
#    'First aid kit',
#    'Fire extinguisher',
#    'Essentials',
#    'Shampoo',
#    'Lock on bedroom door',
#    'Hangers',
#    'Hair dryer',
#    'Iron',
#    'Self check-in',
#    'Keypad']},
#  {'name': 'Lovely room with the best location ever!',
#   'accommodates': 2,
#   'number_of_reviews': 28,
#   'amenities': ['Wifi',
#    'Kitchen',
#    'Smoking allowed',
#    'Family/kid friendly',
#    'Washer',
#    'Essentials',
#    'Shampoo',
#    'Lock on bedroom door',
#    'Hangers']},
#  {'name': 'Lovely and quiet doble room in the center of BCN',
#   'accommodates': 2,
#   'number_of_reviews': 48,
#   'amenities': ['Wifi',
#    'Elevator',
#    'Essentials',
#    'Laptop friendly workspace',
#    'translation missing: en.hosting_amenity_49',
#    'translation missing: en.hosting_amenity_50',
#    'Host greets you']},
#  {'name': 'Arc del Triomf - Big double room in authentic flat',
#   'accommodates': 2,
#   'number_of_reviews': 46,
#   'amenities': ['Wifi',
#    'Kitchen',
#    'Elevator',
#    'Washer',
#    'Essentials',
#    'Shampoo',
#    'Lock on bedroom door',
#    'Hangers',
#    'Hair dryer',
#    'Iron',
#    'Private entrance',
#    'Hot water',
#    'Bed linens',
#    'Extra pillows and blankets',
#    'Microwave',
#    'Coffee maker',
#    'Refrigerator',
#    'Dishes and silverware',
#    'Cooking basics',
#    'Oven',
#    'Paid parking on premises']},
#  {'name': 'North Shore Beach Bungalow Just Steps to the Sand!',
#   'accommodates': 4,
#   'number_of_reviews': 123,
#   'amenities': ['Wifi',
#    'Air conditioning',
#    'Free parking on premises',
#    'Free street parking',
#    'Family/kid friendly',
#    'Smoke detector',
#    'First aid kit',
#    'Fire extinguisher',
#    'Essentials',
#    'Shampoo',
#    'Lock on bedroom door',
#    'Hangers',
#    'Hair dryer',
#    'Laptop friendly workspace',
#    'Babysitter recommendations',
#    'Hot water',
#    'Bed linens',
#    'Extra pillows and blankets',
#    'Coffee maker',
#    'Refrigerator',
#    'Dishes and silverware',
#    'Single level home',
#    'Patio or balcony',
#    'Garden or backyard',
#    'Beach essentials',
#    'Long term stays allowed',
#    'Wide hallway clearance',
#    'Step-free access',
#    'Wide doorway',
#    'Flat path to front door',
#    'Well-lit path to entrance',
#    'Step-free access',
#    'Wide doorway',
#    'Wide clearance to bed',
#    'Accessible-height bed',
#    'Step-free access',
#    'Wide doorway',
#    'Accessible-height toilet',
#    'Wide clearance to shower',
#    'toilet',
#    'Step-free access',
#    'Wide entryway',
#    'Other',
#    'Handheld shower head']},
#  {'name': 'True East Village Art Filled 2 Bedroom with Garden',
#   'accommodates': 5,
#   'number_of_reviews': 66,
#   'amenities': ['Wifi',
#    'Air conditioning',
#    'Kitchen',
#    'Heating',
#    'Smoke detector',
#    'Carbon monoxide detector',
#    'First aid kit',
#    'Safety card',
#    'Fire extinguisher',
#    'Essentials',
#    'Lock on bedroom door',
#    'Hangers',
#    'Hair dryer',
#    'Iron',
#    'Laptop friendly workspace',
#    'translation missing: en.hosting_amenity_49',
#    'translation missing: en.hosting_amenity_50',
#    'Hot water',
#    'Host greets you']},
#  {'name': 'Bright room in sagrada familia',
#   'accommodates': 2,
#   'number_of_reviews': 124,
#   'amenities': ['Wifi',
#    'Air conditioning',
#    'Smoking allowed',
#    'Heating',
#    'Essentials',
#    'Shampoo',
#    'Hangers',
#    'Hair dryer',
#    'Iron',
#    'Laptop friendly workspace',
#    'translation missing: en.hosting_amenity_49',
#    'translation missing: en.hosting_amenity_50',
#    'Hot water',
#    'Bed linens',
#    'Extra pillows and blankets',
#    'Pocket wifi',
#    'Coffee maker',
#    'Refrigerator',
#    'Dishes and silverware',
#    'Cooking basics',
#    'Luggage dropoff allowed',
#    'Long term stays allowed',
#    'Host greets you',
#    'Paid parking on premises']},
#  {'name': 'Cozy room in Sagrada Familia',
#   'accommodates': 2,
#   'number_of_reviews': 99,
#   'amenities': ['Wifi',
#    'Air conditioning',
#    'Kitchen',
#    'Smoking allowed',
#    'Heating',
#    'Essentials',
#    'Shampoo',
#    'Hair dryer',
#    'Iron',
#    'Laptop friendly workspace',
#    'translation missing: en.hosting_amenity_50',
#    'Hot water',
#    'Bed linens',
#    'Extra pillows and blankets',
#    'Pocket wifi',
#    'Refrigerator',
#    'Dishes and silverware',
#    'Host greets you',
#    'Paid parking on premises']},
#  {'name': 'Thelonious Monk room at The Harlem Townhouse',
#   'accommodates': 2,
#   'number_of_reviews': 62,
#   'amenities': ['Wifi',
#    'Indoor fireplace',
#    'Heating',
#    'Family/kid friendly',
#    'Smoke detector',
#    'Carbon monoxide detector',
#    'Essentials',
#    'Lock on bedroom door',
#    'Hangers',
#    'Laptop friendly workspace']},
#  {'name': 'Cozy, separated living room in Prospect Park, NYC',
#   'accommodates': 2,
#   'number_of_reviews': 40,
#   'amenities': ['Wifi',
#    'Air conditioning',
#    'Kitchen',
#    'Heating',
#    'Smoke detector',
#    'Essentials',
#    'Hangers',
#    'Laptop friendly workspace',
#    'translation missing: en.hosting_amenity_49',
#    'translation missing: en.hosting_amenity_50',
#    'Self check-in',
#    'Lockbox']},
#  {'name': 'Bright and quiet bedroom - heart of Mile End',
#   'accommodates': 2,
#   'number_of_reviews': 92,
#   'amenities': ['Wifi',
#    'Free street parking',
#    'Heating',
#    'Smoke detector',
#    'Essentials',
#    'Shampoo',
#    'Hangers',
#    'Hair dryer',
#    'Iron',
#    'translation missing: en.hosting_amenity_49',
#    'translation missing: en.hosting_amenity_50',
#    'Self check-in',
#    'Lockbox',
#    'Hot water',
#    'Microwave',
#    'Coffee maker',
#    'Refrigerator',
#    'Patio or balcony',
#    'Host greets you']},
#  {'name': 'YOUR SUNNY DOUBLE BEDROOM IN THE CENTER',
#   'accommodates': 2,
#   'number_of_reviews': 44,
#   'amenities': ['Wifi',
#    'Elevator',
#    'Buzzer/wireless intercom',
#    'Heating',
#    'Essentials',
#    'Shampoo',
#    'Lock on bedroom door',
#    '24-hour check-in',
#    'Hangers',
#    'Hair dryer',
#    'Iron',
#    'Laptop friendly workspace',
#    'translation missing: en.hosting_amenity_49',
#    'translation missing: en.hosting_amenity_50',
#    'Hot water',
#    'Bed linens',
#    'Extra pillows and blankets',
#    'Wide hallway clearance',
#    'Host greets you']},
#  {'name': 'Old School Hospitality',
#   'accommodates': 4,
#   'number_of_reviews': 61,
#   'amenities': ['Wifi',
#    'Kitchen',
#    'Free parking on premises',
#    'Family/kid friendly',
#    'Washer',
#    'Smoke detector',
#    'First aid kit',
#    'Safety card',
#    'Fire extinguisher',
#    'Essentials',
#    'Shampoo',
#    'Hangers',
#    'Hair dryer',
#    'Iron',
#    'Laptop friendly workspace',
#    'translation missing: en.hosting_amenity_50',
#    'Self check-in',
#    'Lockbox',
#    'Private entrance']},
#  {'name': 'Outstanding Glebe Apartment',
#   'accommodates': 4,
#   'number_of_reviews': 99,
#   'amenities': ['Wifi',
#    'Family/kid friendly',
#    'Washer',
#    'Essentials',
#    'Shampoo',
#    'Hangers',
#    'Hair dryer',
#    'Laptop friendly workspace',
#    'Self check-in',
#    'Keypad']},
#  {'name': 'Luminous Vintage Room near Plaza España',
#   'accommodates': 2,
#   'number_of_reviews': 87,
#   'amenities': ['Wifi',
#    'Kitchen',
#    'Paid parking off premises',
#    'Elevator',
#    'Free street parking',
#    'Buzzer/wireless intercom',
#    'Heating',
#    'First aid kit',
#    'Safety card',
#    'Essentials',
#    'Shampoo',
#    'Lock on bedroom door',
#    'Hangers',
#    'Hair dryer',
#    'Iron',
#    'translation missing: en.hosting_amenity_49',
#    'translation missing: en.hosting_amenity_50',
#    'Private entrance',
#    'Hot water',
#    'Bed linens',
#    'Extra pillows and blankets',
#    'Microwave',
#    'Coffee maker',
#    'Refrigerator',
#    'Dishes and silverware',
#    'Luggage dropoff allowed',
#    'Host greets you']},
#  {'name': 'Bright & spacious 2 bed near Molson Park w/parking',
#   'accommodates': 4,
#   'number_of_reviews': 37,
#   'amenities': ['Wifi',
#    'Kitchen',
#    'Free parking on premises',
#    'Heating',
#    'Family/kid friendly',
#    'Washer',
#    'Dryer',
#    'Smoke detector',
#    'Essentials',
#    'Hangers',
#    'Hair dryer',
#    'Private living room',
#    'Private entrance',
#    'Hot water',
#    'Bed linens',
#    'Extra pillows and blankets',
#    'Microwave',
#    'Coffee maker',
#    'Refrigerator',
#    'Dishwasher',
#    'Dishes and silverware',
#    'Cooking basics',
#    'Oven',
#    'Stove',
#    'Patio or balcony',
#    'Luggage dropoff allowed',
#    'Long term stays allowed']},
#  {'name': 'Perfect Place To Rest, Close to All in NYC!',
#   'accommodates': 2,
#   'number_of_reviews': 84,
#   'amenities': ['Wifi',
#    'Air conditioning',
#    'Kitchen',
#    'Heating',
#    'Family/kid friendly',
#    'Smoke detector',
#    'Carbon monoxide detector',
#    'First aid kit',
#    'Fire extinguisher',
#    'Essentials',
#    'Lock on bedroom door',
#    'Hangers',
#    'Hair dryer',
#    'Iron',
#    'Laptop friendly workspace',
#    'Self check-in',
#    'Keypad',
#    'Microwave',
#    'Coffee maker',
#    'Refrigerator',
#    'Dishes and silverware',
#    'Oven',
#    'Stove']},
#  {'name': 'Baixa 24 - Room 3',
#   'accommodates': 4,
#   'number_of_reviews': 91,
#   'amenities': ['Wifi',
#    'Kitchen',
#    'Breakfast',
#    'Free street parking',
#    'Heating',
#    'Family/kid friendly',
#    'Washer',
#    'First aid kit',
#    'Fire extinguisher',
#    'Essentials',
#    'Shampoo',
#    'Lock on bedroom door',
#    'Hangers',
#    'Hair dryer',
#    'Iron',
#    'Laptop friendly workspace',
#    'Self check-in',
#    'Keypad',
#    'Private living room',
#    'Bathtub',
#    'High chair',
#    'Children’s books and toys',
#    'Pack ’n Play/travel crib',
#    'Hot water',
#    'Bed linens']},
#  {'name': 'Downtown Penthouse, 2 Bedrooms 2 bathrooms',
#   'accommodates': 4,
#   'number_of_reviews': 40,
#   'amenities': ['Wifi',
#    'Pool',
#    'Kitchen',
#    'Free parking on premises',
#    'Smoking allowed',
#    'Elevator',
#    'Heating',
#    'Family/kid friendly',
#    'Washer',
#    'Dryer',
#    'Smoke detector',
#    'First aid kit',
#    'Essentials',
#    'Shampoo',
#    'Hangers',
#    'Hair dryer',
#    'Laptop friendly workspace',
#    'Self check-in',
#    'Lockbox',
#    'Hot water',
#    'Bed linens',
#    'Extra pillows and blankets',
#    'Coffee maker',
#    'Refrigerator',
#    'Dishes and silverware',
#    'Cooking basics',
#    'Oven',
#    'Stove',
#    'Patio or balcony']},
#  {'name': 'Rustic & cozy 1bedroom flat in Le Plateau',
#   'accommodates': 3,
#   'number_of_reviews': 111,
#   'amenities': ['Wifi',
#    'Kitchen',
#    'Heating',
#    'Family/kid friendly',
#    'Smoke detector',
#    'First aid kit',
#    'Essentials',
#    'Shampoo',
#    'Lock on bedroom door',
#    'Hangers',
#    'Hair dryer',
#    'Iron',
#    'Laptop friendly workspace',
#    'Self check-in',
#    'Lockbox',
#    'Private living room',
#    'Private entrance',
#    'Bathtub',
#    'High chair',
#    'Children’s books and toys',
#    'Babysitter recommendations',
#    'Pack ’n Play/travel crib',
#    'Children’s dinnerware',
#    'Hot water',
#    'Bed linens',
#    'Microwave',
#    'Coffee maker',
#    'Refrigerator',
#    'Dishes and silverware',
#    'Cooking basics',
#    'Oven',
#    'Stove',
#    'Garden or backyard',
#    'Luggage dropoff allowed',
#    'Long term stays allowed']},
#  {'name': 'Wonderful double-room centrally located',
#   'accommodates': 2,
#   'number_of_reviews': 32,
#   'amenities': ['Wifi',
#    'Paid parking off premises',
#    'Breakfast',
#    'Heating',
#    'First aid kit',
#    'Essentials',
#    'Shampoo',
#    'Lock on bedroom door',
#    'Hangers',
#    'Hair dryer',
#    'Iron',
#    'Laptop friendly workspace',
#    'translation missing: en.hosting_amenity_49',
#    'translation missing: en.hosting_amenity_50',
#    'Hot water',
#    'Extra pillows and blankets',
#    'Microwave',
#    'Refrigerator',
#    'Dishes and silverware',
#    'Well-lit path to entrance',
#    'Step-free access',
#    'Wide doorway',
#    'Wide clearance to bed',
#    'Accessible-height bed',
#    'Step-free access',
#    'Accessible-height toilet',
#    'Host greets you']},
#  {'name': "Appart d'artiste coquet, chaleureux et lumineux",
#   'accommodates': 3,
#   'number_of_reviews': 53,
#   'amenities': ['Wifi',
#    'Kitchen',
#    'Free street parking',
#    'Heating',
#    'Essentials',
#    'Shampoo',
#    'Hangers',
#    'Hair dryer',
#    'Laptop friendly workspace',
#    'Self check-in',
#    'Lockbox',
#    'Private entrance',
#    'Hot water',
#    'Bed linens']},
#  {'name': 'Private room with double bed next to Plaza Espana',
#   'accommodates': 3,
#   'number_of_reviews': 49,
#   'amenities': ['Wifi',
#    'Kitchen',
#    'Paid parking off premises',
#    'Smoking allowed',
#    'Washer',
#    'First aid kit',
#    'Essentials',
#    'Shampoo',
#    'Hangers',
#    'Hair dryer',
#    'Iron',
#    'Private entrance',
#    'Hot water',
#    'Bed linens',
#    'Microwave',
#    'Refrigerator',
#    'Dishes and silverware',
#    'Cooking basics',
#    'Oven',
#    'Stove',
#    'Luggage dropoff allowed',
#    'Long term stays allowed',
#    'Well-lit path to entrance',
#    'Wide doorway',
#    'Wide clearance to bed',
#    'Accessible-height bed',
#    'Step-free access',
#    'Accessible-height toilet',
#    'Handheld shower head']},
#  {'name': '万利达旅馆A2',
#   'accommodates': 2,
#   'number_of_reviews': 23,
#   'amenities': ['Wifi',
#    'Air conditioning',
#    'Elevator',
#    'Washer',
#    'Fire extinguisher',
#    'Essentials',
#    'Shampoo',
#    'Hangers',
#    'Hair dryer']},
#  {'name': 'Fantastic Single Room',
#   'accommodates': 2,
#   'number_of_reviews': 37,
#   'amenities': ['Wifi',
#    'Air conditioning',
#    'Kitchen',
#    'Heating',
#    'Essentials',
#    'Lock on bedroom door',
#    'Hangers',
#    'Hair dryer',
#    'Iron',
#    'Laptop friendly workspace',
#    'Self check-in',
#    'Keypad',
#    'Hot water',
#    'Bed linens',
#    'Extra pillows and blankets']},
#  {'name': "Tootsie's Hideaway",
#   'accommodates': 2,
#   'number_of_reviews': 37,
#   'amenities': ['Wifi',
#    'Free parking on premises',
#    'Free street parking',
#    'Smoke detector',
#    'First aid kit',
#    'Safety card',
#    'Essentials',
#    'Shampoo',
#    'Lock on bedroom door',
#    'Hangers',
#    'Hair dryer',
#    'Iron',
#    'Laptop friendly workspace',
#    'Private entrance',
#    'Hot water',
#    'Bed linens',
#    'Extra pillows and blankets',
#    'Microwave',
#    'Refrigerator',
#    'Dishes and silverware',
#    'Patio or balcony',
#    'Garden or backyard',
#    'Luggage dropoff allowed',
#    'Long term stays allowed',
#    'Other']},
#  {'name': 'Da Grass Shack Lanai',
#   'accommodates': 4,
#   'number_of_reviews': 74,
#   'amenities': ['Wifi',
#    'Kitchen',
#    'Free parking on premises',
#    'Smoking allowed',
#    'Family/kid friendly',
#    'Smoke detector',
#    'First aid kit',
#    'Fire extinguisher',
#    'Essentials',
#    'Shampoo',
#    'Lock on bedroom door',
#    'Self check-in',
#    'Lockbox',
#    'Private entrance',
#    'Room-darkening shades',
#    'Hot water',
#    'Bed linens',
#    'Extra pillows and blankets',
#    'Refrigerator',
#    'Dishes and silverware',
#    'Cooking basics',
#    'Stove',
#    'BBQ grill',
#    'Patio or balcony',
#    'Long term stays allowed',
#    'Wide hallway clearance',
#    'Flat path to front door',
#    'Well-lit path to entrance',
#    'Step-free access',
#    'Accessible-height bed',
#    'Step-free access',
#    'Wide doorway',
#    'Accessible-height toilet',
#    'Wide clearance to shower',
#    'toilet',
#    'Step-free access',
#    'Wide entryway']},
#  {'name': 'Cheap Large Bedroom w/WorkDesk- 10min to JFK/Mall',
#   'accommodates': 2,
#   'number_of_reviews': 33,
#   'amenities': ['']},
#  {'name': 'DOWNTOWN/PLATEAU-SLEEPS 4-AMAZING LOCATION-QUIET!',
#   'accommodates': 4,
#   'number_of_reviews': 23,
#   'amenities': ['Wifi',
#    'Air conditioning',
#    'Kitchen',
#    'Paid parking off premises',
#    'Heating',
#    'Smoke detector',
#    'First aid kit',
#    'Fire extinguisher',
#    'Essentials',
#    'Shampoo',
#    'Hangers',
#    'Hair dryer',
#    'Iron',
#    'Laptop friendly workspace',
#    'Self check-in',
#    'Lockbox',
#    'Private living room',
#    'Bathtub',
#    'Pack ’n Play/travel crib',
#    'Room-darkening shades',
#    'Hot water',
#    'Bed linens',
#    'Extra pillows and blankets',
#    'Ethernet connection',
#    'Pocket wifi',
#    'Microwave',
#    'Coffee maker',
#    'Refrigerator',
#    'Dishes and silverware',
#    'Cooking basics',
#    'Oven',
#    'Stove',
#    'Patio or balcony',
#    'Luggage dropoff allowed',
#    'Long term stays allowed',
#    'Cleaning before checkout',
#    'Wide hallway clearance',
#    'Wide doorway',
#    'Well-lit path to entrance',
#    'Step-free access',
#    'Step-free access',
#    'Accessible-height toilet',
#    'Step-free access',
#    'Wide entryway']},
#  {'name': 'Studio w/rooftop in Sheung Wan HK (Man Mo temple)',
#   'accommodates': 2,
#   'number_of_reviews': 51,
#   'amenities': ['Wifi',
#    'Air conditioning',
#    'Kitchen',
#    'Heating',
#    'Essentials',
#    'Shampoo',
#    'Hangers',
#    'Hair dryer',
#    'Iron',
#    'Hot water',
#    'Bed linens',
#    'Extra pillows and blankets',
#    'Coffee maker',
#    'Refrigerator',
#    'Dishes and silverware',
#    'Cooking basics',
#    'Oven',
#    'Stove',
#    'Patio or balcony',
#    'Long term stays allowed',
#    'Host greets you']},
#  {'name': 'Chambre privée à deux pas du métro',
#   'accommodates': 2,
#   'number_of_reviews': 25,
#   'amenities': ['Wifi',
#    'Pool',
#    'Heating',
#    'Smoke detector',
#    'First aid kit',
#    'Fire extinguisher',
#    'Essentials',
#    'Lock on bedroom door',
#    'Hangers',
#    'Private living room',
#    'High chair',
#    'Microwave',
#    'Coffee maker',
#    'Refrigerator',
#    'Dishes and silverware',
#    'BBQ grill',
#    'Garden or backyard']},
#  {'name': 'Charming room near Casa da Música',
#   'accommodates': 2,
#   'number_of_reviews': 40,
#   'amenities': ['Wifi',
#    'Kitchen',
#    'Smoking allowed',
#    'Essentials',
#    'Shampoo',
#    'Hangers',
#    'Iron',
#    'Laptop friendly workspace']},
#  {'name': 'BCN center / balcony - ensuite bathroom',
#   'accommodates': 2,
#   'number_of_reviews': 76,
#   'amenities': ['Wifi',
#    'Elevator',
#    'Heating',
#    'Fire extinguisher',
#    'Essentials',
#    'Shampoo',
#    'Lock on bedroom door',
#    'Hangers',
#    'Hair dryer',
#    'Hot water',
#    'Host greets you']},
#  {'name': '²LARGE DOUBLE ROOM SLEEPS UP TO 4  IN FLAMENGO',
#   'accommodates': 5,
#   'number_of_reviews': 32,
#   'amenities': ['Wifi',
#    'Air conditioning',
#    'Kitchen',
#    'Free parking on premises',
#    'Pets live on this property',
#    'Cat(s)',
#    'Elevator',
#    'Free street parking',
#    'Family/kid friendly',
#    'Washer',
#    'First aid kit',
#    'Fire extinguisher',
#    'Essentials',
#    'Lock on bedroom door',
#    'Hangers',
#    'Iron',
#    'Laptop friendly workspace',
#    'Outlet covers',
#    'Room-darkening shades',
#    'Hot water',
#    'Bed linens',
#    'Extra pillows and blankets',
#    'Ethernet connection',
#    'Microwave',
#    'Coffee maker',
#    'Refrigerator',
#    'Dishes and silverware',
#    'Cooking basics',
#    'Oven',
#    'Stove',
#    'Single level home',
#    'Luggage dropoff allowed',
#    'Long term stays allowed',
#    'Cleaning before checkout',
#    'Wide hallway clearance',
#    'Step-free access',
#    'Wide doorway',
#    'Flat path to front door',
#    'Well-lit path to entrance',
#    'Disabled parking spot',
#    'Step-free access',
#    'Wide doorway',
#    'Wide clearance to bed',
#    'Accessible-height bed',
#    'Step-free access',
#    'Wide doorway',
#    'Accessible-height toilet',
#    'Step-free access',
#    'Wide entryway',
#    'Beachfront',
#    'Handheld shower head',
#    'Roll-in shower']},
#  {'name': 'Beachhouse Kailua: Cottage with Green A/C',
#   'accommodates': 2,
#   'number_of_reviews': 65,
#   'amenities': ['Wifi',
#    'Air conditioning',
#    'Kitchen',
#    'Free parking on premises',
#    'Smoke detector',
#    'First aid kit',
#    'Fire extinguisher',
#    'Essentials',
#    'Shampoo',
#    'Lock on bedroom door',
#    'Hangers',
#    'Hair dryer',
#    'Iron',
#    'Laptop friendly workspace',
#    'Self check-in',
#    'Smart lock',
#    'Keypad',
#    'Building staff',
#    'Private entrance',
#    'Hot water',
#    'Bed linens',
#    'Microwave',
#    'Coffee maker',
#    'Refrigerator',
#    'Dishes and silverware',
#    'Patio or balcony',
#    'Beach essentials']},
#  {'name': 'Room in Pointe Claire heritage home',
#   'accommodates': 2,
#   'number_of_reviews': 73,
#   'amenities': ['Cable TV',
#    'Wifi',
#    'Air conditioning',
#    'Free parking on premises',
#    'Heating',
#    'Washer',
#    'Dryer',
#    'Smoke detector',
#    'First aid kit',
#    'Fire extinguisher',
#    'Essentials',
#    'Shampoo',
#    'Hangers',
#    'Hair dryer',
#    'Laptop friendly workspace',
#    'Hot water',
#    'Coffee maker',
#    'Refrigerator',
#    'BBQ grill',
#    'Garden or backyard',
#    'Host greets you',
#    'Lake access']},
#  {'name': 'Sheepshead Bay, 1-bdr apartment. Close to all!',
#   'accommodates': 4,
#   'number_of_reviews': 37,
#   'amenities': ['Wifi',
#    'Air conditioning',
#    'Kitchen',
#    'Elevator',
#    'Heating',
#    'Washer',
#    'Dryer',
#    'Smoke detector',
#    'Carbon monoxide detector',
#    'First aid kit',
#    'Essentials',
#    'Shampoo',
#    'Hangers',
#    'Hair dryer',
#    'Iron',
#    'Laptop friendly workspace']},
#  {'name': 'Superbe chambre à deux pas du métro Mt-Royal!',
#   'accommodates': 2,
#   'number_of_reviews': 51,
#   'amenities': ['Wifi',
#    'Kitchen',
#    'Paid parking off premises',
#    'Free street parking',
#    'Heating',
#    'Washer',
#    'Dryer',
#    'Smoke detector',
#    'Essentials',
#    'Shampoo',
#    'Hair dryer',
#    'Hot water',
#    'Other']},
#  {'name': 'Lantau Beach Flat & Rooftop',
#   'accommodates': 2,
#   'number_of_reviews': 24,
#   'amenities': ['Wifi',
#    'Air conditioning',
#    'Kitchen',
#    'Smoking allowed',
#    'Heating',
#    'Washer',
#    'Essentials',
#    'Shampoo',
#    'Hangers',
#    'Iron',
#    'Laptop friendly workspace',
#    'Hot water',
#    'Coffee maker',
#    'Refrigerator',
#    'Dishes and silverware',
#    'Patio or balcony',
#    'Host greets you']},
#  {'name': 'Winter Escape in Morningside Heights',
#   'accommodates': 2,
#   'number_of_reviews': 88,
#   'amenities': ['Wifi',
#    'Air conditioning',
#    'Kitchen',
#    'Elevator',
#    'Free street parking',
#    'Heating',
#    'Family/kid friendly',
#    'Washer',
#    'Dryer',
#    'Smoke detector',
#    'Carbon monoxide detector',
#    'First aid kit',
#    'Fire extinguisher',
#    'Essentials',
#    'Shampoo',
#    'Lock on bedroom door',
#    'Hangers',
#    'Hair dryer',
#    'Iron',
#    'Laptop friendly workspace',
#    'Self check-in',
#    'Lockbox',
#    'Bathtub',
#    'Babysitter recommendations',
#    'Room-darkening shades',
#    'Hot water',
#    'Bed linens',
#    'Extra pillows and blankets',
#    'Microwave',
#    'Coffee maker',
#    'Refrigerator',
#    'Dishwasher',
#    'Dishes and silverware',
#    'Cooking basics',
#    'Oven',
#    'Stove',
#    'Patio or balcony',
#    'Luggage dropoff allowed',
#    'Wide hallway clearance',
#    'Wide doorway',
#    'Flat path to front door',
#    'Well-lit path to entrance',
#    'Step-free access',
#    'Wide doorway',
#    'Wide clearance to bed',
#    'Accessible-height bed',
#    'Step-free access',
#    'Accessible-height toilet',
#    'Step-free access',
#    'Wide entryway']},
#  {'name': '"Hôtel" room Frontenac metro, private & furnished',
#   'accommodates': 2,
#   'number_of_reviews': 29,
#   'amenities': ['Wifi',
#    'Kitchen',
#    'Smoking allowed',
#    'Pets allowed',
#    'Gym',
#    'Free street parking',
#    'Buzzer/wireless intercom',
#    'Heating',
#    'Suitable for events',
#    'Washer',
#    'Dryer',
#    'Smoke detector',
#    'First aid kit',
#    'Essentials',
#    'Shampoo',
#    'Lock on bedroom door',
#    'Hangers',
#    'Hair dryer',
#    'Iron',
#    'Laptop friendly workspace',
#    'Hot water',
#    'Bed linens',
#    'Extra pillows and blankets',
#    'Microwave',
#    'Coffee maker',
#    'Refrigerator',
#    'Dishes and silverware',
#    'Cooking basics',
#    'Oven',
#    'Stove',
#    'BBQ grill',
#    'Patio or balcony',
#    'Luggage dropoff allowed',
#    'Long term stays allowed',
#    'Cleaning before checkout',
#    'Host greets you']},
#  {'name': 'The Green Room Mong Kok',
#   'accommodates': 2,
#   'number_of_reviews': 41,
#   'amenities': ['Wifi',
#    'Air conditioning',
#    'Essentials',
#    'Shampoo',
#    'Hangers',
#    'Hair dryer',
#    'Laptop friendly workspace']},
#  {'name': 'Private bedroom near Sherbrooke Station',
#   'accommodates': 2,
#   'number_of_reviews': 45,
#   'amenities': ['Wifi',
#    'Kitchen',
#    'Free street parking',
#    'Heating',
#    'Washer',
#    'Dryer',
#    'Smoke detector',
#    'First aid kit',
#    'Essentials',
#    'Shampoo',
#    'Hangers',
#    'Hair dryer',
#    'Hot water',
#    'Refrigerator',
#    'Dishes and silverware',
#    'Cooking basics',
#    'Oven',
#    'Stove',
#    'Long term stays allowed',
#    'Other']},
#  {'name': 'Private Terrace. Convenient. 2 BR Apt. WanChai MTR',
#   'accommodates': 5,
#   'number_of_reviews': 51,
#   'amenities': ['Wifi',
#    'Air conditioning',
#    'Kitchen',
#    'Family/kid friendly',
#    'Essentials',
#    'Shampoo',
#    'Hangers',
#    'Hair dryer',
#    'Iron',
#    'Laptop friendly workspace',
#    'Self check-in',
#    'Smart lock',
#    'Private living room',
#    'Hot water',
#    'Bed linens',
#    'Microwave',
#    'Coffee maker',
#    'Refrigerator',
#    'Dishes and silverware',
#    'Stove',
#    'Single level home',
#    'Patio or balcony']},
#  {'name': 'Bright room at the other side of the river',
#   'accommodates': 2,
#   'number_of_reviews': 40,
#   'amenities': ['Wifi',
#    'Free parking on premises',
#    'Elevator',
#    'Essentials',
#    'Shampoo',
#    'Lock on bedroom door',
#    'Hangers',
#    'Hair dryer',
#    'Hot water',
#    'Bed linens',
#    'Extra pillows and blankets',
#    'Luggage dropoff allowed']},
#  {'name': '有窗舒適雙人房!鄰近旺角站!Comfy double Rm Near Mong kok MTR!1',
#   'accommodates': 2,
#   'number_of_reviews': 23,
#   'amenities': ['Wifi',
#    'Air conditioning',
#    'Elevator',
#    'Washer',
#    'Essentials',
#    'Shampoo',
#    'Lock on bedroom door',
#    'Hangers',
#    'Laptop friendly workspace']},
#  {'name': '尖沙咀 寧靜方便優雅 Private studio inTST (1min to TST mtr)',
#   'accommodates': 2,
#   'number_of_reviews': 25,
#   'amenities': ['Wifi',
#    'Air conditioning',
#    'Kitchen',
#    'Elevator',
#    'Washer',
#    'Essentials',
#    'Shampoo',
#    'Hangers',
#    'Hair dryer',
#    'Laptop friendly workspace',
#    'Self check-in',
#    'Lockbox',
#    'Hot water',
#    'Bed linens',
#    'Long term stays allowed']},
#  {'name': 'PRETTY ROOM IN BARCELONA-A/C-NEAR PLAZA ESPAÑA',
#   'accommodates': 2,
#   'number_of_reviews': 53,
#   'amenities': ['Wifi',
#    'Air conditioning',
#    'Kitchen',
#    'Elevator',
#    'Free street parking',
#    'Heating',
#    'Essentials',
#    'Shampoo',
#    'Lock on bedroom door',
#    'Hangers',
#    'Hair dryer',
#    'Hot water',
#    'Bed linens',
#    'Microwave',
#    'Coffee maker',
#    'Refrigerator',
#    'Dishwasher',
#    'Dishes and silverware',
#    'Cooking basics',
#    'Oven',
#    'Stove',
#    'Luggage dropoff allowed',
#    'Long term stays allowed',
#    'Step-free access',
#    'Wide clearance to bed',
#    'Accessible-height bed',
#    'Step-free access',
#    'Wide clearance to shower',
#    'toilet',
#    'Step-free access',
#    'Wide entryway',
#    'Host greets you',
#    'Paid parking on premises']},
#  {'name': 'Mid Century Modern Guesthouse with Pool and Views!',
#   'accommodates': 4,
#   'number_of_reviews': 121,
#   'amenities': ['Wifi',
#    'Pool',
#    'Free parking on premises',
#    'Pets live on this property',
#    'Dog(s)',
#    'Family/kid friendly',
#    'Smoke detector',
#    'Essentials',
#    'Shampoo',
#    'Lock on bedroom door',
#    'Private entrance',
#    'Bed linens',
#    'Extra pillows and blankets',
#    'Coffee maker',
#    'Refrigerator',
#    'Patio or balcony',
#    'Garden or backyard']},
#  {'name': 'Artist Studio',
#   'accommodates': 2,
#   'number_of_reviews': 47,
#   'amenities': ['Wifi',
#    'Kitchen',
#    'Heating',
#    'Smoke detector',
#    'Carbon monoxide detector',
#    'Fire extinguisher',
#    'Essentials',
#    'Shampoo',
#    'Lock on bedroom door',
#    'Hangers',
#    'Hair dryer',
#    'Laptop friendly workspace',
#    'Hot water',
#    'Bed linens',
#    'Extra pillows and blankets',
#    'Pocket wifi',
#    'Coffee maker',
#    'Refrigerator',
#    'Dishes and silverware',
#    'Cooking basics',
#    'Stove',
#    'Host greets you']},
#  {'name': 'Super Cute Chelsea One Bedroom',
#   'accommodates': 2,
#   'number_of_reviews': 45,
#   'amenities': ['Wifi',
#    'Air conditioning',
#    'Kitchen',
#    'Indoor fireplace',
#    'Buzzer/wireless intercom',
#    'Heating',
#    'Family/kid friendly',
#    'Smoke detector',
#    'Carbon monoxide detector',
#    'Fire extinguisher',
#    'Essentials',
#    'Shampoo',
#    'Hangers',
#    'Hair dryer',
#    'Iron',
#    'Laptop friendly workspace',
#    'translation missing: en.hosting_amenity_50',
#    'Self check-in',
#    'Lockbox',
#    'Private living room',
#    'Hot water',
#    'Bed linens',
#    'Extra pillows and blankets',
#    'Refrigerator',
#    'Cooking basics',
#    'Oven',
#    'Stove',
#    'Luggage dropoff allowed']},
#  {'name': 'Relax in the Raval - Room with Balcony',
#   'accommodates': 2,
#   'number_of_reviews': 27,
#   'amenities': ['Wifi',
#    'Kitchen',
#    'Paid parking off premises',
#    'Smoking allowed',
#    'Elevator',
#    'Essentials',
#    'Shampoo',
#    'Hangers',
#    'Hair dryer',
#    'Iron',
#    'Private living room',
#    'Hot water',
#    'Host greets you']},
#  {'name': 'Cosy Cottage blue',
#   'accommodates': 2,
#   'number_of_reviews': 39,
#   'amenities': ['Wifi',
#    'Free street parking',
#    'Essentials',
#    'Iron',
#    'Laptop friendly workspace',
#    'Hot water',
#    'Single level home',
#    'Garden or backyard',
#    'Other',
#    'Paid parking on premises']},
#  {'name': '*THE NEW YORKER * Downtown-Centre Ville',
#   'accommodates': 5,
#   'number_of_reviews': 27,
#   'amenities': ['Wifi',
#    'Air conditioning',
#    'Pool',
#    'Kitchen',
#    'Paid parking off premises',
#    'Free street parking',
#    'Heating',
#    'Smoke detector',
#    'Carbon monoxide detector',
#    'Essentials',
#    'Shampoo',
#    'Hangers',
#    'Laptop friendly workspace',
#    'Self check-in',
#    'Lockbox',
#    'Hot water',
#    'Bed linens',
#    'Extra pillows and blankets',
#    'Pocket wifi',
#    'Microwave',
#    'Refrigerator',
#    'Dishes and silverware',
#    'Cooking basics',
#    'Oven',
#    'Stove',
#    'Patio or balcony',
#    'Long term stays allowed',
#    'Well-lit path to entrance']},
#  {'name': 'Surfers Farm Shack',
#   'accommodates': 2,
#   'number_of_reviews': 29,
#   'amenities': ['Wifi',
#    'Kitchen',
#    'Free parking on premises',
#    'First aid kit',
#    'Essentials']},
#  {'name': 'Brand New One Master Bedroom Epping 全新一主人套房Epping',
#   'accommodates': 2,
#   'number_of_reviews': 53,
#   'amenities': ['Wifi',
#    'Free parking on premises',
#    'Free street parking',
#    'Essentials',
#    'Shampoo',
#    'Hangers',
#    'Hot water',
#    'Bed linens',
#    'Extra pillows and blankets',
#    'Luggage dropoff allowed',
#    'Long term stays allowed',
#    'Well-lit path to entrance',
#    'Step-free access',
#    'Accessible-height toilet',
#    'Host greets you',
#    'Handheld shower head',
#    'Roll-in shower']},
#  {'name': 'Large attic room, ensuite bathroom Forest Lodge',
#   'accommodates': 2,
#   'number_of_reviews': 35,
#   'amenities': ['Wifi',
#    'Kitchen',
#    'Heating',
#    'Washer',
#    'Smoke detector',
#    'First aid kit',
#    'Fire extinguisher',
#    'Essentials',
#    'Shampoo',
#    'Lock on bedroom door',
#    'Hangers',
#    'Hair dryer',
#    'Iron',
#    'Laptop friendly workspace',
#    'Hot water',
#    'Bed linens',
#    'Extra pillows and blankets',
#    'Microwave',
#    'Refrigerator',
#    'Dishwasher',
#    'Dishes and silverware',
#    'Cooking basics',
#    'Garden or backyard',
#    'Luggage dropoff allowed',
#    'Host greets you']},
#  {'name': 'Cosy & Sunny Perfect Location',
#   'accommodates': 3,
#   'number_of_reviews': 64,
#   'amenities': ['Wifi',
#    'Air conditioning',
#    'Kitchen',
#    'Paid parking off premises',
#    'Elevator',
#    'Free street parking',
#    'Heating',
#    'Washer',
#    'Dryer',
#    'Smoke detector',
#    'Carbon monoxide detector',
#    'First aid kit',
#    'Safety card',
#    'Fire extinguisher',
#    'Essentials',
#    'Shampoo',
#    'Lock on bedroom door',
#    'Hangers',
#    'Hair dryer',
#    'Iron',
#    'Laptop friendly workspace',
#    'Self check-in',
#    'Lockbox',
#    'Private entrance',
#    'Hot water',
#    'Bed linens',
#    'Extra pillows and blankets',
#    'Ethernet connection',
#    'Coffee maker',
#    'Refrigerator',
#    'Dishes and silverware',
#    'Cooking basics',
#    'Oven',
#    'Stove',
#    'Patio or balcony',
#    'Long term stays allowed']},
#  {'name': 'Two room suite 1min from subway 20min to Manhattan',
#   'accommodates': 2,
#   'number_of_reviews': 40,
#   'amenities': ['Wifi',
#    'Air conditioning',
#    'Kitchen',
#    'Free street parking',
#    'Heating',
#    'Smoke detector',
#    'Carbon monoxide detector',
#    'Essentials',
#    'Lock on bedroom door',
#    'Hangers',
#    'Hair dryer',
#    'Laptop friendly workspace',
#    'Self check-in',
#    'Lockbox',
#    'Hot water',
#    'Bed linens',
#    'Microwave',
#    'Coffee maker',
#    'Refrigerator',
#    'Dishes and silverware',
#    'Cooking basics',
#    'Stove',
#    'Long term stays allowed']},
#  {'name': 'Room A4',
#   'accommodates': 3,
#   'number_of_reviews': 34,
#   'amenities': ['Wifi', 'Essentials']},
#  {'name': 'Private Room\'s "Gaya" (Nº2) Low-Cost',
#   'accommodates': 2,
#   'number_of_reviews': 25,
#   'amenities': ['Wifi',
#    'Kitchen',
#    'Gym',
#    'Free street parking',
#    'Family/kid friendly',
#    'Essentials',
#    'Shampoo',
#    'Lock on bedroom door',
#    'Hangers',
#    'Hair dryer',
#    'Iron',
#    'Laptop friendly workspace',
#    'Self check-in',
#    'Building staff',
#    'Private living room',
#    'Hot water',
#    'Microwave',
#    'Refrigerator',
#    'Dishes and silverware',
#    'Cooking basics',
#    'Oven',
#    'Stove',
#    'Patio or balcony',
#    'Luggage dropoff allowed',
#    'Cleaning before checkout']},
#  {'name': 'Double room & private toilet near Sagrada Familia',
#   'accommodates': 2,
#   'number_of_reviews': 24,
#   'amenities': ['Wifi',
#    'Kitchen',
#    'Paid parking off premises',
#    'Elevator',
#    'Heating',
#    'Washer',
#    'First aid kit',
#    'Essentials',
#    'Shampoo',
#    'Hair dryer',
#    'Iron',
#    'Laptop friendly workspace',
#    'Hot water',
#    'Bed linens',
#    'Microwave',
#    'Refrigerator',
#    'Dishes and silverware',
# ...
#  {'name': 'Floor Through East Village Lux Apt',
#   'accommodates': 4,
#   'number_of_reviews': 83,
#   'amenities': ['Cable TV',
#    'Wifi',
#    'Air conditioning',
#    'Kitchen',
#    'Heating',
#    'Smoke detector',
#    'Carbon monoxide detector',
#    'First aid kit',
#    'Fire extinguisher',
#    'Essentials']},
#  {'name': 'Amazing Ocean View Moon Cabin on retreat property',
#   'accommodates': 2,
#   'number_of_reviews': 48,
#   'amenities': ['Wifi',
#    'Kitchen',
#    'Free parking on premises',
#    'Pets live on this property',
#    'Cat(s)',
#    'Family/kid friendly',
#    'Washer',
#    'Dryer',
#    'Smoke detector',
#    'Fire extinguisher',
#    'Essentials',
#    'Shampoo',
#    'Lock on bedroom door',
#    'Hangers',
#    'Laptop friendly workspace',
#    'Private living room',
#    'Hot water',
#    'Bed linens',
#    'Extra pillows and blankets',
#    'Coffee maker',
#    'Refrigerator',
#    'Dishes and silverware',
#    'Cooking basics',
#    'Oven',
#    'Stove',
#    'Single level home',
#    'Patio or balcony',
#    'Garden or backyard',
#    'Luggage dropoff allowed',
#    'Cleaning before checkout']},
#  {'name': 'Apart(5)-5 minutes walk from Taksim',
#   'accommodates': 2,
#   'number_of_reviews': 171,
#   'amenities': ['']},
#  {'name': 'Large, sunny apartment. Perfect location.',
#   'accommodates': 4,
#   'number_of_reviews': 165,
#   'amenities': ['Wifi',
#    'Air conditioning',
#    'Kitchen',
#    'Paid parking off premises',
#    'Pets allowed',
#    'Free street parking',
#    'Heating',
#    'Family/kid friendly',
#    'Smoke detector',
#    'Carbon monoxide detector',
#    'Essentials',
#    'Shampoo',
#    'Hair dryer',
#    'Iron',
#    'Laptop friendly workspace',
#    'Self check-in',
#    'Lockbox',
#    'Private living room',
#    'Hot water',
#    'Bed linens',
#    'Extra pillows and blankets',
#    'Microwave',
#    'Coffee maker',
#    'Refrigerator',
#    'Dishes and silverware',
#    'Cooking basics',
#    'Oven',
#    'Stove',
#    'Luggage dropoff allowed',
#    'Long term stays allowed']},
#  {'name': 'Tara Cottage:a Haven for Relaxation',
#   'accommodates': 3,
#   'number_of_reviews': 30,
#   'amenities': ['Cable TV',
#    'Wifi',
#    'Wheelchair accessible',
#    'Kitchen',
#    'Free parking on premises',
#    'Pets live on this property',
#    'Dog(s)',
#    'Washer',
#    'Dryer',
#    'Smoke detector',
#    'Carbon monoxide detector',
#    'Fire extinguisher',
#    'Essentials',
#    'Shampoo',
#    '24-hour check-in',
#    'Hangers',
#    'Hair dryer',
#    'Iron',
#    'Laptop friendly workspace',
#    'translation missing: en.hosting_amenity_49',
#    'translation missing: en.hosting_amenity_50',
#    'Self check-in',
#    'Lockbox']},
#  {'name': 'Room in Brooklyn, 20 min from Manh',
#   'accommodates': 2,
#   'number_of_reviews': 48,
#   'amenities': ['Wifi',
#    'Kitchen',
#    'translation missing: en.hosting_amenity_49',
#    'translation missing: en.hosting_amenity_50']},
#  {'name': 'COPA LUXURY 1 BEDROOM',
#   'accommodates': 3,
#   'number_of_reviews': 64,
#   'amenities': ['Cable TV',
#    'Wifi',
#    'Air conditioning',
#    'Kitchen',
#    'Elevator',
#    'Family/kid friendly',
#    'Washer',
#    'Dryer',
#    'Hangers',
#    'Hair dryer',
#    'Iron',
#    'Hot water',
#    'Bed linens',
#    'Extra pillows and blankets']},
#  {'name': '鄰近香港城市大學､地下列車站,交通便捷｡雙人房,上下層床｡歡迎月租或年租｡長期租住月租五折｡',
#   'accommodates': 2,
#   'number_of_reviews': 28,
#   'amenities': ['Wifi',
#    'Air conditioning',
#    'Pets allowed',
#    'Elevator',
#    'Heating',
#    'Washer',
#    'Lock on bedroom door',
#    'Hangers',
#    'Hair dryer',
#    'Laptop friendly workspace',
#    'Bathtub',
#    'Window guards',
#    'Room-darkening shades',
#    'Hot water',
#    'Bed linens',
#    'Microwave',
#    'Refrigerator',
#    'Luggage dropoff allowed',
#    'Long term stays allowed',
#    'Wide doorway',
#    'Well-lit path to entrance',
#    'Step-free access',
#    'Step-free access']},
#  {'name': 'traditional and Charming room',
#   'accommodates': 3,
#   'number_of_reviews': 408,
#   'amenities': ['Wifi',
#    'Kitchen',
#    'Heating',
#    'Family/kid friendly',
#    'First aid kit',
#    'Fire extinguisher',
#    'Essentials',
#    'Crib',
#    'Hot water',
#    'Other']},
#  {'name': 'Bucolic Eco Art House Cézanne Suite',
#   'accommodates': 2,
#   'number_of_reviews': 47,
#   'amenities': ['Cable TV',
#    'Wifi',
#    'Air conditioning',
#    'Pool',
#    'Kitchen',
#    'Smoking allowed',
#    'Pets live on this property',
#    'Cat(s)',
#    'Washer',
#    'Fire extinguisher',
#    'Essentials',
#    'Lock on bedroom door',
#    'Hangers',
#    'Hair dryer',
#    'Laptop friendly workspace',
#    'translation missing: en.hosting_amenity_49',
#    'translation missing: en.hosting_amenity_50',
#    'Hot water',
#    'Extra pillows and blankets']},
#  {'name': 'Best Location on the UWS!!',
#   'accommodates': 2,
#   'number_of_reviews': 171,
#   'amenities': ['Wifi',
#    'Air conditioning',
#    'Wheelchair accessible',
#    'Kitchen',
#    'Pets allowed',
#    'Doorman',
#    'Pets live on this property',
#    'Dog(s)',
#    'Elevator',
#    'Buzzer/wireless intercom',
#    'Heating',
#    'Family/kid friendly',
#    'Washer',
#    'Dryer',
#    'Smoke detector',
#    'Carbon monoxide detector',
#    'Essentials',
#    'Shampoo',
#    'Hangers',
#    'Hair dryer',
#    'Iron',
#    'translation missing: en.hosting_amenity_50']},
#  {'name': 'Spanish family host U/private WC',
#   'accommodates': 3,
#   'number_of_reviews': 265,
#   'amenities': ['Wifi',
#    'Kitchen',
#    'Smoking allowed',
#    'Pets live on this property',
#    'Dog(s)',
#    'Elevator',
#    'Family/kid friendly',
#    'Washer',
#    'First aid kit',
#    'Essentials',
#    'Shampoo',
#    'Lock on bedroom door',
#    'Hangers',
#    'Hair dryer',
#    'Iron',
#    'Laptop friendly workspace',
#    'Crib',
#    'Hot water',
#    'Bed linens',
#    'Extra pillows and blankets',
#    'Microwave',
#    'Coffee maker',
#    'Refrigerator',
#    'Dishes and silverware',
#    'Cooking basics',
#    'Oven',
#    'Stove',
#    'Luggage dropoff allowed',
#    'Long term stays allowed',
#    'Host greets you',
#    'Paid parking on premises']},
#  {'name': 'OCEANFRONT - TOP FLOOR - SUNSETS - VIEWS - PRIVATE',
#   'accommodates': 2,
#   'number_of_reviews': 37,
#   'amenities': ['Cable TV',
#    'Wifi',
#    'Wheelchair accessible',
#    'Pool',
#    'Kitchen',
#    'Free parking on premises',
#    'Elevator',
#    'Family/kid friendly',
#    'Smoke detector',
#    'Essentials',
#    'Hangers',
#    'Hair dryer',
#    'Iron',
#    'Laptop friendly workspace',
#    'translation missing: en.hosting_amenity_49',
#    'Self check-in',
#    'Lockbox',
#    'Microwave',
#    'Coffee maker',
#    'Refrigerator',
#    'Dishwasher',
#    'Dishes and silverware',
#    'Cooking basics',
#    'Oven',
#    'Stove',
#    'BBQ grill',
#    'Patio or balcony',
#    'Long term stays allowed',
#    'Well-lit path to entrance',
#    'Step-free access',
#    'Step-free access',
#    'Waterfront']},
#  {'name': 'B & W room close to Sydney CBD airport, Sydney Uni',
#   'accommodates': 2,
#   'number_of_reviews': 29,
#   'amenities': ['Wifi',
#    'Air conditioning',
#    'Smoking allowed',
#    'Free street parking',
#    'Heating',
#    'Washer',
#    'Dryer',
#    'Smoke detector',
#    'First aid kit',
#    'Essentials',
#    'Shampoo',
#    'Lock on bedroom door',
#    'Hangers',
#    'Hair dryer',
#    'Iron',
#    'translation missing: en.hosting_amenity_49',
#    'translation missing: en.hosting_amenity_50',
#    'Hot water',
#    'Bed linens',
#    'Extra pillows and blankets',
#    'Microwave',
#    'Coffee maker',
#    'Refrigerator',
#    'Dishwasher',
#    'Dishes and silverware',
#    'Cooking basics',
#    'Single level home',
#    'Garden or backyard',
#    'Luggage dropoff allowed',
#    'Long term stays allowed',
#    'Step-free access',
#    'Handheld shower head']},
#  {'name': 'Ainalani',
#   'accommodates': 2,
#   'number_of_reviews': 155,
#   'amenities': ['Wifi',
#    'Kitchen',
#    'Free parking on premises',
#    'Pets live on this property',
#    'Family/kid friendly',
#    'Washer',
#    'Dryer',
#    'Smoke detector',
#    'First aid kit',
#    'Fire extinguisher',
#    'Essentials',
#    'Lock on bedroom door',
#    'Hangers',
#    'Iron',
#    'Private living room',
#    'Hot water',
#    'Bed linens',
#    'Other']},
#  {'name': 'Gallery´s Street House',
#   'accommodates': 4,
#   'number_of_reviews': 166,
#   'amenities': ['Wifi',
#    'Family/kid friendly',
#    'First aid kit',
#    'Fire extinguisher',
#    'Essentials',
#    '24-hour check-in',
#    'Hangers',
#    'Hair dryer',
#    'Laptop friendly workspace',
#    'Bathtub',
#    'Crib',
#    'Long term stays allowed',
#    'Cleaning before checkout',
#    'Host greets you']},
#  {'name': 'Wburg 1 bedroom - Spacious & Sunny',
#   'accommodates': 2,
#   'number_of_reviews': 31,
#   'amenities': ['Wifi',
#    'Air conditioning',
#    'Kitchen',
#    'Heating',
#    'Family/kid friendly',
#    'Smoke detector',
#    'Carbon monoxide detector',
#    'Essentials',
#    'Shampoo',
#    'Hangers',
#    'Hair dryer',
#    'Iron',
#    'translation missing: en.hosting_amenity_50',
#    'Self check-in',
#    'Lockbox',
#    'Hot water',
#    'Bed linens',
#    'Extra pillows and blankets',
#    'Coffee maker',
#    'Refrigerator',
#    'Dishes and silverware',
#    'Cooking basics',
#    'Oven',
#    'Stove',
#    'Luggage dropoff allowed',
#    'Long term stays allowed']},
#  {'name': 'Cozy Apartment in Porto Center',
#   'accommodates': 2,
#   'number_of_reviews': 32,
#   'amenities': ['Wifi',
#    'Kitchen',
#    'Elevator',
#    'Hot tub',
#    'Heating',
#    'Family/kid friendly',
#    'Washer',
#    'Smoke detector',
#    'Carbon monoxide detector',
#    'Fire extinguisher',
#    'Essentials',
#    'Shampoo',
#    'Hangers',
#    'Hair dryer',
#    'Iron',
#    'Private living room',
#    'Cleaning before checkout',
#    'Wide doorway',
#    'Flat path to front door',
#    'Well-lit path to entrance',
#    'Step-free access',
#    'Wide doorway',
#    'Wide clearance to bed',
#    'Accessible-height bed',
#    'Step-free access',
#    'Step-free access',
#    'Wide entryway',
#    'Host greets you']},
#  {'name': 'Double Bedroom in shared Apt by Boqueria & Ramblas',
#   'accommodates': 3,
#   'number_of_reviews': 147,
#   'amenities': ['Wifi',
#    'Paid parking off premises',
#    'Smoking allowed',
#    'First aid kit',
#    'Essentials',
#    'Shampoo',
#    'Hangers',
#    'Hair dryer',
#    'translation missing: en.hosting_amenity_49',
#    'translation missing: en.hosting_amenity_50',
#    'Hot water',
#    'Bed linens',
#    'Extra pillows and blankets',
#    'Refrigerator',
#    'Dishes and silverware',
#    'Single level home',
#    'Patio or balcony',
#    'Long term stays allowed',
#    'Wide doorway',
#    'Step-free access',
#    'Wide doorway',
#    'Step-free access',
#    'Wide entryway',
#    'Host greets you']},
#  {'name': 'Kings Road Brothers Sta Catarina',
#   'accommodates': 2,
#   'number_of_reviews': 180,
#   'amenities': ['Wifi',
#    'Kitchen',
#    'Paid parking off premises',
#    'Family/kid friendly',
#    'Smoke detector',
#    'Carbon monoxide detector',
#    'First aid kit',
#    'Fire extinguisher',
#    'Essentials',
#    'Shampoo',
#    'Hangers',
#    'Iron',
#    'Hot water',
#    'Bed linens',
#    'Luggage dropoff allowed',
#    'Long term stays allowed',
#    'Host greets you']},
#  {'name': 'Sunny and charming centric flat!!',
#   'accommodates': 2,
#   'number_of_reviews': 52,
#   'amenities': ['Wifi',
#    'Wheelchair accessible',
#    'Kitchen',
#    'Paid parking off premises',
#    'Smoking allowed',
#    'Pets allowed',
#    'Elevator',
#    'Free street parking',
#    'Buzzer/wireless intercom',
#    'Family/kid friendly',
#    'Washer',
#    'Essentials',
#    'Shampoo',
#    'Hair dryer',
#    'Laptop friendly workspace',
#    'Hot water',
#    'Host greets you']},
#  {'name': 'Upper WestSide NYC Central Park II',
#   'accommodates': 2,
#   'number_of_reviews': 29,
#   'amenities': ['Wifi',
#    'Air conditioning',
#    'Kitchen',
#    'Breakfast',
#    'Heating',
#    'Smoke detector',
#    'Carbon monoxide detector',
#    'First aid kit',
#    'Essentials',
#    'Shampoo',
#    'Hangers',
#    'Hair dryer',
#    'Iron',
#    'Laptop friendly workspace',
#    'translation missing: en.hosting_amenity_49',
#    'Bathtub',
#    'Hot water',
#    'Bed linens',
#    'Extra pillows and blankets',
#    'Luggage dropoff allowed',
#    'Long term stays allowed',
#    'Host greets you']},
#  {'name': 'Belle chambre calme',
#   'accommodates': 2,
#   'number_of_reviews': 99,
#   'amenities': ['Wifi',
#    'Kitchen',
#    'Heating',
#    'Washer',
#    'Dryer',
#    'Smoke detector',
#    'Essentials',
#    'translation missing: en.hosting_amenity_49',
#    'translation missing: en.hosting_amenity_50']},
#  {'name': 'Basement Beach Apartment, Rockaways',
#   'accommodates': 2,
#   'number_of_reviews': 62,
#   'amenities': ['Wifi',
#    'Free parking on premises',
#    'Gym',
#    'Heating',
#    'Smoke detector',
#    'Carbon monoxide detector',
#    'Fire extinguisher',
#    'Essentials',
#    'Shampoo',
#    'Hangers',
#    'translation missing: en.hosting_amenity_50',
#    'Private entrance',
#    'Hot water',
#    'Bed linens',
#    'Microwave',
#    'Refrigerator',
#    'Dishes and silverware',
#    'Cooking basics',
#    'Luggage dropoff allowed']},
#  {'name': 'Quality apartment, Quality location',
#   'accommodates': 2,
#   'number_of_reviews': 27,
#   'amenities': ['']},
#  {'name': 'Fantastic apartment in Copacabana',
#   'accommodates': 3,
#   'number_of_reviews': 114,
#   'amenities': ['Cable TV',
#    'Wifi',
#    'Air conditioning',
#    'Kitchen',
#    'Doorman',
#    'Elevator',
#    'Buzzer/wireless intercom']},
#  {'name': 'Charming & Comfy in Annandale - 2',
#   'accommodates': 2,
#   'number_of_reviews': 71,
#   'amenities': ['Wifi',
#    'Family/kid friendly',
#    'Smoke detector',
#    'Essentials',
#    'Laptop friendly workspace',
#    'Hot water',
#    'Bed linens']},
#  {'name': 'DOUBLE ROOM attached to the CATALUÑA Square',
#   'accommodates': 2,
#   'number_of_reviews': 161,
#   'amenities': ['Wifi',
#    'Kitchen',
#    'Heating',
#    'Family/kid friendly',
#    'First aid kit',
#    'Essentials',
#    'Shampoo',
#    'Hair dryer',
#    'Iron',
#    'Laptop friendly workspace',
#    'Crib',
#    'Hot water',
#    'Bed linens',
#    'Host greets you']},
#  {'name': '•F61 Mid of Waikiki girls Unit Private room',
#   'accommodates': 2,
#   'number_of_reviews': 170,
#   'amenities': ['Wifi',
#    'Kitchen',
#    'Washer',
#    'Dryer',
#    'Smoke detector',
#    'Fire extinguisher',
#    'Essentials',
#    'Lock on bedroom door',
#    'Hangers',
#    'Hair dryer',
#    'Laptop friendly workspace',
#    'Self check-in',
#    'Lockbox',
#    'Hot water',
#    'Bed linens',
#    'Microwave',
#    'Refrigerator',
#    'Dishes and silverware',
#    'Cooking basics',
#    'Oven',
#    'Stove']},
#  {'name': 'Hawaii North Shore Oahu getaway!',
#   'accommodates': 2,
#   'number_of_reviews': 42,
#   'amenities': ['Cable TV',
#    'Wifi',
#    'Pool',
#    'Kitchen',
#    'Free parking on premises',
#    'Pets live on this property',
#    'Cat(s)',
#    'Other pet(s)',
#    'Family/kid friendly',
#    'Washer',
#    'Dryer']},
#  {'name': 'Beautiful Place in the Middle of Manhattan',
#   'accommodates': 2,
#   'number_of_reviews': 180,
#   'amenities': ['Wifi',
#    'Air conditioning',
#    'Kitchen',
#    'Pets allowed',
#    'Free street parking',
#    'Heating',
#    'Family/kid friendly',
#    'Smoke detector',
#    'Carbon monoxide detector',
#    'First aid kit',
#    'Fire extinguisher',
#    'Essentials',
#    'Shampoo',
#    'Lock on bedroom door',
#    'Hangers',
#    'Hair dryer',
#    'Laptop friendly workspace',
#    'Private living room',
#    'Children’s books and toys',
#    'Hot water',
#    'Bed linens',
#    'Extra pillows and blankets',
#    'Microwave',
#    'Coffee maker',
#    'Refrigerator',
#    'Dishes and silverware',
#    'Cooking basics',
#    'Oven',
#    'Stove',
#    'Luggage dropoff allowed',
#    'Long term stays allowed',
#    'Host greets you']},
#  {'name': 'Triple room with private bathroom',
#   'accommodates': 3,
#   'number_of_reviews': 141,
#   'amenities': ['Wifi',
#    'Kitchen',
#    'Heating',
#    'Family/kid friendly',
#    'Washer',
#    'Essentials',
#    'Shampoo',
#    '24-hour check-in',
#    'Hangers',
#    'Hair dryer',
#    'Iron',
#    'translation missing: en.hosting_amenity_50',
#    'Hot water',
#    'Luggage dropoff allowed',
#    'Long term stays allowed',
#    'Host greets you',
#    'Paid parking on premises']},
#  {'name': 'Stylish 1br apt west village',
#   'accommodates': 2,
#   'number_of_reviews': 108,
#   'amenities': ['Wifi',
#    'Air conditioning',
#    'Kitchen',
#    'Heating',
#    'Smoke detector',
#    'First aid kit',
#    'Essentials',
#    'Shampoo',
#    'Hangers',
#    'Hair dryer',
#    'Iron',
#    'Laptop friendly workspace',
#    'Coffee maker',
#    'Refrigerator',
#    'Cooking basics',
#    'Oven',
#    'Stove']}]

# %% [markdown]
# ## Question 7
#
# Return the count of documents that do not have any of the following cast members: "Gèrard Depardieu", "Robert De Niro", "Morgan Freeman", "Samuel L. Jackson","Nicolas Cage", nor "Bruce Willis".

# %%
movies['movies'].count_documents({'cast':{"$nin":["Gèrard Depardieu", "Robert De Niro", "Morgan Freeman", "Samuel L. Jackson","Nicolas Cage", "Bruce Willis"],"$exists":True}})
# Out:
# 22836

# %% [markdown]
# ## Question 8
#
# Write the following in MongoDB:
#
# SELECT name, number_of_reviews, beds <br>
# FROM airbnb <br>
# WHERE number_of_reviews >= 200 <br>
# ORDER BY beds DESC <br>
# LIMIT 1

# %%
list(airbnb.find({"number_of_reviews":{"$gte":200}},{'_id':0,"name":1}).sort("beds",-1))
# Out:
# [{'name': 'Beautiful Home Away From Home!'},
#  {'name': 'Spectacular Modern Uptown Duplex'},
#  {'name': 'SANTA CATARINA HOUSE'},
#  {'name': 'Lulapartment'},
#  {'name': 'Lulapartment II'},
#  {'name': '3BR 2WR Apt (KS) 5 min wan chai MTR'},
#  {'name': 'Rustic Gaudí - Sagrada Família'},
#  {'name': 'Glorias:Sagrada Familia 15minutes, Beach 20minutes'},
#  {'name': 'Historical Istanbul House @ Taksim'},
#  {'name': 'Casa da Hera - The Ivy House'},
#  {'name': 'The Ohana at Volcanoes National Park!'},
#  {'name': 'great Terrace&lift city center'},
#  {'name': "B & B  Room Yoga Garden's Place"},
#  {'name': "ABEL'S IN DOWNTOWN - THE PLACE TO BE 1 OF 2"},
#  {'name': 'Beautiful North Shore Oahu,3 Beds!'},
#  {'name': 'Next to the Airport/up to 2+1 people double room'},
#  {'name': 'Back-to-Back House II'},
#  {'name': 'Sunny penthouse with Parking'},
#  {'name': 'ROMANTIC Apartment WIFI in center'},
#  {'name': 'Spanish family host U/private WC'},
#  {'name': '5 Star 2BDR, Prime Location, Very Quiet, Elevator'},
#  {'name': 'Apartamento São Bento da Vitória 2 - Amazing view'},
#  {'name': '2 BR Queen Size Sunny - Nolita'},
#  {'name': 'BOMBARDA Room'},
#  {'name': '1 Stop fr. Manhattan! Private Suite,Landmark Block'},
#  {'name': '5*Super host Apartment+terrace  8 min from Ramblas'},
#  {'name': 'Stylish apartment A in city center'},
#  {'name': 'Mezzos Studio in Sydney CBD'},
#  {'name': 'The New York Loft in Old Montreal'},
#  {'name': 'Clérigos 1 or 2 guests (2 singles beds ) small'},
#  {'name': 'Beautiful apartment in the center'},
#  {'name': 'East Village Studio'},
#  {'name': 'Atic with great views'},
#  {'name': 'Hamakua Hideaway Cliff House'},
#  {'name': 'Cozy LOFT - In the ❤ of OLD PORT / Old Montreal'},
#  {'name': 'LOVELY AND CENTRAL ROOM'},
#  {'name': 'Triple Room@Austin,Jordan,Tsim Sha Tsui'},
#  {'name': 'traditional and Charming room'},
#  {'name': 'Most breathtaking view of Manhattan'},
#  {'name': 'Little Italy gem Center of it all!'},
#  {'name': 'Oporto Best View'},
#  {'name': 'ON HIGHLINE! Private room & bath'},
#  {'name': 'New apartment near Sagrada Familia'},
#  {'name': 'La Sagrada Familia (and metro) 4 blocks!'},
#  {'name': 'A bedroom far away from home'},
#  {'name': 'FloresRooms 3T'},
#  {'name': 'Bundeena Garden Studio near beaches'},
#  {'name': 'Newly and comfortable apt'},
#  {'name': "O'Porto Studio | Historic Center"},
#  {'name': 'Private Cozy Bedroom in Brooklyn'},
#  {'name': 'Convenient & Cozy Private Rm@Jordan'},
#  {'name': 'Bright PrivateRm 1 min to JordanMTR'},
#  {'name': 'Sunny 1 or 2 BR apt in Boerum Hill'},
#  {'name': 'The Sassy Lilac Megan Love Room'},
#  {'name': "Cute apt in artist's home"},
#  {'name': 'Eco Hale Hawaii in the Rainforest Lots Of Aloha'},
#  {'name': 'Private entire second floor'},
#  {'name': 'Near Airport private room, 2 bedroom granny flat**'},
#  {'name': '☼☼ Lovely Colorful Studio ☼☼ Tsim Sha Tsui'},
#  {'name': 'IPANEMA - EXCELLENT LOCATION !!!'},
#  {'name': 'Fresh, Simple Sleep in Brooklyn!'},
#  {'name': 'Beautiful apartment by Pl Catalunya'},
#  {'name': 'Studio + Terrace @ Historic Centre!'},
#  {'name': '1分鐘到高鐵西九龍站､地鐵柯士甸站､機場和港珠澳大橋巴士A22站    10分鐘到中港城碼頭､海港城'},
#  {'name': 'Adorable Garden Gingerbread House'},
#  {'name': 'Cute Tiny Room Family Home by LGA NO CLEANING FEE'},
#  {'name': 'IDEALLY LOCATED COZY COTTAGE'},
#  {'name': 'Stunning vintage room with AC (old town)'},
#  {'name': 'New Studio in Heart of Chelsea'},
#  {'name': 'Charming Beach #1 Cabana Room Single'},
#  {'name': 'SUPREME BALCONY DOUBLE ROOM'},
#  {'name': 'Porto city centre apartment H'},
#  {'name': 'Kailua Blue Ocean Breeze/Across Beach'},
#  {'name': 'Females only for midtown apt share'},
#  {'name': 'Lovely apartment with private parking'},
#  {'name': 'Bronte B&B Studio'},
#  {'name': 'Charming Boutique Room in Bushwick'},
#  {'name': 'cozy room in Taksim Istanbul'},
#  {'name': 'Double 02 CasanovaRooms Barcelona'},
#  {'name': '#Private Studio - Waikiki Dream'},
#  {'name': 'Cozy apartment'},
#  {'name': 'B&B Porto Downtown 1'},
#  {'name': 'North Shore Resort, Private room  '},
#  {'name': 'Apartment for 2 guests'},
#  {'name': 'PRIVATE Room in Spacious, Quiet Apt'},
#  {'name': 'A Romantic Loft plus terrace  Heart of Brooklyn'},
#  {'name': 'Chic Inner City - 3 mins to Trains'},
#  {'name': 'Room w/pvt bathroom on Central Park'},
#  {'name': 'Great studio/NOT a shared space'},
#  {'name': 'Manhattan, near subway, quiet street in LES!'},
#  {'name': 'Room near a Lovely Beach & Airport'},
#  {'name': 'Newly renovated historic brownstone'},
#  {'name': 'Cozy Cottage, Room #2'},
#  {'name': 'Perfectly Located Apartment With View'},
#  {'name': 'Very Large Private Room on quiet st'},
#  {'name': 'Copacabana Beautiful Studio Beside Ipanema'},
#  {'name': 'Hale Kea - A Relaxing Apartment with Ocean Views in Kona'},
#  {'name': 'Elegant suite in historic center'},
#  {'name': 'Chic City Pad with Leafy Outlook'}]

# %% [markdown]
# ## Question 9
#
# Return the count of all documents where the "tomates.viewer.rating" value is "$ne" to 3.

# %%
movies['movies'].count_documents({"tomatoes.viewer.rating":{'$ne':3}})
# Out:
# 22501

# %% [markdown]
# ## Question 10
#
# Return the count of all the documents that have the "property_type" value of "Bungalow" and "amenities" that have the following items: "TV", "Wifi","Smart TV", "Heating", "Swimming Pool", "Waterfront","Gym","Beachfront","Safe","Refrigerator", and a "Tennis Court".
#
# ~~~
# Syntax: { field: { $in: [<value1>, <value2>, ... <valueN> ] } }
# ~~~

# %%
airbnb.count_documents({"property_type":"Bungalow","amenities":{"$in":["TV","Wifi","Smart TV","Heating","Swimming Pool", "Waterfront","Gym","Beachfront","Safe","Refrigerator", "Tennis Court"]}})
# Out:
# 14

# %% [markdown]
# # Logical Operators
#
# ~~~
# $and: Joins query clauses with a logical AND returns all documents that match the conditions of both clauses.
# $not: Inverts the effect of a query expression and returns documents that do not match the query expression.
# $nor: Joins query clauses with a logical NOR returns all documents that fail to match both clauses.
# $or: Joins query clauses with a logical OR returns all documents that match the conditions of either clause.
# ~~~
#
# See https://docs.mongodb.com/manual/reference/operator/query-logical/ for more info.

# %% [markdown]
# ## The OR operator examples
#
# ~~~
# Syntax: { $or: [ { <expression1> }, { <expression2> }, ... , { <expressionN> } ] }
# ~~~

# %% [markdown]
# ## Question 11
#
# Rewrite the above question (Question 10) using the $or operator.

# %% [markdown]
# ## Question 12
#
# Return the count of all documents in the movies database and movies collection (i.e. movies["movies"]) where the document had either a "rated" value of "PG" or "PG-13".

# %% [markdown]
# ## Question 13
#
# Return two movies sorted by year descending where either the "awards.wins" value is greater than 250 or
# the "year" is between 2000 and 2005.

# %% [markdown]
# ## Question 14
#
# Return 3 movies sorted by year descending where either the "awards.wins" value is greater than 250 or
# the "year" is less than 2005 or greater than 2015.

# %% [markdown]
# ## The AND operator examples
#
# ~~~
# Syntax: { $and: [ { <expression1> }, { <expression2> } , ... , { <expressionN> } ] }
# ~~~

# %% [markdown]
# ## Question 15
#
# Return a movie that has a "runtime" of greater than 90, a year greater than 2000,
# and an "imdb.votes" less than 40.

# %% [markdown]
# ## Question 16
#
# Return the document's title sorted by "year" descending that has a "runtime" value greater than 100, "year" greater than 2000 and less than 2005, and an "imdb.votes" value less than 30. Show 3 different ways of writing this query.

# %% [markdown]
# ## Question 17
#
#
# Return a document that has a "type" of movie, and where the "year" value is less than 1930 or rated a "PG", and the "imdb.votes" is greater than 100 or the runtime is greater than 120.

# %% [markdown]
# ## The NOT
#
# ~~~
# $NOT syntax: { field: { $not: { <operator-expression> } } }
# ~~~
#
# See more here https://docs.mongodb.com/manual/reference/operator/query/not/#op._S_not

# %% [markdown]
# ## Question 18
#
# Return the count of all the documents in training['grades'] dataset where none of the "scores.score" values are less than 93.5

# %% [markdown]
# # Other Operators
#
# Element, Evaluation, Geospatial, and Array operators
#
# ~~~
# $text: Performs text search.
# {
#   $text:
#     {
#       $search: <string>,
#       $language: <string>,
#       $caseSensitive: <boolean>,
#       $diacriticSensitive: <boolean>
#     }
# }
#
#
# $elemMatch: Selects documents if element in the array field matches all the specified $elemMatch conditions.
# { <field>: { $elemMatch: { <query1>, <query2>, ... } } }
#
#
#
# $size: Selects documents if the array field is a specified size.
# { <field>: { $size: value } }
#
#
#
# $all: Matches arrays that contain all elements specified in the query.
# { <field>: { $all: [ <value1> , <value2> ... ] } }
#
# ~~~
# text - https://docs.mongodb.com/manual/reference/operator/query/text <br>
# elemMatch - https://docs.mongodb.com/manual/reference/operator/query/elemMatch/ <br>
# size - https://docs.mongodb.com/manual/reference/operator/query/size/ <br>
# all - https://docs.mongodb.com/manual/reference/operator/query/all/

# %% [markdown]
# ## Question 19 - $text
#
# Return the documents sorted by beds descending that have the word "park" or the phrase "los angeles" in the description field (index has already been created on "description") in the Airbnb dataset. Only return the description, name and limit to 1 result sorted by "beds" descending.

# %% [markdown]
# ## Question 20 - $elemMatch
#
# In the geospatial dataset, sorted by "latdec" descending, find a document where the "coordinates" the longitude value is greater than -90 but less than or equal -88. Limit to 1 result.

# %% [markdown]
# ## Question 21 - $elemMatch
#
# In the training["companies"] dataset, return the count of documents that have at least one embedded document in the "relationships" field where the "person.first_name" value is "Ben" and the "is_past" value is False. Compare this count with the count of documents where the "relationships" field has an "is_past" value of false and a "person.first_name" value of "Ben".

# %% [markdown]
# ## Question 22 - $elemMatch
#
# In the grades collection, find a document where one element matches the type of "scores.type"
# of "exam" and "scores.score" is greater than 97.

# %% [markdown]
# ## Question 23 - $size
#
# In the Airbnb dataset, return the count of documents that have an "amenities" field size of 25.

# %% [markdown]
# ## Question 24 - $all
#
# Return the count of documents that have all the following values in the "amenities" field: 'TV', 'Kitchen', 'Wifi', 'Internet','Cable TV', 'Coffee maker', 'Cooking basics','Family/kid friendly', 'Gym', and 'Heating'.

# %% [markdown]
# ## Question 25 - $all with elemMatch
#
# Return a single document sorted by class_id descending where there's one embeddded document that has "scores.type" of exam and "scores.score" of greater than 97, "scores.type" of quiz and "scores.score" of greater than 96, and
# "scores.type" of homework and "scores.score" of greater than 95.
