# %%
import pandas as pd
import numpy as np
import math
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# %%
data=pd.read_csv('raw data 17-19\SH600000.csv')

# %%
data.head()
# Out:
#    Time      Open      High       Low     Close    Volume
# 0  Day1  154.6414  159.7405  154.4560  156.9592  45036400
# 1  Day2  156.9592  158.7207  156.3102  156.5883  21043100
# 2  Day3  156.5883  158.5353  155.8467  158.4426  23335200
# 3  Day4  158.9988  162.1510  158.9988  159.5551  33835300
# 4  Day5  159.5551  160.8530  158.6280  160.0186  29530100

# %%
variables=pd.read_csv('engineered features 17-19\SH600000.csv')

# %%
variables.rename(columns={'Unnamed: 0':'Time'},inplace=True)

# %%
variables.head()
# Out:
#     Time  volumelag     rsilag  fastKlag  fastDlag     ADlag     OBVlag  \
# 0  Day17   17860600  57.161421  0.493500  0.628701 -0.600043  132603900
# 1  Day18   30809600  43.371027  0.000000  0.324672 -1.000000  101794300
# 2  Day19   14531400  42.452003  0.031911  0.175137 -0.700032   87262900
# 3  Day20    8483500  39.311722  0.009433  0.013781 -0.894749   78779400
# 4  Day21   22525800  34.588465  0.110347  0.050564 -0.272718   56253600
#
#       MA5lag     MA15lag  day5Returnlag  day15Returnlag   PROClag
# 0  160.05570  159.320207       0.233345        1.716987  0.058217
# 1  159.23984  159.202773      -3.690899       -2.282088 -2.833712
# 2  157.97898  158.937000      -4.745577       -3.195824 -0.239781
# 3  156.18038  158.510527      -3.785677       -4.287377 -0.843920
# 4  154.53014  157.904820      -5.238613       -5.128181 -1.463404

# %%
data=data.merge(variables,on='Time',how='left')

# %% [markdown]
# ### variable creation

# %% [markdown]
# #### 1. MACD

# %%
data['EMA-12']=np.array(0)

# %%
## 12day EMA
N=12.0
coeff=2.0/(N+1)
data.loc[0,'EMA-12'] = data.loc[0,'Close']
for i in range(1,len(data)):
    data.loc[i,'EMA-12'] = (data.loc[i-1,'EMA-12']*(1-coeff))+ (data.loc[i,'Close']*coeff)

# %%
data['EMA-26']=np.array(0)
## 26day EMA
N=26.0
coeff=2.0/(N+1)
data.loc[0,'EMA-26'] = data.loc[0,'Close']
for i in range(1,len(data)):
    data.loc[i,'EMA-26'] = (data.loc[i-1,'EMA-26']*(1-coeff))+ (data.loc[i,'Close']*coeff)

# %%
##DIF
data['DIF'] = data['EMA-12']-data['EMA-26']

# %%
## MACD
N=9
coeff=2.0/(N+1)
data['MACD']=np.array(0)
data.loc[0,'MACD'] = 0
for i in range(2,len(data)):
    data.loc[i,'MACD']= (data.loc[i-1,'MACD']*(1-coeff))+ (data.loc[i,'DIF']*coeff)

# %%
data.head()
# Out:
#    Time      Open      High       Low     Close    Volume  volumelag  rsilag  \
# 0  Day1  154.6414  159.7405  154.4560  156.9592  45036400        NaN     NaN
# 1  Day2  156.9592  158.7207  156.3102  156.5883  21043100        NaN     NaN
# 2  Day3  156.5883  158.5353  155.8467  158.4426  23335200        NaN     NaN
# 3  Day4  158.9988  162.1510  158.9988  159.5551  33835300        NaN     NaN
# 4  Day5  159.5551  160.8530  158.6280  160.0186  29530100        NaN     NaN
#
#    fastKlag  fastDlag  ...  OBVlag  MA5lag  MA15lag  day5Returnlag  \
# 0       NaN       NaN  ...     NaN     NaN      NaN            NaN
# 1       NaN       NaN  ...     NaN     NaN      NaN            NaN
# 2       NaN       NaN  ...     NaN     NaN      NaN            NaN
# 3       NaN       NaN  ...     NaN     NaN      NaN            NaN
# 4       NaN       NaN  ...     NaN     NaN      NaN            NaN
#
#    day15Returnlag  PROClag      EMA-12      EMA-26       DIF      MACD
# 0             NaN      NaN  156.959200  156.959200  0.000000  0.000000
# 1             NaN      NaN  156.902138  156.931726 -0.029587  0.000000
# 2             NaN      NaN  157.139133  157.043643  0.095490  0.019098
# 3             NaN      NaN  157.510820  157.229676  0.281143  0.071507
# 4             NaN      NaN  157.896632  157.436263  0.460369  0.149279
#
# [5 rows x 21 columns]

# %%
data.drop(['EMA-12','EMA-26','DIF'],axis=1,inplace=True)

# %% [markdown]
# #### 2. 3-Day Return & MA3

# %%
## 3-Day Return
price = data["Close"]
day3Return = np.zeros(len(data))
for i in range(14,len(data)):
    day3Return[i] = 100*(price[i]-price[i-2])/price[i-2]

# %%
day3Returnlag = np.append(np.array([0]),day3Return[0:len(day3Return)-1])
data['day3Returnlag']=day3Returnlag

# %%
## MA3
MA3 = np.zeros(len(data))
for i in range(14,len(data)):
    MA3[i] = data.loc[i-2:i+1,'Close'].sum()/3

# %%
MA3lag = np.append(np.array([0]),MA3[0:len(MA3)-1])
data['MA3lag']=MA3lag

# %%
data.head()
# Out:
#    Time      Open      High       Low     Close    Volume  volumelag  rsilag  \
# 0  Day1  154.6414  159.7405  154.4560  156.9592  45036400        NaN     NaN
# 1  Day2  156.9592  158.7207  156.3102  156.5883  21043100        NaN     NaN
# 2  Day3  156.5883  158.5353  155.8467  158.4426  23335200        NaN     NaN
# 3  Day4  158.9988  162.1510  158.9988  159.5551  33835300        NaN     NaN
# 4  Day5  159.5551  160.8530  158.6280  160.0186  29530100        NaN     NaN
#
#    fastKlag  fastDlag  ADlag  OBVlag  MA5lag  MA15lag  day5Returnlag  \
# 0       NaN       NaN    NaN     NaN     NaN      NaN            NaN
# 1       NaN       NaN    NaN     NaN     NaN      NaN            NaN
# 2       NaN       NaN    NaN     NaN     NaN      NaN            NaN
# 3       NaN       NaN    NaN     NaN     NaN      NaN            NaN
# 4       NaN       NaN    NaN     NaN     NaN      NaN            NaN
#
#    day15Returnlag  PROClag      MACD  day3Returnlag  MA3lag
# 0             NaN      NaN  0.000000            0.0     0.0
# 1             NaN      NaN  0.000000            0.0     0.0
# 2             NaN      NaN  0.019098            0.0     0.0
# 3             NaN      NaN  0.071507            0.0     0.0
# 4             NaN      NaN  0.149279            0.0     0.0

# %% [markdown]
# #### 4. Open,High,Low,Close lag

# %%
Openlag = np.append(np.array([0]),data['Open'][0:len(data)-1])
data['Openlag']=Openlag

# %%
Highlag = np.append(np.array([0]),data['High'][0:len(data)-1])
data['Highlag']=Highlag

# %%
Lowlag = np.append(np.array([0]),data['Low'][0:len(data)-1])
data['Lowlag']=Lowlag

# %%
Closelag = np.append(np.array([0]),data['Close'][0:len(data)-1])
data['Closelag']=Closelag

# %%
data
# Out:
#        Time      Open      High       Low     Close    Volume   volumelag  \
# 0      Day1  154.6414  159.7405  154.4560  156.9592  45036400         NaN
# 1      Day2  156.9592  158.7207  156.3102  156.5883  21043100         NaN
# 2      Day3  156.5883  158.5353  155.8467  158.4426  23335200         NaN
# 3      Day4  158.9988  162.1510  158.9988  159.5551  33835300         NaN
# 4      Day5  159.5551  160.8530  158.6280  160.0186  29530100         NaN
# ..      ...       ...       ...       ...       ...       ...         ...
# 751  Day752  157.8890  159.6702  157.5073  158.0162  40150148  23789908.0
# 752  Day753  158.5252  158.5252  154.8356  155.2172  37033892  40150148.0
# 753  Day754  155.3445  156.3623  155.2172  156.2351  21671028  37033892.0
# 754  Day755  156.3623  156.3623  155.2172  155.7262  13678175  21671028.0
# 755  Day756  155.9806  156.7440  155.5989  156.3623  15739054  13678175.0
#
#         rsilag  fastKlag  fastDlag  ...  day5Returnlag  day15Returnlag  \
# 0          NaN       NaN       NaN  ...            NaN             NaN
# 1          NaN       NaN       NaN  ...            NaN             NaN
# 2          NaN       NaN       NaN  ...            NaN             NaN
# 3          NaN       NaN       NaN  ...            NaN             NaN
# 4          NaN       NaN       NaN  ...            NaN             NaN
# ..         ...       ...       ...  ...            ...             ...
# 751  62.404014  0.876540  0.864197  ...       2.392746        4.198110
# 752  62.745694  0.847054  0.862597  ...       2.390708        4.633532
# 753  51.626945  0.588230  0.770608  ...      -1.533547        2.866762
# 754  54.766169  0.658233  0.697839  ...      -0.967725        4.510676
# 755  52.917208  0.569451  0.605305  ...      -1.369823        2.943681
#
#       PROClag      MACD  day3Returnlag      MA3lag   Openlag   Highlag  \
# 0         NaN  0.000000       0.000000    0.000000    0.0000    0.0000
# 1         NaN  0.000000       0.000000    0.000000  154.6414  159.7405
# 2         NaN  0.019098       0.000000    0.000000  156.9592  158.7207
# 3         NaN  0.071507       0.000000    0.000000  156.5883  158.5353
# 4         NaN  0.149279       0.000000    0.000000  158.9988  162.1510
# ..        ...       ...            ...         ...       ...       ...
# 751  0.080595 -0.567049       0.161386  210.433867  157.7618  159.0341
# 752  0.080530 -0.369724       0.161256  209.628067  157.8890  159.6702
# 753 -1.787213 -0.200753      -1.692201  209.119167  158.5252  158.5252
# 754  0.653650 -0.066074      -1.127163  208.398233  155.3445  156.3623
# 755 -0.326259  0.050351       0.327928  207.846933  156.3623  156.3623
#
#        Lowlag  Closelag
# 0      0.0000    0.0000
# 1    154.4560  156.9592
# 2    156.3102  156.5883
# 3    155.8467  158.4426
# 4    158.9988  159.5551
# ..        ...       ...
# 751  157.5073  157.8890
# 752  157.5073  158.0162
# 753  154.8356  155.2172
# 754  155.2172  156.2351
# 755  155.2172  155.7262
#
# [756 rows x 24 columns]

# %%
# OBV
data['OBV']=data['OBVlag']+(data['Close'] > data['Closelag'])*data['Volume']+(data['Close'] < data['Closelag'])*(-data['Volume'])
# Out:
# 0               NaN
# 1               NaN
# 2               NaN
# 3               NaN
# 4               NaN
#            ...
# 751    1.846001e+09
# 752    1.886151e+09
# 753    1.849117e+09
# 754    1.870788e+09
# 755    1.857110e+09
# Length: 756, dtype: float64

# %%
# PROC
data["PROC"]=(data['Close']-data['Closelag'])/data['Closelag']

# %%
data.drop(['Open','High','Low','Close','Volume'],axis=1,inplace=True)

# %%
data=data.iloc[16:,:]

# %%
data.head()
# Out:
#      Time   volumelag     rsilag  fastKlag  fastDlag     ADlag       OBVlag  \
# 16  Day17  17860600.0  57.161421  0.493500  0.628701 -0.600043  132603900.0
# 17  Day18  30809600.0  43.371027  0.000000  0.324672 -1.000000  101794300.0
# 18  Day19  14531400.0  42.452003  0.031911  0.175137 -0.700032   87262900.0
# 19  Day20   8483500.0  39.311722  0.009433  0.013781 -0.894749   78779400.0
# 20  Day21  22525800.0  34.588465  0.110347  0.050564 -0.272718   56253600.0
#
#        MA5lag     MA15lag  day5Returnlag  day15Returnlag   PROClag      MACD  \
# 16  160.05570  159.320207       0.233345        1.716987  0.058217  0.601010
# 17  159.23984  159.202773      -3.690899       -2.282088 -2.833712  0.470475
# 18  157.97898  158.937000      -4.745577       -3.195824 -0.239781  0.288494
# 19  156.18038  158.510527      -3.785677       -4.287377 -0.843920  0.047651
# 20  154.53014  157.904820      -5.238613       -5.128181 -1.463404 -0.211652
#
#     day3Returnlag      MA3lag   Openlag   Highlag    Lowlag  Closelag
# 16      -1.772484  211.812967  159.1842  161.5020  158.7207  159.2769
# 17      -2.737332  209.247967  158.8134  158.8134  154.8268  154.8268
# 18      -3.026741  207.239233  154.8268  156.0321  154.1779  154.4560
# 19      -1.077850  204.457933  154.3633  154.8268  153.0653  153.1580
# 20      -2.280908  203.283600  153.1580  153.5289  149.4496  150.9330

# %%
data[data['Time'] =='Day504']
# Out:
#        Time   volumelag     rsilag  fastKlag  fastDlag     ADlag  \
# 503  Day504  12448791.0  48.829347  0.447764  0.492539 -0.684184
#
#            OBVlag     MA5lag     MA15lag  day5Returnlag  day15Returnlag  \
# 503  1.503734e+09  133.43596  132.621573      -1.559588        0.845921
#
#       PROClag      MACD  day3Returnlag      MA3lag   Openlag   Highlag  \
# 503  0.093246  0.544583      -0.923347  177.190733  134.3737  134.3737
#
#        Lowlag  Closelag
# 503  132.0293  132.3995

# %% [markdown]
# ## Train, Test &OOT

# %%
tt=data.iloc[:404,:].copy()
oot=data.iloc[404:504,:].copy()

# %%
tt.to_csv('SH600000_tt.csv')
oot.to_csv('SH600000_oot.csv')
